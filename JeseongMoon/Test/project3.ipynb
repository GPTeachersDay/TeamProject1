# %% [markdown]
# # EDA : 강철판
#
# ## features
# 1. X_Minimum : X의 최소값
# 2. X_Maximum : X의 최대값
# 3. Y_Minimum : Y의 최소값
# 4. Y_Maximum : Y의 최대값
# 5. Pixels_Areas : 픽셀 영역 (오류가 발생한 강판의 영역을 픽셀로 표시한 크기)
# 6. X_Perimeter : X 주변의 길이 (오류가 발생한 강판의 X 방향 주변 길이)
# 7. Y_Perimeter : Y 주변의 길이 (오류가 발생한 강판의 Y 방향 주변 길이)
# 8. Sum_of_Luminosity : 휘도의 합 (오류가 발생한 강판 영역의 전체 휘도)
# 9. Minimum_of_Luminosity : 최소 휘도 (오류가 발생한 강판 영역의 최소 휘도)
# 10. Maximum_of_Luminosity : 최대 휘도 (오류가 발생한 강판 영역의 최대 휘도)
# 11. Length_of_Conveyer : 컨베이어의 길이
# 12. TypeOfSteel_A300 : A300 형 강판 여부
# 13. TypeOfSteel_A400 : A400 형 강판 여부
# 14. Steel_Plate_Thickness : 강판의 두께
# 15. Edges_Index : 가장자리 지수 (오류가 발생한 강판의 가장자리 형태를 나타내는 지표)
# 16. Empty_Index : 빈 공간 지수 (오류가 발생한 강판의 빈 공간을 나타내는 지표)
# 17. Square_Index : 정사각형 지수 (오류가 발생한 강판의 정사각형 형태를 나타내는 지표)
# 18. Outside_X_Index : 외부 X 지수 (오류가 발생한 강판의 X 방향 외부 형태를 나타내는 지표)
# 19. Edges_X_Index : 가장자리 X 지수 (오류가 발생한 강판의 X 방향 가장자리를 나타내는 지표)
# 20. Edges_Y_Index : 가장자리 Y 지수 (오류가 발생한 강판의 Y 방향 가장자리를 나타내는 지표)
# 21. Outside_Global_Index : 전체 외부 지수 (오류가 발생한 강판의 전체 외부 형태를 나타내는 지표)
# 22. LogOfAreas : 영역의 로그값
# 23. Log_X_Index : X 지수의 로그값
# 24. Log_Y_Index : Y 지수의 로그값
# 25. Orientation_Index : 방향 지수 (오류가 발생한 강판의 방향을 나타내는 지표)
# 26. Luminosity_Index : 휘도 지수 (오류가 발생한 강판의 휘도를 나타내는 지표)
# 27. SigmoidOfAreas : 영역의 시그모이드 함수 값 (이 함수는 보통 0과 1 사이의 결과를 내며, 여기서는 오류 영역의 특성을 나타낼 수 있습니다)
#
#
# ## target
# 1. Pastry : 페이스트리 결함, 이는 강판의 특정 부분이 너무 얇아져 결함이 발생한 경우를 의미할 수 있습니다.
# 2. Z_Scratch : Z 스크래치 결함, 강판에 'Z' 모양의 스크래치가 생긴 경우를 의미합니다.
# 3. K_Scatch : K 스크래치 결함, 강판에 'K' 모양의 스크래치가 생긴 경우를 의미합니다.
# 4. Stains : 얼룩 결함, 강판에 얼룩이나 불순물이 생긴 경우를 의미합니다.
# 5. Dirtiness : 더러움 결함, 강판이 더러워진 경우를 의미합니다.
# 6. Bumps : 돌기 결함, 강판에 돌기나 울퉁불퉁한 부분이 생긴 경우를 의미합니다.
# 7. Other_Faults : 기타 결함, 위의 카테고리에 속하지 않는 기타 다른 종류의 결함을 의미합니다.
#
#
# ## Domain
# 강판 결함 분석은 제조 공정에서 중요한 부분입니다.
# 강판은 건축, 자동차, 선박, 가전제품 등 다양한 산업에서 사용되는 주요 소재이기 때문에, 그 품질은 최종 제품의 품질에 직접적인 영향을 미칩니다.
# 따라서 강판의 결함을 정확하게 감지하고 분류하는 것은 제조 효율성, 안전성, 그리고 경제성을 높이는 데 매우 중요합니다.
#
# 1. 강판의 특성:
# 강판의 결함은 종류와 크기에 따라 다양하게 나타날 수 있습니다.
# 결함의 유형에는 표면상의 불규칙한 부분, 두께의 불규칙, 재질 결함, 구조적 결함 등이 있을 수 있습니다.
#
# 2. 제조 공정:
# 강판 제조 공정에서의 다양한 단계에서 결함이 발생할 수 있습니다.
# 예를 들어, 제련, 주조, 압연, 열처리, 표면 마무리 등의 단계에서 결함이 발생할 수 있으며, 이는 최종 제품의 품질에 영향을 미칩니다.
#
# 3. 감지 기술:
# 강판 결함 감지는 시각 검사, 자동 결함 감지 시스템, 비파괴 검사 등 다양한 방법으로 수행될 수 있습니다.
# 머신 러닝 및 AI는 이러한 결함 감지 작업을 자동화하고 정확성을 높이는 데 도움이 될 수 있습니다.
#
# 4. 분석 및 품질 관리:
# 결함 분석은 결함의 원인을 찾고, 제조 공정을 개선하여 향후 결함을 방지하는 데 사용됩니다.
# 또한, 강판의 품질은 ISO 등의 국제 표준에 따라 평가되고 관리됩니다.
#
#
# ## Workflow
# 1. 기본 통계량 확인
# 2. 결측치 확인
# 3. 상관 분석
# 4. 분포 확인
# 5. 카테고리별 분석
# 6. 피처 중요도 분석
#
#
# ## Reference
# - https://www.kaggle.com/datasets/uciml/faulty-steel-plates
# - https://www.kaggle.com/code/tahazafar/steel-plate-faults-data-analysis/notebook
# - https://mindcompass.github.io/data_analysis/data_analysis(test2_1)/

# %% [markdown]
# ## Data Load

# %%
import pandas as pd

csv_path = '/Users/moonjeseong/Desktop/project/TeamProject1/JeseongMoon/Dataset/mulit_classification_data.csv'
df = pd.read_csv(csv_path)
print(f'{df.shape}')
df.head()
# Out:
# (1941, 34)
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %%
temp_df = pd.DataFrame({
    'Pixels_Areas' : df['Pixels_Areas'],
    'Area' : (df['X_Maximum'] - df['X_Minimum']) * (df['Y_Maximum'] - df['Y_Minimum'])
})
temp_df
# Out:
#       Pixels_Areas  Area
# 0              267   352
# 1              108   174
# 2               71   108
# 3              176   315
# 4             2409  4369
# ...            ...   ...
# 1936           273   448
# 1937           287   527
# 1938           292   435
# 1939           419  1023
# 1940           103   320
#
# [1941 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Minimum              1941 non-null   int64
#  1   X_Maximum              1941 non-null   int64
#  2   Y_Minimum              1941 non-null   int64
#  3   Y_Maximum              1941 non-null   int64
#  4   Pixels_Areas           1941 non-null   int64
#  5   X_Perimeter            1941 non-null   int64
#  6   Y_Perimeter            1941 non-null   int64
#  7   Sum_of_Luminosity      1941 non-null   int64
#  8   Minimum_of_Luminosity  1941 non-null   int64
#  9   Maximum_of_Luminosity  1941 non-null   int64
#  10  Length_of_Conveyer     1941 non-null   int64
#  11  TypeOfSteel_A300       1941 non-null   int64
#  12  TypeOfSteel_A400       1941 non-null   int64
#  13  Steel_Plate_Thickness  1941 non-null   int64
#  14  Edges_Index            1941 non-null   float64
# ...

# %%
df.describe(include="all")
# Out:
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1941.000000  1941.000000  1.941000e+03  1.941000e+03    1941.000000
# mean    571.136012   617.964451  1.650685e+06  1.650739e+06    1893.878413
# std     520.690671   497.627410  1.774578e+06  1.774590e+06    5168.459560
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      51.000000   192.000000  4.712530e+05  4.712810e+05      84.000000
# 50%     435.000000   467.000000  1.204128e+06  1.204136e+06     174.000000
# 75%    1053.000000  1072.000000  2.183073e+06  2.183084e+06     822.000000
# max    1705.000000  1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000   1941.000000       1.941000e+03            1941.000000
# mean     111.855229     82.965997       2.063121e+05              84.548686
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

corr = df.corr()

mask = np.zeros_like(corr, dtype=bool)  # np.bool 대신 bool을 사용
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize=(24, 20))
sns.heatmap(corr,
            cmap="RdYlBu_r",
            annot=True,
            mask=mask,
            fmt='.1f',
            linewidths=.5,
            cbar_kws={"shrink": .5})

plt.show()
save_path = '../../../../../Git_Blog/assets/images/aib/GPTeachersDay/'
fig.savefig(save_path + 'steel_heatmap.png', dpi=80, bbox_inches='tight')

# %%
df.columns
# Out:
# Index(['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
#        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains',
#        'Dirtiness', 'Bumps', 'Other_Faults'],
#       dtype='object')

# %%
multicollinearity_list = ['X_Minimum', 'Y_Minimum', 'Pixels_Areas', 'TypeOfSteel_A300']

# %% [markdown]
# ## Export Report

# %%
# from ydata_profiling import ProfileReport
# df_report = ProfileReport(df, title='Steel Profile Report')
# df_report.to_file('eda_steel.html')

# %%
y_dataframe = df.iloc[:,-7:]
y_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pastry        1941 non-null   int64
#  1   Z_Scratch     1941 non-null   int64
#  2   K_Scatch      1941 non-null   int64
#  3   Stains        1941 non-null   int64
#  4   Dirtiness     1941 non-null   int64
#  5   Bumps         1941 non-null   int64
#  6   Other_Faults  1941 non-null   int64
# dtypes: int64(7)
# memory usage: 106.3 KB

# %%
y_list = []
for i in range(y_dataframe.shape[0]):
    if y_dataframe["Pastry"].values[i] == 1:
        y_list.append("Pastry")
    elif y_dataframe["Z_Scratch"].values[i] == 1:
        y_list.append("Z_Scratch")
    elif y_dataframe["K_Scatch"].values[i] == 1:
        y_list.append("K_Scatch")
    elif y_dataframe["Stains"].values[i] == 1:
        y_list.append("Stains")
    elif y_dataframe["Dirtiness"].values[i] == 1:
        y_list.append("Dirtiness")
    elif y_dataframe["Bumps"].values[i] == 1:
        y_list.append("Bumps")
    else:
        y_list.append("Other_Faults")

y_list = np.array(y_list)
y_list.shape
# Out:
# (1941,)

# %%
faultstype = pd.DataFrame({'faults':y_list})
faultstype.describe()
# Out:
#               faults
# count           1941
# unique             7
# top     Other_Faults
# freq             673

# %%
fig, ax=plt.subplots(1,2,figsize=(15,6))

faultstype['faults'].value_counts().plot.pie(ax=ax[0])
sns.countplot(x='faults', data=faultstype, ax=ax[1])

fig.savefig(save_path + 'steel_targets.png', dpi=80, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 6
#       3 faultstype['faults'].value_counts().plot.pie(ax=ax[0])
#       4 sns.countplot(x='faults', data=faultstype, ax=ax[1])
# ----> 6 fig.savefig(save_path + 'steel_targets.png', dpi=80, bbox_inches='tight')
#
# File ~/opt/anaconda3/envs/project/lib/python3.10/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
#    3341             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3343 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
# ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps']
print(y_dataframe[list(y_dataframe.columns)[:-1]].sum(axis=1).value_counts())

# 'Other_Faults'
print(y_dataframe[list(y_dataframe.columns)[-1]].value_counts())
# Out:
# 1    1268
# 0     673
# dtype: int64
# 0    1268
# 1     673
# Name: Other_Faults, dtype: int64

# %% [markdown]
# ## Predict Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(y_list)
y = encoder.transform(y_list)
X = df.iloc[:,:-7]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 83)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, )
# Out:
# (1552, 27) (389, 27) (1552,) (389,)

# %%
print(encoder.classes_)
encoder.inverse_transform(y_train)
# Out:
# ['Bumps' 'Dirtiness' 'K_Scatch' 'Other_Faults' 'Pastry' 'Stains'
#  'Z_Scratch']
# array(['Other_Faults', 'K_Scatch', 'Bumps', ..., 'Bumps', 'Other_Faults',
#        'Pastry'], dtype='<U12')

# %%
from sklearn import metrics
import numpy as np

def get_metrics(model, X, y):
    y_pred=model.predict(X)
    
    Precision    = metrics.precision_score (y, y_pred, average="weighted")
    Recall       = metrics.recall_score    (y, y_pred, average="weighted")
    Accuracy     = metrics.accuracy_score  (y, y_pred)
    F1           = metrics.f1_score        (y, y_pred, average="weighted")
    
    print(f'Precision Score  : {Precision}')
    print(f'Recall Score     : {Recall}')
    print(f'Accuracy Score   : {Accuracy}')
    print(f'F1 Score         : {F1}')
    return Precision, Recall, Accuracy, F1

# %%
from collections import Counter

# Base Model : 최빈값
y_max = Counter(y_train).most_common(1)[0][0]
y_pred = np.array([y_max] * len(y_test))

print(f'Base Model Precision    : {metrics.precision_score (y_test, y_pred, average="weighted"):.3f}')
print(f'Base Model Recall       : {metrics.recall_score    (y_test, y_pred, average="weighted"):.3f}')
print(f'Base Model Accuracy     : {metrics.accuracy_score  (y_test, y_pred):.3f}')
print(f'Base Model F1           : {metrics.f1_score        (y_test, y_pred, average="weighted"):.3f}')
# Out:
# Base Model Precision    : 0.133
# Base Model Recall       : 0.365
# Base Model Accuracy     : 0.365
# Base Model F1           : 0.195
# /Users/moonjeseong/opt/anaconda3/envs/project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model_lg_all=LogisticRegression(random_state=83)
model_lg_all.fit(X_train, y_train)

lg_precision_train, lg_recall_train, lg_accuracy_train, lg_f1_train = get_metrics(model_lg_all, X_train, y_train)
print('='*100)
lg_precision_test, lg_recall_test, lg_accuracy_test, lg_f1_test = get_metrics(model_lg_all, X_test, y_test)
# Out:
# Precision Score  : 0.35463913675855097
# Recall Score     : 0.4677835051546392
# Accuracy Score   : 0.4677835051546392
# F1 Score         : 0.40283299958871793
# ...
# Precision Score  : 0.3660816055583195
# Recall Score     : 0.4601542416452442
# Accuracy Score   : 0.4601542416452442
# F1 Score         : 0.4051583690924095
# /Users/moonjeseong/opt/anaconda3/envs/project/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
from sklearn.metrics import confusion_matrix

c_mat = confusion_matrix(y_train, model_lg_all.predict(X_train))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(12,10))
fig.suptitle('Confusion Matrix', fontsize = 22, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,
            cbar_kws = {'shrink': .5},
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

# %% [markdown]
# ### Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf_all = RandomForestClassifier(random_state=83)
model_rf_all.fit(X_train, y_train)

rf_precision_train, rf_recall_train, rf_accuracy_train, rf_f1_train = get_metrics(model_rf_all, X_train, y_train)
print('='*100)
rf_precision_test, rf_recall_test, rf_accuracy_test, rf_f1_test = get_metrics(model_rf_all, X_test, y_test)
# Out:
# Precision Score  : 1.0
# Recall Score     : 1.0
# Accuracy Score   : 1.0
# F1 Score         : 1.0
# ...
# Precision Score  : 0.7995036897739692
# Recall Score     : 0.7892030848329049
# Accuracy Score   : 0.7892030848329049
# F1 Score         : 0.7915845166403068

# %%
from sklearn.metrics import confusion_matrix

c_mat = confusion_matrix(y_train, model_rf_all.predict(X_train))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(12,10))
fig.suptitle('Confusion Matrix', fontsize = 22, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,
            cbar_kws = {'shrink': .5},
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

# %% [markdown]
# ### Gradient Boosting Classifier Model

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gb_all = GradientBoostingClassifier(random_state=83)
model_gb_all.fit(X_train, y_train)

gb_precision_train, gb_recall_train, gb_accuracy_train, gb_f1_train = get_metrics(model_gb_all, X_train, y_train)
print('='*100)
gb_precision_test, gb_recall_test, gb_accuracy_test, gb_f1_test = get_metrics(model_gb_all, X_test, y_test)
# Out:
# Precision Score  : 0.9748512901371206
# Recall Score     : 0.9748711340206185
# Accuracy Score   : 0.9748711340206185
# F1 Score         : 0.9748604098017101
# ...
# Precision Score  : 0.7855136793793412
# Recall Score     : 0.7763496143958869
# Accuracy Score   : 0.7763496143958869
# F1 Score         : 0.7789785027761292

# %%
from sklearn.metrics import confusion_matrix

c_mat = confusion_matrix(y_train, model_gb_all.predict(X_train))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(16,15))
fig.suptitle('Confusion Matrix', fontsize = 28, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,             # 실제 값을 표시한다
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,            # 경계면 실선으로 구분하기
            cbar_kws = {'shrink': .5},  # 컬러바 크기 절반으로 줄이기
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

# %% [markdown]
# ### 다중공선성 의심 특성 제거

# %%
y2 = y
X2 = X[[c for c in list(X.columns) if c not in multicollinearity_list]]
X_trains, X_tests, y_trains, y_tests = train_test_split(X2, y2, train_size = 0.8, random_state = 83)
print(X_trains.shape, X_tests.shape, y_trains.shape, y_tests.shape, )
# Out:
# (1552, 23) (389, 23) (1552,) (389,)

# %%
from sklearn.linear_model import LogisticRegression
model_lg_all=LogisticRegression(random_state=83)
model_lg_all.fit(X_trains, y_trains)

lg_precision_train, lg_recall_train, lg_accuracy_train, lg_f1_train = get_metrics(model_lg_all, X_trains, y_trains)
print('='*100)
lg_precision_test, lg_recall_test, lg_accuracy_test, lg_f1_test = get_metrics(model_lg_all, X_tests, y_tests)
# Out:
# Precision Score  : 0.3528892554412816
# Recall Score     : 0.46585051546391754
# Accuracy Score   : 0.46585051546391754
# F1 Score         : 0.40086355048296757
# ...
# Precision Score  : 0.36351605342752336
# Recall Score     : 0.45758354755784064
# Accuracy Score   : 0.45758354755784064
# F1 Score         : 0.40224741041454665
# /Users/moonjeseong/opt/anaconda3/envs/project/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf_all = RandomForestClassifier(random_state=83, max_depth=8)
model_rf_all.fit(X_trains, y_trains)

rf_precision_train, rf_recall_train, rf_accuracy_train, rf_f1_train = get_metrics(model_rf_all, X_trains, y_trains)
print('='*100)
rf_precision_test, rf_recall_test, rf_accuracy_test, rf_f1_test = get_metrics(model_rf_all, X_tests, y_tests)
# Out:
# Precision Score  : 0.8804120207463593
# Recall Score     : 0.8730670103092784
# Accuracy Score   : 0.8730670103092784
# F1 Score         : 0.8740174754515064
# ...
# Precision Score  : 0.7623157012394818
# Recall Score     : 0.7455012853470437
# Accuracy Score   : 0.7455012853470437
# F1 Score         : 0.749049147156744

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gb_all = GradientBoostingClassifier(random_state=83, max_depth=3)
model_gb_all.fit(X_trains, y_trains)

gb_precision_train, gb_recall_train, gb_accuracy_train, gb_f1_train = get_metrics(model_gb_all, X_trains, y_trains)
print('='*100)
gb_precision_test, gb_recall_test, gb_accuracy_test, gb_f1_test = get_metrics(model_gb_all, X_tests, y_tests)
# Out:
# Precision Score  : 0.9768144791342267
# Recall Score     : 0.9768041237113402
# Accuracy Score   : 0.9768041237113402
# F1 Score         : 0.9768067802240189
# ...
# Precision Score  : 0.7860106040888093
# Recall Score     : 0.7737789203084833
# Accuracy Score   : 0.7737789203084833
# F1 Score         : 0.7762983914169005

# %% [markdown]
# # 딥러닝 모델링

# %% [markdown]
# # 배치 정규화, es, rlrp

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from sklearn.metrics import accuracy_score, log_loss

# %%
from sklearn.utils import class_weight

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(X_trains.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_trains, tf.keras.utils.to_categorical(y_trains), epochs=1000, batch_size=10, verbose=1, 
          validation_data=(X_tests, tf.keras.utils.to_categorical(y_tests)), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_tests)
y_pred_classes = np.argmax(y_pred, axis=1)  # 클래스 예측값으로 변환
accuracy = accuracy_score(y_tests, y_pred_classes)
loss = log_loss(y_tests, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/1000
# 156/156 [==============================] - 1s 2ms/step - loss: 1.6963 - accuracy: 0.3969 - val_loss: 1.6225 - val_accuracy: 0.4704
# Epoch 2/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.5205 - accuracy: 0.4420 - val_loss: 1.5918 - val_accuracy: 0.3907
# Epoch 3/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4779 - accuracy: 0.4671 - val_loss: 1.5552 - val_accuracy: 0.4293
# Epoch 4/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4331 - accuracy: 0.4736 - val_loss: 1.4710 - val_accuracy: 0.4730
# Epoch 5/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4400 - accuracy: 0.4601 - val_loss: 1.5307 - val_accuracy: 0.4833
# Epoch 6/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4177 - accuracy: 0.4807 - val_loss: 2.0938 - val_accuracy: 0.2545
# Epoch 7/1000
# ...

# %% [markdown]
# # 배치 정규화, 데이터 증강(노이즈 추가), es, rlrp, adam

# %%
import tensorflow as tf
from sklearn.utils import class_weight

# 데이터 증강을 위한 함수 정의
def augment_data(features, labels):
    # 데이터 증강 로직을 구현
    # 여기서는 예시로 features를 조작하는 단순한 예시를 제공합니다.
    noise = np.random.normal(loc=0, scale=0.1, size=features.shape)
    augmented_features = features + noise
    return augmented_features, labels

y_trains_encoded = tf.keras.utils.to_categorical(y_trains)
y_tests_encoded = tf.keras.utils.to_categorical(y_tests)

# 데이터 증강을 적용한 모델 학습을 위한 데이터셋 생성
train_dataset = tf.data.Dataset.from_tensor_slices((X_trains, y_trains_encoded))
train_dataset = train_dataset.shuffle(buffer_size=1000)  # 데이터셋 섞기
train_dataset = train_dataset.map(augment_data)  # 데이터 증강 적용
train_dataset = train_dataset.batch(10)


# 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(X_trains.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(train_dataset, epochs=1000, batch_size=5, verbose=1, 
          validation_data=(X_tests, y_tests_encoded), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_tests)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_tests, y_pred_classes)
loss = log_loss(y_tests, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/1000
# 156/156 [==============================] - 1s 3ms/step - loss: 1.7115 - accuracy: 0.3924 - val_loss: 1.7669 - val_accuracy: 0.4499
# Epoch 2/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4888 - accuracy: 0.4491 - val_loss: 1.5115 - val_accuracy: 0.4499
# Epoch 3/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4431 - accuracy: 0.4755 - val_loss: 1.3757 - val_accuracy: 0.5116
# Epoch 4/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4108 - accuracy: 0.4652 - val_loss: 1.4082 - val_accuracy: 0.4884
# Epoch 5/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4107 - accuracy: 0.4665 - val_loss: 1.3979 - val_accuracy: 0.5064
# Epoch 6/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.3666 - accuracy: 0.4768 - val_loss: 1.3936 - val_accuracy: 0.4730
# Epoch 7/1000
# ...

# %% [markdown]
# # 배치 정규화, dropout, l1_l2 정규화, es, rlrp

# %%
from tensorflow.keras import regularizers

# 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(X_trains.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),  # Dropout 추가
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1/L2 정규화 추가
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),  # Dropout 추가
    tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1/L2 정규화 추가
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1/L2 정규화 추가
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_trains, tf.keras.utils.to_categorical(y_trains), epochs=1000, batch_size=10, verbose=1, 
          validation_data=(X_tests, tf.keras.utils.to_categorical(y_tests)), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_tests)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_tests, y_pred_classes)
loss = log_loss(y_tests, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/1000
# 156/156 [==============================] - 1s 3ms/step - loss: 25.8933 - accuracy: 0.2938 - val_loss: 19.6424 - val_accuracy: 0.4730
# Epoch 2/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 16.3025 - accuracy: 0.4098 - val_loss: 13.0996 - val_accuracy: 0.4576
# Epoch 3/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 10.7045 - accuracy: 0.4530 - val_loss: 8.5373 - val_accuracy: 0.4781
# Epoch 4/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 7.0563 - accuracy: 0.4497 - val_loss: 5.7320 - val_accuracy: 0.4653
# Epoch 5/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 4.8715 - accuracy: 0.4517 - val_loss: 4.1291 - val_accuracy: 0.4987
# Epoch 6/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 3.8543 - accuracy: 0.4568 - val_loss: 3.4927 - val_accuracy: 0.4833
# Epoch 7/1000
# ...

# %%
# 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(X_trains.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_trains, tf.keras.utils.to_categorical(y_trains), epochs=1000, batch_size=10, verbose=1, 
          validation_data=(X_tests, tf.keras.utils.to_categorical(y_tests)), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_tests)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_tests, y_pred_classes)
loss = log_loss(y_tests, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/1000
# 156/156 [==============================] - 1s 2ms/step - loss: 1.5975 - accuracy: 0.4356 - val_loss: 1.5319 - val_accuracy: 0.4370 - lr: 0.0010
# Epoch 2/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4483 - accuracy: 0.4839 - val_loss: 1.4880 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 3/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4106 - accuracy: 0.4871 - val_loss: 1.3459 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 4/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4105 - accuracy: 0.4787 - val_loss: 1.3779 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 5/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4004 - accuracy: 0.4774 - val_loss: 1.3585 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 6/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.3975 - accuracy: 0.4832 - val_loss: 1.4803 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 7/1000
# ...

# %%
from tensorflow.keras import regularizers
from sklearn.utils import resample

# 데이터 샘플링
X_train_resampled, y_train_resampled = resample(X_train, y_train, random_state=83)

# 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(X_train_resampled.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

# 모델 초기화
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_train_resampled, tf.keras.utils.to_categorical(y_train_resampled), epochs=1000, batch_size=10, verbose=1, 
          validation_data=(X_test, tf.keras.utils.to_categorical(y_test)), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_test, y_pred_classes)
loss = log_loss(y_test, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_41 (Dense)            (None, 16)                448
#
#  batch_normalization_32 (Bat  (None, 16)               64
#  chNormalization)
#
#  dense_42 (Dense)            (None, 32)                544
#
#  batch_normalization_33 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_43 (Dense)            (None, 7)                 231
#
# ...
# Total params: 1,415
# Trainable params: 1,319
# Non-trainable params: 96
# _________________________________________________________________
# Epoch 1/1000
# 156/156 [==============================] - 1s 2ms/step - loss: 1.8248 - accuracy: 0.3409 - val_loss: 2.0141 - val_accuracy: 0.3856 - lr: 0.0010
# Epoch 2/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4964 - accuracy: 0.4620 - val_loss: 1.6827 - val_accuracy: 0.4473 - lr: 0.0010
# Epoch 3/1000
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
es = EarlyStopping(monitor='val_loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_train, tf.keras.utils.to_categorical(y_train), epochs=1000, batch_size=10, verbose=1, 
          validation_data=(X_test, tf.keras.utils.to_categorical(y_test)), callbacks=[es, rlrp])

# 모델 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # 클래스 예측값으로 변환
accuracy = accuracy_score(y_test, y_pred_classes)
loss = log_loss(y_test, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/1000
# 156/156 [==============================] - 2s 3ms/step - loss: 1.7876 - accuracy: 0.3814 - val_loss: 1.7767 - val_accuracy: 0.3522 - lr: 0.0010
# Epoch 2/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.5173 - accuracy: 0.4485 - val_loss: 1.5094 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 3/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4525 - accuracy: 0.4678 - val_loss: 1.4687 - val_accuracy: 0.4267 - lr: 0.0010
# Epoch 4/1000
# 156/156 [==============================] - 0s 1ms/step - loss: 1.4346 - accuracy: 0.4768 - val_loss: 1.3938 - val_accuracy: 0.4602 - lr: 0.0010
# Epoch 5/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.4034 - accuracy: 0.4659 - val_loss: 1.4041 - val_accuracy: 0.4499 - lr: 0.0010
# Epoch 6/1000
# 156/156 [==============================] - 0s 2ms/step - loss: 1.3804 - accuracy: 0.4742 - val_loss: 1.4221 - val_accuracy: 0.4807 - lr: 0.0010
# Epoch 7/1000
# ...
