# %%
import pandas as pd

csv_path = '/Users/moonjeseong/Desktop/project/TeamProject1/JeseongMoon/Dataset/mulit_classification_data.csv'
df = pd.read_csv(csv_path)
print(f'{df.shape}')
df.head()
# Out:
# (1941, 34)
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  Maximum_of_Luminosity  Length_of_Conveyer  TypeOfSteel_A300  TypeOfSteel_A400  Steel_Plate_Thickness  Edges_Index  Empty_Index  Square_Index  Outside_X_Index  Edges_X_Index  Edges_Y_Index  Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  Orientation_Index  Luminosity_Index  SigmoidOfAreas  Pastry  Z_Scratch  K_Scatch  Stains  Dirtiness  Bumps  Other_Faults
# 0         42         50     270900     270944           267           17           44              24220                     76                    108                1687                 1                 0                     80       0.0498       0.2415        0.1818           0.0047         0.4706         1.0000                   1.0      2.4265       0.9031       1.6435             0.8182           -0.2913          0.5822       1          0         0       0          0      0             0
# 1        645        651    2538079    2538108           108           10           30              11397                     84                    123                1687                 1                 0                     80       0.7647       0.3793        0.2069           0.0036         0.6000         0.9667                   1.0      2.0334       0.7782       1.4624             0.7931           -0.1756          0.2984       1          0         0       0          0      0             0
# 2        829        835    1553913    1553931            71            8           19               7972                     99                    125                1623                 1                 0                    100       0.9710       0.3426        0.3333           0.0037         0.7500         0.9474                   1.0      1.8513       0.7782       1.2553             0.6667           -0.1228          0.2150       1          0         0       0          0      0             0
# 3        853        860     369370     369415           176           13           45              18996                     99                    126                1353                 0                 1                    290       0.7287       0.4413        0.1556           0.0052         0.5385         1.0000                   1.0      2.2455       0.8451       1.6532             0.8444           -0.1568          0.5212       1          0         0       0          0      0             0
# 4       1289       1306     498078     498335          2409           60          260             246930                     37                    126                1353                 0                 1                    185       0.0695       0.4486        0.0662           0.0126         0.2833         0.9885                   1.0      3.3818       1.2305       2.4099             0.9338           -0.1992          1.0000       1          0         0       0          0      0             0

# %%
pd.set_option('display.max_columns', None)

# %%
import numpy as np
import tensorflow
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
import sklearn
from sklearn.metrics import accuracy_score, log_loss

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

y = df[['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']]
X = df.iloc[:,:-7]

# %%
X.shape
# Out:
# (1941, 27)

# %%
X = X.rename(columns={'TypeOfSteel_A300': 'TypeOfSteel'})
X = X.drop(columns=['TypeOfSteel_A400'])
X.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  Maximum_of_Luminosity  Length_of_Conveyer  TypeOfSteel  Steel_Plate_Thickness  Edges_Index  Empty_Index  Square_Index  Outside_X_Index  Edges_X_Index  Edges_Y_Index  Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  Orientation_Index  Luminosity_Index  SigmoidOfAreas
# 0         42         50     270900     270944           267           17           44              24220                     76                    108                1687            1                     80       0.0498       0.2415        0.1818           0.0047         0.4706         1.0000                   1.0      2.4265       0.9031       1.6435             0.8182           -0.2913          0.5822
# 1        645        651    2538079    2538108           108           10           30              11397                     84                    123                1687            1                     80       0.7647       0.3793        0.2069           0.0036         0.6000         0.9667                   1.0      2.0334       0.7782       1.4624             0.7931           -0.1756          0.2984
# 2        829        835    1553913    1553931            71            8           19               7972                     99                    125                1623            1                    100       0.9710       0.3426        0.3333           0.0037         0.7500         0.9474                   1.0      1.8513       0.7782       1.2553             0.6667           -0.1228          0.2150
# 3        853        860     369370     369415           176           13           45              18996                     99                    126                1353            0                    290       0.7287       0.4413        0.1556           0.0052         0.5385         1.0000                   1.0      2.2455       0.8451       1.6532             0.8444           -0.1568          0.5212
# 4       1289       1306     498078     498335          2409           60          260             246930                     37                    126                1353            0                    185       0.0695       0.4486        0.0662           0.0126         0.2833         0.9885                   1.0      3.3818       1.2305       2.4099             0.9338           -0.1992          1.0000

# %%
X.TypeOfSteel.value_counts()
# Out:
# 0    1164
# 1     777
# Name: TypeOfSteel, dtype: int64

# %%
y["Type"] = y[['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']].idxmax(axis=1)
y = y.drop(columns=['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults'])
y.head()
# Out:
# /var/folders/jy/phdqtrzx3nb0kq5pycq5kz100000gn/T/ipykernel_11409/2028821799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Type"] = y[['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']].idxmax(axis=1)
#      Type
# 0  Pastry
# 1  Pastry
# 2  Pastry
# 3  Pastry
# 4  Pastry

# %%
y.Type.value_counts()
# Out:
# Other_Faults    673
# Bumps           402
# K_Scatch        391
# Z_Scratch       190
# Pastry          158
# Stains           72
# Dirtiness        55
# Name: Type, dtype: int64

# %%
print(X.shape, y.shape)
# Out:
# (1941, 26) (1941, 1)

# %%
y_dataframe = df.iloc[:,-7:]

# %%
y_list = []
for i in range(y_dataframe.shape[0]):
    if y_dataframe["Pastry"].values[i] == 1:
        y_list.append("Pastry")
    elif y_dataframe["Z_Scratch"].values[i] == 1:
        y_list.append("Z_Scratch")
    elif y_dataframe["K_Scatch"].values[i] == 1:
        y_list.append("K_Scatch")
    elif y_dataframe["Stains"].values[i] == 1:
        y_list.append("Stains")
    elif y_dataframe["Dirtiness"].values[i] == 1:
        y_list.append("Dirtiness")
    elif y_dataframe["Bumps"].values[i] == 1:
        y_list.append("Bumps")
    else:
        y_list.append("Other_Faults")

y_list = np.array(y_list)
y_list.shape
# Out:
# (1941,)

# %%
label = y['Type']
print(label.unique())
# Out:
# ['Pastry' 'Z_Scratch' 'K_Scatch' 'Stains' 'Dirtiness' 'Bumps'
#  'Other_Faults']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(label)
label_encoded = le.transform(label)
le_y = pd.DataFrame(label_encoded, columns=['label'])
y = le_y
print(y.value_counts())
# Out:
# label
# 3        673
# 0        402
# 2        391
# 6        190
# 4        158
# 5         72
# 1         55
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 83)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, )
# Out:
# (1552, 26) (389, 26) (1552, 1) (389, 1)

# %%
from sklearn import metrics
import numpy as np

def get_metrics(model, X, y):
    y_pred=model.predict(X)
    
    Precision    = metrics.precision_score (y, y_pred, average="weighted")
    Recall       = metrics.recall_score    (y, y_pred, average="weighted")
    Accuracy     = metrics.accuracy_score  (y, y_pred)
    F1           = metrics.f1_score        (y, y_pred, average="weighted")
    
    print(f'Precision Score  : {Precision}')
    print(f'Recall Score     : {Recall}')
    print(f'Accuracy Score   : {Accuracy}')
    print(f'F1 Score         : {F1}')
    return Precision, Recall, Accuracy, F1

# %%
from sklearn import metrics
import numpy as np

def get_metrics(model, X, y):
    y_pred=model.predict(X)
    
    Precision    = metrics.precision_score (y, y_pred, average="weighted")
    Recall       = metrics.recall_score    (y, y_pred, average="weighted")
    Accuracy     = metrics.accuracy_score  (y, y_pred)
    F1           = metrics.f1_score        (y, y_pred, average="weighted")
    
    print(f'Precision Score  : {Precision}')
    print(f'Recall Score     : {Recall}')
    print(f'Accuracy Score   : {Accuracy}')
    print(f'F1 Score         : {F1}')
    return Precision, Recall, Accuracy, F1

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf_all = RandomForestClassifier(random_state=83)
model_rf_all.fit(X_train, y_train)

rf_precision_train, rf_recall_train, rf_accuracy_train, rf_f1_train = get_metrics(model_rf_all, X_train, y_train)
print('='*100)
rf_precision_test, rf_recall_test, rf_accuracy_test, rf_f1_test = get_metrics(model_rf_all, X_test, y_test)
# Out:
# /var/folders/jy/phdqtrzx3nb0kq5pycq5kz100000gn/T/ipykernel_11409/3915369843.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_rf_all.fit(X_train, y_train)
# Precision Score  : 1.0
# Recall Score     : 1.0
# Accuracy Score   : 1.0
# F1 Score         : 1.0
# ====================================================================================================
# Precision Score  : 0.7992110315751305
# Recall Score     : 0.7866323907455013
# Accuracy Score   : 0.7866323907455013
# F1 Score         : 0.7892523019803969

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from sklearn.metrics import accuracy_score, log_loss

# %%
from sklearn.utils import class_weight

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(512, activation='LeakyReLU', input_shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(256, activation='LeakyReLU', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1, L2 정규화 적용
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(128, activation='LeakyReLU', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1, L2 정규화 적용
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(64, activation='LeakyReLU', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1, L2 정규화 적용
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(32, activation='LeakyReLU', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1, L2 정규화 적용
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(16, activation='LeakyReLU', kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),  # L1, L2 정규화 적용
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),  # 드롭아웃 추가
    tf.keras.layers.Dense(7, activation='softmax')
])


optimizer = tf.keras.optimizers.Adamax()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 학습 자동 중단 설정
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=40, mode='min')

# 모델 학습
model.fit(X_train, tf.keras.utils.to_categorical(y_train), epochs=100, batch_size=10, verbose=1, 
          validation_data=(X_test, tf.keras.utils.to_categorical(y_test)), callbacks=[rlrp])

# 모델 평가
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # 클래스 예측값으로 변환
accuracy = accuracy_score(y_test, y_pred_classes)
loss = log_loss(y_test, y_pred)
print(f'Accuracy: {accuracy}\nLog Loss: {loss}')
# Out:
# Epoch 1/100
# 156/156 [==============================] - 2s 4ms/step - loss: 78.6092 - accuracy: 0.3254 - val_loss: 65.0480 - val_accuracy: 0.4139 - lr: 0.0010
# Epoch 2/100
# 156/156 [==============================] - 0s 3ms/step - loss: 57.3113 - accuracy: 0.3969 - val_loss: 50.4590 - val_accuracy: 0.4344 - lr: 0.0010
# Epoch 3/100
# 156/156 [==============================] - 0s 3ms/step - loss: 45.4228 - accuracy: 0.4104 - val_loss: 40.6622 - val_accuracy: 0.4370 - lr: 0.0010
# Epoch 4/100
# 156/156 [==============================] - 0s 3ms/step - loss: 36.7697 - accuracy: 0.4233 - val_loss: 33.0306 - val_accuracy: 0.4704 - lr: 0.0010
# Epoch 5/100
# 156/156 [==============================] - 0s 3ms/step - loss: 29.8867 - accuracy: 0.4414 - val_loss: 26.7775 - val_accuracy: 0.4550 - lr: 0.0010
# Epoch 6/100
# 156/156 [==============================] - 0s 3ms/step - loss: 24.7672 - accuracy: 0.4562 - val_loss: 22.6594 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 7/100
# 156/156 [==============================] - 0s 3ms/step - loss: 21.0272 - accuracy: 0.4439 - val_loss: 19.3590 - val_accuracy: 0.4756 - lr: 0.0010
# Epoch 8/100
# 156/156 [==============================] - 0s 3ms/step - loss: 18.1110 - accuracy: 0.4323 - val_loss: 16.8690 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 9/100
# 156/156 [==============================] - 0s 3ms/step - loss: 16.1226 - accuracy: 0.4555 - val_loss: 15.1134 - val_accuracy: 0.4807 - lr: 0.0010
# Epoch 10/100
# 156/156 [==============================] - 0s 3ms/step - loss: 14.3652 - accuracy: 0.4581 - val_loss: 13.6077 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 11/100
# 156/156 [==============================] - 0s 3ms/step - loss: 13.0175 - accuracy: 0.4639 - val_loss: 12.2354 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 12/100
# 156/156 [==============================] - 0s 3ms/step - loss: 11.8669 - accuracy: 0.4394 - val_loss: 11.3382 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 13/100
# 156/156 [==============================] - 0s 3ms/step - loss: 10.8073 - accuracy: 0.4478 - val_loss: 10.2303 - val_accuracy: 0.4576 - lr: 0.0010
# Epoch 14/100
# 156/156 [==============================] - 0s 3ms/step - loss: 9.8152 - accuracy: 0.4601 - val_loss: 9.3739 - val_accuracy: 0.4499 - lr: 0.0010
# Epoch 15/100
# 156/156 [==============================] - 0s 3ms/step - loss: 9.0450 - accuracy: 0.4485 - val_loss: 8.7053 - val_accuracy: 0.4730 - lr: 0.0010
# Epoch 16/100
# 156/156 [==============================] - 0s 3ms/step - loss: 8.4126 - accuracy: 0.4665 - val_loss: 8.0229 - val_accuracy: 0.4499 - lr: 0.0010
# Epoch 17/100
# 156/156 [==============================] - 1s 3ms/step - loss: 7.7070 - accuracy: 0.4575 - val_loss: 7.3529 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 18/100
# 156/156 [==============================] - 0s 3ms/step - loss: 7.1676 - accuracy: 0.4633 - val_loss: 6.8214 - val_accuracy: 0.4961 - lr: 0.0010
# Epoch 19/100
# 156/156 [==============================] - 1s 4ms/step - loss: 6.5881 - accuracy: 0.4543 - val_loss: 6.3119 - val_accuracy: 0.4704 - lr: 0.0010
# Epoch 20/100
# 156/156 [==============================] - 1s 4ms/step - loss: 6.1336 - accuracy: 0.4626 - val_loss: 5.9075 - val_accuracy: 0.4807 - lr: 0.0010
# Epoch 21/100
# 156/156 [==============================] - 1s 3ms/step - loss: 5.8527 - accuracy: 0.4639 - val_loss: 5.5662 - val_accuracy: 0.4730 - lr: 0.0010
# Epoch 22/100
# 156/156 [==============================] - 1s 3ms/step - loss: 5.3675 - accuracy: 0.4626 - val_loss: 5.2354 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 23/100
# 156/156 [==============================] - 1s 4ms/step - loss: 4.9976 - accuracy: 0.4543 - val_loss: 4.8484 - val_accuracy: 0.4602 - lr: 0.0010
# Epoch 24/100
# 156/156 [==============================] - 1s 3ms/step - loss: 4.6582 - accuracy: 0.4639 - val_loss: 4.4753 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 25/100
# 156/156 [==============================] - 1s 3ms/step - loss: 4.4663 - accuracy: 0.4555 - val_loss: 4.2967 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 26/100
# 156/156 [==============================] - 1s 3ms/step - loss: 4.2771 - accuracy: 0.4710 - val_loss: 4.1125 - val_accuracy: 0.4447 - lr: 0.0010
# Epoch 27/100
# 156/156 [==============================] - 1s 3ms/step - loss: 3.9069 - accuracy: 0.4852 - val_loss: 3.7971 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 28/100
# 156/156 [==============================] - 1s 3ms/step - loss: 3.7911 - accuracy: 0.4652 - val_loss: 3.5425 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 29/100
# 156/156 [==============================] - 1s 4ms/step - loss: 3.5033 - accuracy: 0.4671 - val_loss: 3.4168 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 30/100
# 156/156 [==============================] - 1s 3ms/step - loss: 3.3218 - accuracy: 0.4575 - val_loss: 3.2541 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 31/100
# 156/156 [==============================] - 1s 3ms/step - loss: 3.1242 - accuracy: 0.4671 - val_loss: 2.9800 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 32/100
# 156/156 [==============================] - 0s 3ms/step - loss: 3.0162 - accuracy: 0.4729 - val_loss: 2.9688 - val_accuracy: 0.4884 - lr: 0.0010
# Epoch 33/100
# 156/156 [==============================] - 0s 3ms/step - loss: 2.9395 - accuracy: 0.4691 - val_loss: 2.8833 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 34/100
# 156/156 [==============================] - 1s 3ms/step - loss: 2.8572 - accuracy: 0.4646 - val_loss: 2.8606 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 35/100
# 156/156 [==============================] - 1s 4ms/step - loss: 2.7347 - accuracy: 0.4652 - val_loss: 2.6280 - val_accuracy: 0.4679 - lr: 0.0010
# Epoch 36/100
# 156/156 [==============================] - 1s 3ms/step - loss: 2.5856 - accuracy: 0.4723 - val_loss: 2.5675 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 37/100
# 156/156 [==============================] - 1s 3ms/step - loss: 2.4543 - accuracy: 0.4665 - val_loss: 2.4116 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 38/100
# 156/156 [==============================] - 0s 3ms/step - loss: 2.3184 - accuracy: 0.4768 - val_loss: 2.2795 - val_accuracy: 0.4961 - lr: 0.0010
# Epoch 39/100
# 156/156 [==============================] - 0s 3ms/step - loss: 2.3848 - accuracy: 0.4684 - val_loss: 2.4127 - val_accuracy: 0.4370 - lr: 0.0010
# Epoch 40/100
# 156/156 [==============================] - 1s 4ms/step - loss: 2.2706 - accuracy: 0.4768 - val_loss: 2.2134 - val_accuracy: 0.4576 - lr: 0.0010
# Epoch 41/100
# 156/156 [==============================] - 1s 3ms/step - loss: 2.1759 - accuracy: 0.4716 - val_loss: 2.0634 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 42/100
# 156/156 [==============================] - 1s 4ms/step - loss: 2.1063 - accuracy: 0.4774 - val_loss: 2.0642 - val_accuracy: 0.4987 - lr: 0.0010
# Epoch 43/100
# 156/156 [==============================] - 0s 3ms/step - loss: 2.0165 - accuracy: 0.4858 - val_loss: 2.0489 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 44/100
# 156/156 [==============================] - 0s 3ms/step - loss: 2.0473 - accuracy: 0.4639 - val_loss: 1.9580 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 45/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.9391 - accuracy: 0.4794 - val_loss: 1.9107 - val_accuracy: 0.4961 - lr: 0.0010
# Epoch 46/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.9684 - accuracy: 0.4620 - val_loss: 1.8331 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 47/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.8828 - accuracy: 0.4768 - val_loss: 1.8637 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 48/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.8421 - accuracy: 0.4697 - val_loss: 1.7578 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 49/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.8001 - accuracy: 0.4800 - val_loss: 1.8067 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 50/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.7752 - accuracy: 0.4774 - val_loss: 1.7484 - val_accuracy: 0.4987 - lr: 0.0010
# Epoch 51/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.8340 - accuracy: 0.4549 - val_loss: 1.7007 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 52/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.7729 - accuracy: 0.4794 - val_loss: 1.6887 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 53/100
# 156/156 [==============================] - 1s 3ms/step - loss: 1.7352 - accuracy: 0.4794 - val_loss: 1.7209 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 54/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.7270 - accuracy: 0.4923 - val_loss: 1.6951 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 55/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.7406 - accuracy: 0.4652 - val_loss: 1.6985 - val_accuracy: 0.5219 - lr: 0.0010
# Epoch 56/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.7218 - accuracy: 0.4890 - val_loss: 1.6432 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 57/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6513 - accuracy: 0.4820 - val_loss: 1.6325 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 58/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6770 - accuracy: 0.4878 - val_loss: 1.6096 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 59/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6835 - accuracy: 0.4800 - val_loss: 1.5926 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 60/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6383 - accuracy: 0.4897 - val_loss: 1.6330 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 61/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6306 - accuracy: 0.4878 - val_loss: 1.6231 - val_accuracy: 0.4781 - lr: 0.0010
# Epoch 62/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6216 - accuracy: 0.4878 - val_loss: 1.6043 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 63/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6471 - accuracy: 0.4942 - val_loss: 1.5801 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 64/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6228 - accuracy: 0.4787 - val_loss: 1.5937 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 65/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6213 - accuracy: 0.4916 - val_loss: 1.6042 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 66/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6489 - accuracy: 0.4787 - val_loss: 1.5905 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 67/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6475 - accuracy: 0.5045 - val_loss: 1.5778 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 68/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5836 - accuracy: 0.4858 - val_loss: 1.5794 - val_accuracy: 0.5193 - lr: 0.0010
# Epoch 69/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5778 - accuracy: 0.5013 - val_loss: 1.5747 - val_accuracy: 0.5141 - lr: 0.0010
# Epoch 70/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6081 - accuracy: 0.4871 - val_loss: 1.5984 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 71/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6190 - accuracy: 0.4826 - val_loss: 1.6459 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 72/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6570 - accuracy: 0.4781 - val_loss: 1.7005 - val_accuracy: 0.5141 - lr: 0.0010
# Epoch 73/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6279 - accuracy: 0.4890 - val_loss: 1.6622 - val_accuracy: 0.4807 - lr: 0.0010
# Epoch 74/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6050 - accuracy: 0.4839 - val_loss: 1.5328 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 75/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5674 - accuracy: 0.4897 - val_loss: 1.5552 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 76/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5795 - accuracy: 0.4768 - val_loss: 1.5230 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 77/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5622 - accuracy: 0.4742 - val_loss: 1.6442 - val_accuracy: 0.4653 - lr: 0.0010
# Epoch 78/100
# 156/156 [==============================] - 1s 3ms/step - loss: 1.6032 - accuracy: 0.4794 - val_loss: 1.5155 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 79/100
# 156/156 [==============================] - 1s 3ms/step - loss: 1.6018 - accuracy: 0.4916 - val_loss: 1.5691 - val_accuracy: 0.4833 - lr: 0.0010
# Epoch 80/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5928 - accuracy: 0.4845 - val_loss: 1.5282 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 81/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5515 - accuracy: 0.4839 - val_loss: 1.5826 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 82/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5737 - accuracy: 0.4884 - val_loss: 1.5723 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 83/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6162 - accuracy: 0.4807 - val_loss: 1.5657 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 84/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5981 - accuracy: 0.4723 - val_loss: 1.5726 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 85/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5922 - accuracy: 0.4865 - val_loss: 1.5651 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 86/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5660 - accuracy: 0.4878 - val_loss: 1.5189 - val_accuracy: 0.4987 - lr: 0.0010
# Epoch 87/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6241 - accuracy: 0.4794 - val_loss: 1.6380 - val_accuracy: 0.5141 - lr: 0.0010
# Epoch 88/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6148 - accuracy: 0.4807 - val_loss: 1.5445 - val_accuracy: 0.5013 - lr: 0.0010
# Epoch 89/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5684 - accuracy: 0.4755 - val_loss: 1.5679 - val_accuracy: 0.5141 - lr: 0.0010
# Epoch 90/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5765 - accuracy: 0.4955 - val_loss: 1.5435 - val_accuracy: 0.5193 - lr: 0.0010
# Epoch 91/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5741 - accuracy: 0.4968 - val_loss: 1.5176 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 92/100
# 156/156 [==============================] - 1s 3ms/step - loss: 1.5562 - accuracy: 0.4903 - val_loss: 1.5291 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 93/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5848 - accuracy: 0.4845 - val_loss: 1.6114 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 94/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6468 - accuracy: 0.4903 - val_loss: 1.6360 - val_accuracy: 0.4910 - lr: 0.0010
# Epoch 95/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6148 - accuracy: 0.4852 - val_loss: 1.6051 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 96/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.6110 - accuracy: 0.4865 - val_loss: 1.5193 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 97/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5487 - accuracy: 0.4923 - val_loss: 1.5485 - val_accuracy: 0.4781 - lr: 0.0010
# Epoch 98/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5533 - accuracy: 0.4832 - val_loss: 1.5075 - val_accuracy: 0.5064 - lr: 0.0010
# Epoch 99/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5284 - accuracy: 0.5000 - val_loss: 1.4991 - val_accuracy: 0.5141 - lr: 0.0010
# Epoch 100/100
# 156/156 [==============================] - 0s 3ms/step - loss: 1.5565 - accuracy: 0.4929 - val_loss: 1.5184 - val_accuracy: 0.5167 - lr: 0.0010
# 13/13 [==============================] - 0s 1ms/step
# Accuracy: 0.5167095115681234
# Log Loss: 1.3625762826578849
