# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
def load_dataset(csv_path, TRAIN_RATIO=0.8):
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    # 데이터셋 로드
    df = pd.read_csv(csv_path)
    
    # 성별 원핫 인코딩
    df=pd.get_dummies(df,columns=['Sex'])
    
    # 학습 데이터 분리
    X = df.drop('Rings', axis=1)
    y = df['Rings']
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=TRAIN_RATIO, random_state = 83)
    
    return X_train, X_test, y_train, y_test

csv_path = '../colabo/Data/Regression_data.csv'
X_train, X_test, y_train, y_test = load_dataset(csv_path)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3341, 10) (836, 10) (3341,) (836,)

# %%
# 전복 전체 무게가 살 + 내장 + 껍질보다 적게 나가는 경우는 말이 안됨
body = X_train['Whole weight'] - (X_train['Shucked weight'] + X_train['Viscera weight'] + X_train['Shell weight'])
X_train['body'] = body

index = X_train[X_train['body'] < 0].index

body = X_test['Whole weight'] - (X_test['Shucked weight'] + X_test['Viscera weight'] + X_test['Shell weight'])
X_test['body'] = body

index2 = X_test[X_test['body'] < 0].index

print(index.shape, index2.shape)
# Out:
# (118,) (37,)

# %%
X_train.drop(index, axis=0, inplace=True)
X_test.drop(index2, axis=0, inplace=True)
y_train.drop(index, axis=0, inplace=True)
y_test.drop(index2, axis=0, inplace=True)

# %%
# Lenth가 Diameter보다 크다.
# --> Length는 장축의 길이, Diameter는 단축의 지름으로 판단됨
# 타원(전복 껍데기)의 둘레 및 넓이 구해보기
# Length가 Diameter보다 큰게 딱 1개 있음 --> 그럴 수도 있으니 삭제는 안함
index3 = X_train[X_train['Diameter'] > X_train['Length']].index
index4 = X_test[X_test['Diameter'] > X_test['Length']].index
print(index3.shape, index4.shape)
# Out:
# (1,) (0,)

# %%
import numpy as np

# train 껍질의 넓이 ( a * b * π)
area = 0.5 * X_train['Length'] * 0.5 * X_train['Diameter'] * np.pi
X_train['Area'] = area

# test 껍질의 넓이 
area2 = 0.5 * X_test['Length'] * 0.5 * X_test['Diameter'] * np.pi
X_test['Area'] = area2

# %%
# train 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter = np.pi * np.sqrt(0.5 * ((X_train['Length'] ** 2) + (X_train['Diameter'] ** 2)))
X_train['Perimeter'] = perimeter

# test 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter2 = np.pi * np.sqrt(0.5 * ((X_test['Length'] ** 2) + (X_test['Diameter'] ** 2)))
X_test['Perimeter'] = perimeter2

X_train.head()
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 461    0.585     0.465   0.170        0.9915          0.3865          0.2240
# 2835   0.570     0.420   0.140        0.8745          0.4160          0.1650
# 1378   0.620     0.500   0.150        1.2930          0.5960          0.3135
# 2569   0.460     0.345   0.115        0.4215          0.1895          0.1020
# 369    0.690     0.560   0.215        1.7190          0.6800          0.2990
#
#       Shell weight  Sex_F  Sex_I  Sex_M    body      Area  Perimeter
# 461          0.265      1      0      0  0.1160  0.213648   1.660072
# 2835         0.250      0      0      1  0.0435  0.188024   1.572837
# 1378         0.354      1      0      0  0.0295  0.243473   1.769361
# 2569         0.111      0      1      0  0.0190  0.124643   1.277329
# 369          0.470      1      0      0  0.2700  0.303478   1.974085

# %%
# 타겟값과 각 변수들 간의 상관관계
co = X_train.corrwith(y_train)

# 상관계수를 내림차순으로 정리
print(co.sort_values(ascending=False))

# 절대값
co_abs = abs(co)
# Out:
# Shell weight      0.619796
# Diameter          0.559512
# Perimeter         0.548978
# Length            0.539317
# Height            0.534439
# body              0.533203
# Area              0.532949
# Whole weight      0.525487
# Viscera weight    0.489945
# Shucked weight    0.403014
# Sex_F             0.242466
# Sex_M             0.178722
# Sex_I            -0.431255
# dtype: float64

# %%
columns = ['Shell weight', 'Diameter', 'Length', 'Height', 'body', 'Viscera weight', 'Shucked weight', 'Whole weight', 'Sex_F', 'Sex_M', 'Sex_I']
X_train_2 = X_train[columns]
X_test_2 = X_test[columns]
X_train_2.head()
# Out:
#       Shell weight  Diameter  Length  Height    body  Viscera weight  \
# 461          0.265     0.465   0.585   0.170  0.1160          0.2240
# 2835         0.250     0.420   0.570   0.140  0.0435          0.1650
# 1378         0.354     0.500   0.620   0.150  0.0295          0.3135
# 2569         0.111     0.345   0.460   0.115  0.0190          0.1020
# 369          0.470     0.560   0.690   0.215  0.2700          0.2990
#
#       Shucked weight  Whole weight  Sex_F  Sex_M  Sex_I
# 461           0.3865        0.9915      1      0      0
# 2835          0.4160        0.8745      0      1      0
# 1378          0.5960        1.2930      1      0      0
# 2569          0.1895        0.4215      0      0      1
# 369           0.6800        1.7190      1      0      0

# %%
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 피처 선택
scaling_features = columns[:-3]  # 원핫인코딩되지 않은 연속형 또는 순서형 변수들

# 스케일링
scaler = MinMaxScaler()
X_train_scaled = X_train_2.copy()  # 원본 데이터 복사
X_test_scaled = X_test_2.copy()    # 원본 데이터 복사
X_train_scaled[scaling_features] = scaler.fit_transform(X_train_2[scaling_features])
X_test_scaled[scaling_features] = scaler.transform(X_test_2[scaling_features])

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

# %%
# 사용자 정의 평가 지표 클래스
import tensorflow as tf

class EvalAccuracy(tf.keras.metrics.Metric): # TensorFlow의 Metric 클래스를 상속 받음

    def __init__(self, name="eval_accuracy", **kwargs): # 부모 클래스의 __init__() 메소드를 호출하여 필요한 초기화를 수행
        super(EvalAccuracy, self).__init__(name=name, **kwargs)
        self.correct = self.add_weight(name="ctp", initializer="zeros")
        # add_weight() 메소드를 사용하여 평가 지표를 계산하는데 필요한 변수를 생성(각 배치에서의 평가 결과를 누적하기 위해)
        # add_weight() 는 텐서플로우 Layer 클래스의 메서드(새로운 가중치를 추가하는 기능, 여기서는 평가 지표를 계산하는 데 사용되는 일종의 내부 변수를 의미)
        # 이 구문이 실행되면, EvalAccuracy 인스턴스는 새로운 가중치를 추가하고 그 가중치를 self.correct에 저장한다.
        # 이 self.correct는 update_state() 메서드에서 업데이트되며, '현재까지 처리한 모든 배치에 대한 평가 지표의 평균을 저장'한다.

    def update_state(self, y_true, y_predict, sample_weight=None):
        value = tf.abs((y_predict - y_true) / y_true)
        self.correct.assign(tf.reduce_mean(value)) # 오차율을 계산해서 correct 변수에 누적한 후, assign() 메소드를 사용하여 correct 변수의 값을 업데이트

    def result(self):
        return 1 - self.correct

    def reset_states(self):
        # 에포크마다 평가 지표 초기화
        self.correct.assign(0.)

# %%
# 베이스모델
import numpy as np

def Base_Model(LEARNING_RATE=0.01):
    
    np.random.seed(42)
    tf.random.set_seed(42)
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')
    
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=512, activation='relu', input_shape=(len(X_train_2.keys()),)),
        tf.keras.layers.Dense(units=256, activation='relu'),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=256, activation='relu'),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=1)
    ])
    
    # 옵티마이저와 손실 함수 설정
    optimizer = tf.keras.optimizers.Adam(
                                        learning_rate=0.01,
                                        beta_1=0.9,
                                        beta_2=0.99,
                                        epsilon=1e-08
                                        )

    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=[EvalAccuracy()])
    
    return model

model = Base_Model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 512)               6144
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 256)               16640
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 236,481
# Trainable params: 236,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 자동 중단 설정
es = EarlyStopping(monitor='loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=40, mode='min')

# %%
# 하이퍼파라미터 세팅
LEARNING_RATE = 0.01
EPOCHS = 200
MB_SIZE = 5000
REPORT = 1
TRAIN_RATIO = 0.8

np.random.seed(42)
tf.random.set_seed(42)

# 모델 학습
history = model.fit(
  X_train_scaled, y_train,
  batch_size=MB_SIZE,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS,
  callbacks=[es, rlrp]
  )
# Out:
# Epoch 1/200
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 1/1 [==============================] - 0s 374ms/step - loss: 2.8029 - eval_accuracy: 0.8801 - val_loss: 4.7336 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 2/200
# 1/1 [==============================] - 0s 71ms/step - loss: 2.8013 - eval_accuracy: 0.8803 - val_loss: 4.7141 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 3/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.8069 - eval_accuracy: 0.8802 - val_loss: 4.7432 - val_eval_accuracy: 0.8542 - lr: 4.0000e-04
# Epoch 4/200
# 1/1 [==============================] - ETA: 0s - loss: 2.8034 - eval_accuracy: 0.8795
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 1/1 [==============================] - 0s 68ms/step - loss: 2.8034 - eval_accuracy: 0.8795 - val_loss: 4.7226 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 5/200
# 1/1 [==============================] - 0s 72ms/step - loss: 2.7999 - eval_accuracy: 0.8806 - val_loss: 4.6944 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 6/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.8040 - eval_accuracy: 0.8806 - val_loss: 4.7423 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 7/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.8021 - eval_accuracy: 0.8797 - val_loss: 4.7101 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 8/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.8006 - eval_accuracy: 0.8803 - val_loss: 4.7198 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 9/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.8002 - eval_accuracy: 0.8803 - val_loss: 4.7498 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 10/200
# 1/1 [==============================] - 0s 53ms/step - loss: 2.8008 - eval_accuracy: 0.8797 - val_loss: 4.7029 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 11/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.8050 - eval_accuracy: 0.8803 - val_loss: 4.7394 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 12/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7981 - eval_accuracy: 0.8804 - val_loss: 4.7472 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 13/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.8050 - eval_accuracy: 0.8801 - val_loss: 4.7052 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 14/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.8130 - eval_accuracy: 0.8802 - val_loss: 4.7379 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 15/200
# 1/1 [==============================] - 0s 71ms/step - loss: 2.8010 - eval_accuracy: 0.8798 - val_loss: 4.7464 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 16/200
# 1/1 [==============================] - 0s 71ms/step - loss: 2.8145 - eval_accuracy: 0.8799 - val_loss: 4.7113 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 17/200
# 1/1 [==============================] - 0s 68ms/step - loss: 2.8005 - eval_accuracy: 0.8807 - val_loss: 4.7216 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 18/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.8107 - eval_accuracy: 0.8798 - val_loss: 4.7562 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 19/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.8005 - eval_accuracy: 0.8795 - val_loss: 4.7187 - val_eval_accuracy: 0.8563 - lr: 4.0000e-04
# Epoch 20/200
# 1/1 [==============================] - 0s 67ms/step - loss: 2.8042 - eval_accuracy: 0.8809 - val_loss: 4.6936 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 21/200
# 1/1 [==============================] - 0s 69ms/step - loss: 2.8051 - eval_accuracy: 0.8804 - val_loss: 4.7604 - val_eval_accuracy: 0.8533 - lr: 4.0000e-04
# Epoch 22/200
# 1/1 [==============================] - 0s 70ms/step - loss: 2.8025 - eval_accuracy: 0.8790 - val_loss: 4.7298 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 23/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.8078 - eval_accuracy: 0.8805 - val_loss: 4.6992 - val_eval_accuracy: 0.8561 - lr: 4.0000e-04
# Epoch 24/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.8043 - eval_accuracy: 0.8811 - val_loss: 4.7528 - val_eval_accuracy: 0.8535 - lr: 4.0000e-04
# Epoch 25/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.8040 - eval_accuracy: 0.8791 - val_loss: 4.7379 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 26/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7979 - eval_accuracy: 0.8799 - val_loss: 4.6989 - val_eval_accuracy: 0.8566 - lr: 4.0000e-04
# Epoch 27/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.8016 - eval_accuracy: 0.8812 - val_loss: 4.7370 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 28/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7968 - eval_accuracy: 0.8801 - val_loss: 4.7789 - val_eval_accuracy: 0.8532 - lr: 4.0000e-04
# Epoch 29/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7994 - eval_accuracy: 0.8791 - val_loss: 4.7228 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 30/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7983 - eval_accuracy: 0.8808 - val_loss: 4.7111 - val_eval_accuracy: 0.8560 - lr: 4.0000e-04
# Epoch 31/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7954 - eval_accuracy: 0.8809 - val_loss: 4.7557 - val_eval_accuracy: 0.8538 - lr: 4.0000e-04
# Epoch 32/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7981 - eval_accuracy: 0.8793 - val_loss: 4.7242 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 33/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7979 - eval_accuracy: 0.8801 - val_loss: 4.7124 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 34/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7939 - eval_accuracy: 0.8810 - val_loss: 4.7505 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 35/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7943 - eval_accuracy: 0.8801 - val_loss: 4.7497 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 36/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7964 - eval_accuracy: 0.8798 - val_loss: 4.7412 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 37/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7929 - eval_accuracy: 0.8808 - val_loss: 4.7361 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 38/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7970 - eval_accuracy: 0.8809 - val_loss: 4.7247 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 39/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.8003 - eval_accuracy: 0.8801 - val_loss: 4.7455 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 40/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7936 - eval_accuracy: 0.8796 - val_loss: 4.7437 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 41/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.8088 - eval_accuracy: 0.8800 - val_loss: 4.7140 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 42/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7938 - eval_accuracy: 0.8808 - val_loss: 4.7350 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 43/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7986 - eval_accuracy: 0.8798 - val_loss: 4.7597 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 44/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7979 - eval_accuracy: 0.8798 - val_loss: 4.7137 - val_eval_accuracy: 0.8564 - lr: 4.0000e-04
# Epoch 45/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7943 - eval_accuracy: 0.8814 - val_loss: 4.7186 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 46/200
# 1/1 [==============================] - 0s 71ms/step - loss: 2.7946 - eval_accuracy: 0.8806 - val_loss: 4.7934 - val_eval_accuracy: 0.8532 - lr: 4.0000e-04
# Epoch 47/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.7948 - eval_accuracy: 0.8792 - val_loss: 4.7392 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 48/200
# 1/1 [==============================] - 0s 67ms/step - loss: 2.7913 - eval_accuracy: 0.8807 - val_loss: 4.7202 - val_eval_accuracy: 0.8560 - lr: 4.0000e-04
# Epoch 49/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7922 - eval_accuracy: 0.8811 - val_loss: 4.7623 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 50/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.7920 - eval_accuracy: 0.8798 - val_loss: 4.7488 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 51/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7891 - eval_accuracy: 0.8800 - val_loss: 4.7289 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 52/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7929 - eval_accuracy: 0.8810 - val_loss: 4.7444 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 53/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7894 - eval_accuracy: 0.8804 - val_loss: 4.7671 - val_eval_accuracy: 0.8535 - lr: 4.0000e-04
# Epoch 54/200
# 1/1 [==============================] - 0s 70ms/step - loss: 2.7922 - eval_accuracy: 0.8794 - val_loss: 4.7342 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 55/200
# 1/1 [==============================] - 0s 67ms/step - loss: 2.7925 - eval_accuracy: 0.8806 - val_loss: 4.7048 - val_eval_accuracy: 0.8562 - lr: 4.0000e-04
# Epoch 56/200
# 1/1 [==============================] - 0s 68ms/step - loss: 2.7918 - eval_accuracy: 0.8812 - val_loss: 4.7637 - val_eval_accuracy: 0.8539 - lr: 4.0000e-04
# Epoch 57/200
# 1/1 [==============================] - 0s 78ms/step - loss: 2.7894 - eval_accuracy: 0.8797 - val_loss: 4.7595 - val_eval_accuracy: 0.8539 - lr: 4.0000e-04
# Epoch 58/200
# 1/1 [==============================] - 0s 72ms/step - loss: 2.7881 - eval_accuracy: 0.8799 - val_loss: 4.7255 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 59/200
# 1/1 [==============================] - 0s 78ms/step - loss: 2.7900 - eval_accuracy: 0.8812 - val_loss: 4.7306 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 60/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7877 - eval_accuracy: 0.8807 - val_loss: 4.7657 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 61/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7897 - eval_accuracy: 0.8797 - val_loss: 4.7313 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 62/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7914 - eval_accuracy: 0.8804 - val_loss: 4.7340 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 63/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7864 - eval_accuracy: 0.8807 - val_loss: 4.7775 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 64/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.8030 - eval_accuracy: 0.8798 - val_loss: 4.7069 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 65/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7935 - eval_accuracy: 0.8808 - val_loss: 4.7182 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 66/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7908 - eval_accuracy: 0.8807 - val_loss: 4.7587 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 67/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7985 - eval_accuracy: 0.8798 - val_loss: 4.7285 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 68/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7879 - eval_accuracy: 0.8807 - val_loss: 4.7262 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 69/200
# 1/1 [==============================] - 0s 85ms/step - loss: 2.7905 - eval_accuracy: 0.8805 - val_loss: 4.7659 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 70/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7897 - eval_accuracy: 0.8798 - val_loss: 4.7389 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 71/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7879 - eval_accuracy: 0.8807 - val_loss: 4.7248 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 72/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7907 - eval_accuracy: 0.8809 - val_loss: 4.7788 - val_eval_accuracy: 0.8537 - lr: 4.0000e-04
# Epoch 73/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7867 - eval_accuracy: 0.8798 - val_loss: 4.7610 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 74/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7839 - eval_accuracy: 0.8804 - val_loss: 4.7236 - val_eval_accuracy: 0.8561 - lr: 4.0000e-04
# Epoch 75/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7880 - eval_accuracy: 0.8814 - val_loss: 4.7320 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 76/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7845 - eval_accuracy: 0.8805 - val_loss: 4.7668 - val_eval_accuracy: 0.8539 - lr: 4.0000e-04
# Epoch 77/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7876 - eval_accuracy: 0.8795 - val_loss: 4.7286 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 78/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.7836 - eval_accuracy: 0.8807 - val_loss: 4.7343 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 79/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7854 - eval_accuracy: 0.8809 - val_loss: 4.7568 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 80/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7844 - eval_accuracy: 0.8802 - val_loss: 4.7555 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 81/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7812 - eval_accuracy: 0.8806 - val_loss: 4.7439 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 82/200
# 1/1 [==============================] - 0s 66ms/step - loss: 2.7864 - eval_accuracy: 0.8809 - val_loss: 4.7463 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 83/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7878 - eval_accuracy: 0.8804 - val_loss: 4.7678 - val_eval_accuracy: 0.8539 - lr: 4.0000e-04
# Epoch 84/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7838 - eval_accuracy: 0.8798 - val_loss: 4.7407 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 85/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7842 - eval_accuracy: 0.8808 - val_loss: 4.7247 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 86/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7842 - eval_accuracy: 0.8810 - val_loss: 4.7702 - val_eval_accuracy: 0.8538 - lr: 4.0000e-04
# Epoch 87/200
# 1/1 [==============================] - 0s 69ms/step - loss: 2.7836 - eval_accuracy: 0.8797 - val_loss: 4.7648 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 88/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.7865 - eval_accuracy: 0.8800 - val_loss: 4.7070 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 89/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7932 - eval_accuracy: 0.8814 - val_loss: 4.7598 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 90/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7813 - eval_accuracy: 0.8803 - val_loss: 4.7759 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 91/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7924 - eval_accuracy: 0.8799 - val_loss: 4.7242 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 92/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.7883 - eval_accuracy: 0.8811 - val_loss: 4.7477 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 93/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7849 - eval_accuracy: 0.8804 - val_loss: 4.7967 - val_eval_accuracy: 0.8536 - lr: 4.0000e-04
# Epoch 94/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.7928 - eval_accuracy: 0.8794 - val_loss: 4.7312 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 95/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7820 - eval_accuracy: 0.8812 - val_loss: 4.7261 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 96/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7837 - eval_accuracy: 0.8813 - val_loss: 4.8043 - val_eval_accuracy: 0.8536 - lr: 4.0000e-04
# Epoch 97/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.7897 - eval_accuracy: 0.8795 - val_loss: 4.7632 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 98/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7793 - eval_accuracy: 0.8805 - val_loss: 4.7257 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 99/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7816 - eval_accuracy: 0.8814 - val_loss: 4.7588 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 100/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7856 - eval_accuracy: 0.8801 - val_loss: 4.7606 - val_eval_accuracy: 0.8538 - lr: 4.0000e-04
# Epoch 101/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7800 - eval_accuracy: 0.8799 - val_loss: 4.7300 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 102/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7794 - eval_accuracy: 0.8810 - val_loss: 4.7487 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 103/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7857 - eval_accuracy: 0.8809 - val_loss: 4.7473 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 104/200
# 1/1 [==============================] - 0s 87ms/step - loss: 2.7803 - eval_accuracy: 0.8805 - val_loss: 4.7271 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 105/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7853 - eval_accuracy: 0.8805 - val_loss: 4.7547 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 106/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7808 - eval_accuracy: 0.8805 - val_loss: 4.7558 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 107/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7798 - eval_accuracy: 0.8805 - val_loss: 4.7549 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 108/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7860 - eval_accuracy: 0.8804 - val_loss: 4.7773 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 109/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7791 - eval_accuracy: 0.8802 - val_loss: 4.7741 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 110/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7887 - eval_accuracy: 0.8805 - val_loss: 4.7238 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 111/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7825 - eval_accuracy: 0.8813 - val_loss: 4.7544 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 112/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.7820 - eval_accuracy: 0.8801 - val_loss: 4.7770 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 113/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7853 - eval_accuracy: 0.8797 - val_loss: 4.7296 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 114/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7788 - eval_accuracy: 0.8812 - val_loss: 4.7416 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 115/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.7771 - eval_accuracy: 0.8808 - val_loss: 4.7978 - val_eval_accuracy: 0.8533 - lr: 4.0000e-04
# Epoch 116/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7842 - eval_accuracy: 0.8795 - val_loss: 4.7507 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 117/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7728 - eval_accuracy: 0.8811 - val_loss: 4.7384 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 118/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.7803 - eval_accuracy: 0.8814 - val_loss: 4.7873 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 119/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.7776 - eval_accuracy: 0.8800 - val_loss: 4.7723 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 120/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7747 - eval_accuracy: 0.8804 - val_loss: 4.7303 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 121/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7821 - eval_accuracy: 0.8815 - val_loss: 4.7723 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 122/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7748 - eval_accuracy: 0.8806 - val_loss: 4.7871 - val_eval_accuracy: 0.8537 - lr: 4.0000e-04
# Epoch 123/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7743 - eval_accuracy: 0.8800 - val_loss: 4.7439 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 124/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7800 - eval_accuracy: 0.8809 - val_loss: 4.7493 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 125/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7756 - eval_accuracy: 0.8809 - val_loss: 4.7893 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 126/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7824 - eval_accuracy: 0.8801 - val_loss: 4.7421 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 127/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7759 - eval_accuracy: 0.8808 - val_loss: 4.7512 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 128/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7752 - eval_accuracy: 0.8811 - val_loss: 4.7819 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 129/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7833 - eval_accuracy: 0.8804 - val_loss: 4.7647 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 130/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7729 - eval_accuracy: 0.8808 - val_loss: 4.7459 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 131/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7745 - eval_accuracy: 0.8808 - val_loss: 4.7686 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 132/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7754 - eval_accuracy: 0.8805 - val_loss: 4.7612 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 133/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7711 - eval_accuracy: 0.8807 - val_loss: 4.7613 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 134/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7708 - eval_accuracy: 0.8808 - val_loss: 4.7715 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 135/200
# 1/1 [==============================] - 0s 89ms/step - loss: 2.7739 - eval_accuracy: 0.8805 - val_loss: 4.7593 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 136/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7702 - eval_accuracy: 0.8808 - val_loss: 4.7586 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 137/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7704 - eval_accuracy: 0.8809 - val_loss: 4.7689 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 138/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7729 - eval_accuracy: 0.8806 - val_loss: 4.7598 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 139/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7724 - eval_accuracy: 0.8808 - val_loss: 4.7694 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 140/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7681 - eval_accuracy: 0.8807 - val_loss: 4.7741 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 141/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7712 - eval_accuracy: 0.8807 - val_loss: 4.7545 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 142/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7722 - eval_accuracy: 0.8811 - val_loss: 4.7753 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 143/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7684 - eval_accuracy: 0.8806 - val_loss: 4.7736 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 144/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7707 - eval_accuracy: 0.8807 - val_loss: 4.7438 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 145/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7720 - eval_accuracy: 0.8811 - val_loss: 4.7713 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 146/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7682 - eval_accuracy: 0.8806 - val_loss: 4.7689 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 147/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7709 - eval_accuracy: 0.8807 - val_loss: 4.7485 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 148/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7717 - eval_accuracy: 0.8810 - val_loss: 4.7734 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 149/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.7689 - eval_accuracy: 0.8802 - val_loss: 4.7730 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 150/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7730 - eval_accuracy: 0.8805 - val_loss: 4.7462 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 151/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7702 - eval_accuracy: 0.8813 - val_loss: 4.7739 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 152/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7668 - eval_accuracy: 0.8806 - val_loss: 4.7854 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 153/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7720 - eval_accuracy: 0.8803 - val_loss: 4.7408 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 154/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7702 - eval_accuracy: 0.8813 - val_loss: 4.7649 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 155/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7660 - eval_accuracy: 0.8809 - val_loss: 4.7825 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 156/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7657 - eval_accuracy: 0.8805 - val_loss: 4.7699 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 157/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7648 - eval_accuracy: 0.8810 - val_loss: 4.7769 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 158/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7691 - eval_accuracy: 0.8808 - val_loss: 4.7649 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 159/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7740 - eval_accuracy: 0.8806 - val_loss: 4.7691 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 160/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7659 - eval_accuracy: 0.8806 - val_loss: 4.7742 - val_eval_accuracy: 0.8555 - lr: 4.0000e-04
# Epoch 161/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7809 - eval_accuracy: 0.8809 - val_loss: 4.7554 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 162/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7646 - eval_accuracy: 0.8813 - val_loss: 4.7582 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 163/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.7723 - eval_accuracy: 0.8803 - val_loss: 4.7795 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 164/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.7699 - eval_accuracy: 0.8803 - val_loss: 4.7445 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 165/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7686 - eval_accuracy: 0.8815 - val_loss: 4.7738 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 166/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7676 - eval_accuracy: 0.8807 - val_loss: 4.8151 - val_eval_accuracy: 0.8533 - lr: 4.0000e-04
# Epoch 167/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7676 - eval_accuracy: 0.8799 - val_loss: 4.7691 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 168/200
# 1/1 [==============================] - 0s 88ms/step - loss: 2.7671 - eval_accuracy: 0.8814 - val_loss: 4.7556 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 169/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7665 - eval_accuracy: 0.8814 - val_loss: 4.8041 - val_eval_accuracy: 0.8533 - lr: 4.0000e-04
# Epoch 170/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7669 - eval_accuracy: 0.8798 - val_loss: 4.7697 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 171/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7618 - eval_accuracy: 0.8808 - val_loss: 4.7415 - val_eval_accuracy: 0.8560 - lr: 4.0000e-04
# Epoch 172/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7669 - eval_accuracy: 0.8817 - val_loss: 4.7772 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 173/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7642 - eval_accuracy: 0.8804 - val_loss: 4.8016 - val_eval_accuracy: 0.8536 - lr: 4.0000e-04
# Epoch 174/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7652 - eval_accuracy: 0.8800 - val_loss: 4.7581 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 175/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7629 - eval_accuracy: 0.8816 - val_loss: 4.7767 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 176/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7629 - eval_accuracy: 0.8813 - val_loss: 4.8198 - val_eval_accuracy: 0.8535 - lr: 4.0000e-04
# Epoch 177/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7660 - eval_accuracy: 0.8801 - val_loss: 4.7692 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 178/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7609 - eval_accuracy: 0.8814 - val_loss: 4.7553 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 179/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7624 - eval_accuracy: 0.8813 - val_loss: 4.7833 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 180/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7610 - eval_accuracy: 0.8801 - val_loss: 4.7705 - val_eval_accuracy: 0.8542 - lr: 4.0000e-04
# Epoch 181/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7614 - eval_accuracy: 0.8804 - val_loss: 4.7573 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 182/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7631 - eval_accuracy: 0.8813 - val_loss: 4.7633 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 183/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7598 - eval_accuracy: 0.8813 - val_loss: 4.7870 - val_eval_accuracy: 0.8538 - lr: 4.0000e-04
# Epoch 184/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7674 - eval_accuracy: 0.8805 - val_loss: 4.7907 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 185/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7603 - eval_accuracy: 0.8805 - val_loss: 4.7717 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 186/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.7636 - eval_accuracy: 0.8814 - val_loss: 4.7529 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 187/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7657 - eval_accuracy: 0.8809 - val_loss: 4.8145 - val_eval_accuracy: 0.8534 - lr: 4.0000e-04
# Epoch 188/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7615 - eval_accuracy: 0.8801 - val_loss: 4.7676 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 189/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7602 - eval_accuracy: 0.8813 - val_loss: 4.7584 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 190/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7590 - eval_accuracy: 0.8817 - val_loss: 4.8041 - val_eval_accuracy: 0.8535 - lr: 4.0000e-04
# Epoch 191/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7604 - eval_accuracy: 0.8802 - val_loss: 4.7869 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 192/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7571 - eval_accuracy: 0.8807 - val_loss: 4.7475 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 193/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7647 - eval_accuracy: 0.8817 - val_loss: 4.7804 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 194/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.7600 - eval_accuracy: 0.8806 - val_loss: 4.7911 - val_eval_accuracy: 0.8541 - lr: 4.0000e-04
# Epoch 195/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.7588 - eval_accuracy: 0.8804 - val_loss: 4.7473 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 196/200
# 1/1 [==============================] - 0s 70ms/step - loss: 2.7677 - eval_accuracy: 0.8813 - val_loss: 4.7918 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 197/200
# 1/1 [==============================] - 0s 89ms/step - loss: 2.7598 - eval_accuracy: 0.8810 - val_loss: 4.7832 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 198/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7572 - eval_accuracy: 0.8809 - val_loss: 4.7685 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 199/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7562 - eval_accuracy: 0.8811 - val_loss: 4.7724 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 200/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.7592 - eval_accuracy: 0.8809 - val_loss: 4.7689 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04

# %%
import matplotlib.pyplot as plt

# 손실 그래프
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 훈련 및 검증 평가 지표 추출
train_accuracy = history.history['eval_accuracy']
val_accuracy = history.history['val_eval_accuracy']

# 평가 지표 그래프 그리기
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 세트 평가
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Loss:", round(loss, 3))
print("Test Accuracy:", round(accuracy, 3))
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: 5.1799 - eval_accuracy: 0.8709
# Test Loss: 5.18
# Test Accuracy: 0.871
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
