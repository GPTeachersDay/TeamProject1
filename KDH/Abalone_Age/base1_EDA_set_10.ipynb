# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
def load_dataset(csv_path, TRAIN_RATIO=0.8):
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    # 데이터셋 로드
    df = pd.read_csv(csv_path)
    
    # 성별 원핫 인코딩
    df=pd.get_dummies(df,columns=['Sex'])
    
    # 학습 데이터 분리
    X = df.drop('Rings', axis=1)
    y = df['Rings']
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=TRAIN_RATIO, random_state = 83)
    
    return X_train, X_test, y_train, y_test

csv_path = '../colabo/Data/Regression_data.csv'
X_train, X_test, y_train, y_test = load_dataset(csv_path)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3341, 10) (836, 10) (3341,) (836,)

# %%
# 전복 전체 무게가 살 + 내장 + 껍질보다 적게 나가는 경우는 말이 안됨
body = X_train['Whole weight'] - (X_train['Shucked weight'] + X_train['Viscera weight'] + X_train['Shell weight'])
X_train['body'] = body

index = X_train[X_train['body'] < 0].index

body = X_test['Whole weight'] - (X_test['Shucked weight'] + X_test['Viscera weight'] + X_test['Shell weight'])
X_test['body'] = body

index2 = X_test[X_test['body'] < 0].index

print(index.shape, index2.shape)
# Out:
# (118,) (37,)

# %%
X_train.drop(index, axis=0, inplace=True)
X_test.drop(index2, axis=0, inplace=True)
y_train.drop(index, axis=0, inplace=True)
y_test.drop(index2, axis=0, inplace=True)

# %%
# Lenth가 Diameter보다 크다.
# --> Length는 장축의 길이, Diameter는 단축의 지름으로 판단됨
# 타원(전복 껍데기)의 둘레 및 넓이 구해보기
# Length가 Diameter보다 큰게 딱 1개 있음 --> 그럴 수도 있으니 삭제는 안함
index3 = X_train[X_train['Diameter'] > X_train['Length']].index
index4 = X_test[X_test['Diameter'] > X_test['Length']].index
print(index3.shape, index4.shape)
# Out:
# (1,) (0,)

# %%
import numpy as np

# train 껍질의 넓이 ( a * b * π)
area = 0.5 * X_train['Length'] * 0.5 * X_train['Diameter'] * np.pi
X_train['Area'] = area

# test 껍질의 넓이 
area2 = 0.5 * X_test['Length'] * 0.5 * X_test['Diameter'] * np.pi
X_test['Area'] = area2

# %%
# train 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter = np.pi * np.sqrt(0.5 * ((X_train['Length'] ** 2) + (X_train['Diameter'] ** 2)))
X_train['Perimeter'] = perimeter

# test 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter2 = np.pi * np.sqrt(0.5 * ((X_test['Length'] ** 2) + (X_test['Diameter'] ** 2)))
X_test['Perimeter'] = perimeter2

X_train.head()
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 461    0.585     0.465   0.170        0.9915          0.3865          0.2240
# 2835   0.570     0.420   0.140        0.8745          0.4160          0.1650
# 1378   0.620     0.500   0.150        1.2930          0.5960          0.3135
# 2569   0.460     0.345   0.115        0.4215          0.1895          0.1020
# 369    0.690     0.560   0.215        1.7190          0.6800          0.2990
#
#       Shell weight  Sex_F  Sex_I  Sex_M    body      Area  Perimeter
# 461          0.265      1      0      0  0.1160  0.213648   1.660072
# 2835         0.250      0      0      1  0.0435  0.188024   1.572837
# 1378         0.354      1      0      0  0.0295  0.243473   1.769361
# 2569         0.111      0      1      0  0.0190  0.124643   1.277329
# 369          0.470      1      0      0  0.2700  0.303478   1.974085

# %%
# 타겟값과 각 변수들 간의 상관관계
co = X_train.corrwith(y_train)

# 상관계수를 내림차순으로 정리
print(co.sort_values(ascending=False))

# 절대값
co_abs = abs(co)
# Out:
# Shell weight      0.619796
# Diameter          0.559512
# Perimeter         0.548978
# Length            0.539317
# Height            0.534439
# body              0.533203
# Area              0.532949
# Whole weight      0.525487
# Viscera weight    0.489945
# Shucked weight    0.403014
# Sex_F             0.242466
# Sex_M             0.178722
# Sex_I            -0.431255
# dtype: float64

# %%
columns = ['Shell weight', 'Perimeter', 'Height', 'body', 'Area', 'Whole weight', 'Sex_F', 'Sex_M', 'Sex_I']
X_train_2 = X_train[columns]
X_test_2 = X_test[columns]
X_train_2.head()
# Out:
#       Shell weight  Perimeter  Height    body      Area  Whole weight  Sex_F  \
# 461          0.265   1.660072   0.170  0.1160  0.213648        0.9915      1
# 2835         0.250   1.572837   0.140  0.0435  0.188024        0.8745      0
# 1378         0.354   1.769361   0.150  0.0295  0.243473        1.2930      1
# 2569         0.111   1.277329   0.115  0.0190  0.124643        0.4215      0
# 369          0.470   1.974085   0.215  0.2700  0.303478        1.7190      1
#
#       Sex_M  Sex_I
# 461       0      0
# 2835      1      0
# 1378      0      0
# 2569      0      1
# 369       0      0

# %%
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 피처 선택
scaling_features = columns[:-3]  # 원핫인코딩되지 않은 연속형 또는 순서형 변수들

# 스케일링
scaler = MinMaxScaler()
X_train_scaled = X_train_2.copy()  # 원본 데이터 복사
X_test_scaled = X_test_2.copy()    # 원본 데이터 복사
X_train_scaled[scaling_features] = scaler.fit_transform(X_train_2[scaling_features])
X_test_scaled[scaling_features] = scaler.transform(X_test_2[scaling_features])

# %%
"""
from sklearn import metrics
from sklearn import preprocessing

# 피처 스케일링
scaler = preprocessing.MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train_2)
X_test_scaled  = scaler.fit_transform(X_test_2)
"""
# Out:
# '\nfrom sklearn import metrics\nfrom sklearn import preprocessing\n\n# 피처 스케일링\nscaler = preprocessing.MinMaxScaler()\n\nX_train_scaled = scaler.fit_transform(X_train_2)\nX_test_scaled  = scaler.fit_transform(X_test_2)\n'

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

# %%
# 사용자 정의 평가 지표 클래스
import tensorflow as tf

class EvalAccuracy(tf.keras.metrics.Metric): # TensorFlow의 Metric 클래스를 상속 받음

    def __init__(self, name="eval_accuracy", **kwargs): # 부모 클래스의 __init__() 메소드를 호출하여 필요한 초기화를 수행
        super(EvalAccuracy, self).__init__(name=name, **kwargs)
        self.correct = self.add_weight(name="ctp", initializer="zeros")
        # add_weight() 메소드를 사용하여 평가 지표를 계산하는데 필요한 변수를 생성(각 배치에서의 평가 결과를 누적하기 위해)
        # add_weight() 는 텐서플로우 Layer 클래스의 메서드(새로운 가중치를 추가하는 기능, 여기서는 평가 지표를 계산하는 데 사용되는 일종의 내부 변수를 의미)
        # 이 구문이 실행되면, EvalAccuracy 인스턴스는 새로운 가중치를 추가하고 그 가중치를 self.correct에 저장한다.
        # 이 self.correct는 update_state() 메서드에서 업데이트되며, '현재까지 처리한 모든 배치에 대한 평가 지표의 평균을 저장'한다.

    def update_state(self, y_true, y_predict, sample_weight=None):
        value = tf.abs((y_predict - y_true) / y_true)
        self.correct.assign(tf.reduce_mean(value)) # 오차율을 계산해서 correct 변수에 누적한 후, assign() 메소드를 사용하여 correct 변수의 값을 업데이트

    def result(self):
        return 1 - self.correct

    def reset_states(self):
        # 에포크마다 평가 지표 초기화
        self.correct.assign(0.)

# %%
# 베이스모델
import numpy as np

def Base_Model(LEARNING_RATE=0.01):
    
    np.random.seed(42)
    tf.random.set_seed(42)
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')
    
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=512, activation='relu', input_shape=(len(X_train_2.keys()),)),
        tf.keras.layers.Dense(units=256, activation='relu'),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=1)
    ])
    
    # 옵티마이저와 손실 함수 설정
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=[EvalAccuracy()])
    
    return model

model = Base_Model()
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 512)               5120
#
#  dense_26 (Dense)            (None, 256)               131328
#
#  dense_27 (Dense)            (None, 128)               32896
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  dense_29 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 177,665
# Trainable params: 177,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 자동 중단 설정
es = EarlyStopping(monitor='loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=40, mode='min')

# %%
# 하이퍼파라미터 세팅
LEARNING_RATE = 0.01
EPOCHS = 200
MB_SIZE = 1000
REPORT = 1
TRAIN_RATIO = 0.8

np.random.seed(42)
tf.random.set_seed(42)

# 모델 학습
history = model.fit(
  X_train_scaled, y_train,
  batch_size=MB_SIZE,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS,
  callbacks=[es, rlrp]
  )
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 97ms/step - loss: 100.1348 - eval_accuracy: 0.1610 - val_loss: 53.8755 - val_eval_accuracy: 0.3601 - lr: 0.0100
# Epoch 2/200
# 3/3 [==============================] - 0s 27ms/step - loss: 27.6404 - eval_accuracy: 0.6118 - val_loss: 34.8878 - val_eval_accuracy: 0.5203 - lr: 0.0100
# Epoch 3/200
# 1/3 [=========>....................] - ETA: 0s - loss: 34.9351 - eval_accuracy: 0.5273
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 3/3 [==============================] - 0s 26ms/step - loss: 26.1842 - eval_accuracy: 0.5354 - val_loss: 9.6695 - val_eval_accuracy: 0.6851 - lr: 0.0100
# Epoch 4/200
# 3/3 [==============================] - 0s 25ms/step - loss: 16.9773 - eval_accuracy: 0.5996 - val_loss: 35.6722 - val_eval_accuracy: 0.5142 - lr: 0.0100
# Epoch 5/200
# 3/3 [==============================] - 0s 24ms/step - loss: 18.3906 - eval_accuracy: 0.8043 - val_loss: 6.6422 - val_eval_accuracy: 0.7833 - lr: 0.0100
# Epoch 6/200
# 3/3 [==============================] - 0s 27ms/step - loss: 8.6767 - eval_accuracy: 0.6730 - val_loss: 18.2578 - val_eval_accuracy: 0.7031 - lr: 0.0100
# Epoch 7/200
# 3/3 [==============================] - 0s 26ms/step - loss: 19.2275 - eval_accuracy: 0.5687 - val_loss: 6.8788 - val_eval_accuracy: 0.7691 - lr: 0.0100
# Epoch 8/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.6169 - eval_accuracy: 0.7045 - val_loss: 16.8041 - val_eval_accuracy: 0.7223 - lr: 0.0100
# Epoch 9/200
# 3/3 [==============================] - 0s 25ms/step - loss: 16.2110 - eval_accuracy: 0.6629 - val_loss: 8.4513 - val_eval_accuracy: 0.7162 - lr: 0.0100
# Epoch 10/200
# 3/3 [==============================] - 0s 24ms/step - loss: 11.0923 - eval_accuracy: 0.6803 - val_loss: 15.2006 - val_eval_accuracy: 0.7440 - lr: 0.0100
# Epoch 11/200
# 3/3 [==============================] - 0s 23ms/step - loss: 13.7766 - eval_accuracy: 0.7451 - val_loss: 10.3718 - val_eval_accuracy: 0.6752 - lr: 0.0100
# Epoch 12/200
# 3/3 [==============================] - 0s 23ms/step - loss: 12.8951 - eval_accuracy: 0.7310 - val_loss: 9.4594 - val_eval_accuracy: 0.8206 - lr: 0.0100
# Epoch 13/200
# 3/3 [==============================] - 0s 23ms/step - loss: 9.8114 - eval_accuracy: 0.8053 - val_loss: 8.6809 - val_eval_accuracy: 0.7118 - lr: 0.0100
# Epoch 14/200
# 3/3 [==============================] - 0s 23ms/step - loss: 12.0951 - eval_accuracy: 0.6803 - val_loss: 13.1981 - val_eval_accuracy: 0.7722 - lr: 0.0100
# Epoch 15/200
# 3/3 [==============================] - 0s 26ms/step - loss: 11.9882 - eval_accuracy: 0.7950 - val_loss: 8.7532 - val_eval_accuracy: 0.7104 - lr: 0.0100
# Epoch 16/200
# 3/3 [==============================] - 0s 25ms/step - loss: 10.6752 - eval_accuracy: 0.7141 - val_loss: 9.0096 - val_eval_accuracy: 0.8245 - lr: 0.0100
# Epoch 17/200
# 3/3 [==============================] - 0s 23ms/step - loss: 9.3601 - eval_accuracy: 0.8170 - val_loss: 7.8280 - val_eval_accuracy: 0.7356 - lr: 0.0100
# Epoch 18/200
# 3/3 [==============================] - 0s 24ms/step - loss: 10.1176 - eval_accuracy: 0.6838 - val_loss: 13.6781 - val_eval_accuracy: 0.7641 - lr: 0.0100
# Epoch 19/200
# 3/3 [==============================] - 0s 22ms/step - loss: 10.9353 - eval_accuracy: 0.8122 - val_loss: 7.9755 - val_eval_accuracy: 0.7314 - lr: 0.0100
# Epoch 20/200
# 3/3 [==============================] - 0s 22ms/step - loss: 9.5474 - eval_accuracy: 0.7275 - val_loss: 10.0231 - val_eval_accuracy: 0.8140 - lr: 0.0100
# Epoch 21/200
# 3/3 [==============================] - 0s 24ms/step - loss: 9.4145 - eval_accuracy: 0.8287 - val_loss: 7.0075 - val_eval_accuracy: 0.7616 - lr: 0.0100
# Epoch 22/200
# 3/3 [==============================] - 0s 23ms/step - loss: 8.6863 - eval_accuracy: 0.7296 - val_loss: 7.8127 - val_eval_accuracy: 0.8361 - lr: 0.0100
# Epoch 23/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.4953 - eval_accuracy: 0.8182 - val_loss: 7.5089 - val_eval_accuracy: 0.7443 - lr: 0.0100
# Epoch 24/200
# 3/3 [==============================] - 0s 22ms/step - loss: 9.5055 - eval_accuracy: 0.7356 - val_loss: 7.9331 - val_eval_accuracy: 0.8360 - lr: 0.0100
# Epoch 25/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.8252 - eval_accuracy: 0.8274 - val_loss: 6.4431 - val_eval_accuracy: 0.7851 - lr: 0.0100
# Epoch 26/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.2417 - eval_accuracy: 0.7933 - val_loss: 6.4046 - val_eval_accuracy: 0.8369 - lr: 0.0100
# Epoch 27/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.2413 - eval_accuracy: 0.8255 - val_loss: 6.5738 - val_eval_accuracy: 0.7781 - lr: 0.0100
# Epoch 28/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.8728 - eval_accuracy: 0.7443 - val_loss: 8.7930 - val_eval_accuracy: 0.8298 - lr: 0.0100
# Epoch 29/200
# 3/3 [==============================] - 0s 23ms/step - loss: 9.5354 - eval_accuracy: 0.8197 - val_loss: 7.2373 - val_eval_accuracy: 0.7536 - lr: 0.0100
# Epoch 30/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.9824 - eval_accuracy: 0.7277 - val_loss: 10.1679 - val_eval_accuracy: 0.8130 - lr: 0.0100
# Epoch 31/200
# 3/3 [==============================] - 0s 23ms/step - loss: 9.5457 - eval_accuracy: 0.8326 - val_loss: 7.3640 - val_eval_accuracy: 0.7490 - lr: 0.0100
# Epoch 32/200
# 3/3 [==============================] - 0s 21ms/step - loss: 8.3045 - eval_accuracy: 0.7633 - val_loss: 7.9550 - val_eval_accuracy: 0.8380 - lr: 0.0100
# Epoch 33/200
# 3/3 [==============================] - 0s 22ms/step - loss: 8.4646 - eval_accuracy: 0.8406 - val_loss: 7.0933 - val_eval_accuracy: 0.7583 - lr: 0.0100
# Epoch 34/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.8838 - eval_accuracy: 0.7682 - val_loss: 6.8575 - val_eval_accuracy: 0.8432 - lr: 0.0100
# Epoch 35/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.4327 - eval_accuracy: 0.8355 - val_loss: 6.4517 - val_eval_accuracy: 0.7820 - lr: 0.0100
# Epoch 36/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.6949 - eval_accuracy: 0.7593 - val_loss: 7.0806 - val_eval_accuracy: 0.8439 - lr: 0.0100
# Epoch 37/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.6676 - eval_accuracy: 0.8441 - val_loss: 6.1503 - val_eval_accuracy: 0.7969 - lr: 0.0100
# Epoch 38/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.2051 - eval_accuracy: 0.7619 - val_loss: 7.4847 - val_eval_accuracy: 0.8426 - lr: 0.0100
# Epoch 39/200
# 3/3 [==============================] - 0s 28ms/step - loss: 7.7704 - eval_accuracy: 0.8356 - val_loss: 6.6492 - val_eval_accuracy: 0.7731 - lr: 0.0100
# Epoch 40/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.4993 - eval_accuracy: 0.7669 - val_loss: 6.9789 - val_eval_accuracy: 0.8453 - lr: 0.0100
# Epoch 41/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.7636 - eval_accuracy: 0.8382 - val_loss: 6.6437 - val_eval_accuracy: 0.7731 - lr: 0.0100
# Epoch 42/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.7812 - eval_accuracy: 0.7436 - val_loss: 7.7991 - val_eval_accuracy: 0.8401 - lr: 0.0100
# Epoch 43/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.4707 - eval_accuracy: 0.8242 - val_loss: 8.8725 - val_eval_accuracy: 0.7130 - lr: 0.0100
# Epoch 44/200
# 3/3 [==============================] - 0s 24ms/step - loss: 10.5785 - eval_accuracy: 0.7446 - val_loss: 7.2491 - val_eval_accuracy: 0.8443 - lr: 0.0100
# Epoch 45/200
# 3/3 [==============================] - 0s 25ms/step - loss: 8.0400 - eval_accuracy: 0.8397 - val_loss: 6.5364 - val_eval_accuracy: 0.7758 - lr: 0.0100
# Epoch 46/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.4666 - eval_accuracy: 0.7621 - val_loss: 7.0835 - val_eval_accuracy: 0.8451 - lr: 0.0100
# Epoch 47/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.7869 - eval_accuracy: 0.8430 - val_loss: 6.4290 - val_eval_accuracy: 0.7812 - lr: 0.0100
# Epoch 48/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.2368 - eval_accuracy: 0.7852 - val_loss: 6.2234 - val_eval_accuracy: 0.8432 - lr: 0.0100
# Epoch 49/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.8247 - eval_accuracy: 0.8169 - val_loss: 5.9362 - val_eval_accuracy: 0.8070 - lr: 0.0100
# Epoch 50/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.7080 - eval_accuracy: 0.7991 - val_loss: 6.1222 - val_eval_accuracy: 0.8434 - lr: 0.0100
# Epoch 51/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.2394 - eval_accuracy: 0.8333 - val_loss: 6.8697 - val_eval_accuracy: 0.7650 - lr: 0.0100
# Epoch 52/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.2302 - eval_accuracy: 0.7875 - val_loss: 6.5684 - val_eval_accuracy: 0.8469 - lr: 0.0100
# Epoch 53/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.3629 - eval_accuracy: 0.8377 - val_loss: 6.4628 - val_eval_accuracy: 0.7796 - lr: 0.0100
# Epoch 54/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.6421 - eval_accuracy: 0.7446 - val_loss: 8.6981 - val_eval_accuracy: 0.8290 - lr: 0.0100
# Epoch 55/200
# 3/3 [==============================] - 0s 23ms/step - loss: 8.8984 - eval_accuracy: 0.8335 - val_loss: 6.6826 - val_eval_accuracy: 0.7708 - lr: 0.0100
# Epoch 56/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.6862 - eval_accuracy: 0.7645 - val_loss: 7.6730 - val_eval_accuracy: 0.8410 - lr: 0.0100
# Epoch 57/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.8695 - eval_accuracy: 0.8543 - val_loss: 6.1637 - val_eval_accuracy: 0.7914 - lr: 0.0100
# Epoch 58/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.2167 - eval_accuracy: 0.7740 - val_loss: 6.3330 - val_eval_accuracy: 0.8463 - lr: 0.0100
# Epoch 59/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.0625 - eval_accuracy: 0.8349 - val_loss: 6.3743 - val_eval_accuracy: 0.7823 - lr: 0.0100
# Epoch 60/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.4685 - eval_accuracy: 0.7639 - val_loss: 7.1741 - val_eval_accuracy: 0.8454 - lr: 0.0100
# Epoch 61/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.4194 - eval_accuracy: 0.8398 - val_loss: 6.4774 - val_eval_accuracy: 0.7782 - lr: 0.0100
# Epoch 62/200
# 3/3 [==============================] - 0s 47ms/step - loss: 7.2526 - eval_accuracy: 0.7662 - val_loss: 6.5957 - val_eval_accuracy: 0.8476 - lr: 0.0100
# Epoch 63/200
# 3/3 [==============================] - 0s 26ms/step - loss: 7.2997 - eval_accuracy: 0.8327 - val_loss: 6.0061 - val_eval_accuracy: 0.7982 - lr: 0.0100
# Epoch 64/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.8187 - eval_accuracy: 0.7865 - val_loss: 6.1986 - val_eval_accuracy: 0.8465 - lr: 0.0100
# Epoch 65/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.8217 - eval_accuracy: 0.8362 - val_loss: 6.3438 - val_eval_accuracy: 0.7836 - lr: 0.0100
# Epoch 66/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.1160 - eval_accuracy: 0.7866 - val_loss: 6.0764 - val_eval_accuracy: 0.8459 - lr: 0.0100
# Epoch 67/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.7292 - eval_accuracy: 0.8354 - val_loss: 6.3391 - val_eval_accuracy: 0.7829 - lr: 0.0100
# Epoch 68/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.9260 - eval_accuracy: 0.7832 - val_loss: 6.0294 - val_eval_accuracy: 0.8460 - lr: 0.0100
# Epoch 69/200
# 3/3 [==============================] - 0s 21ms/step - loss: 6.6913 - eval_accuracy: 0.8445 - val_loss: 5.8625 - val_eval_accuracy: 0.8050 - lr: 0.0100
# Epoch 70/200
# 3/3 [==============================] - 0s 25ms/step - loss: 6.8058 - eval_accuracy: 0.7801 - val_loss: 6.4210 - val_eval_accuracy: 0.8480 - lr: 0.0100
# Epoch 71/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.7983 - eval_accuracy: 0.8430 - val_loss: 5.7736 - val_eval_accuracy: 0.8099 - lr: 0.0100
# Epoch 72/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.3750 - eval_accuracy: 0.8227 - val_loss: 5.6167 - val_eval_accuracy: 0.8341 - lr: 0.0100
# Epoch 73/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.3163 - eval_accuracy: 0.8237 - val_loss: 5.6014 - val_eval_accuracy: 0.8242 - lr: 0.0100
# Epoch 74/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.4090 - eval_accuracy: 0.7921 - val_loss: 6.5151 - val_eval_accuracy: 0.8479 - lr: 0.0100
# Epoch 75/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.9928 - eval_accuracy: 0.8119 - val_loss: 8.0000 - val_eval_accuracy: 0.7324 - lr: 0.0100
# Epoch 76/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.6769 - eval_accuracy: 0.7481 - val_loss: 9.8132 - val_eval_accuracy: 0.8125 - lr: 0.0100
# Epoch 77/200
# 3/3 [==============================] - 0s 23ms/step - loss: 8.6981 - eval_accuracy: 0.8366 - val_loss: 7.1326 - val_eval_accuracy: 0.7548 - lr: 0.0100
# Epoch 78/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.0901 - eval_accuracy: 0.7562 - val_loss: 6.7288 - val_eval_accuracy: 0.8472 - lr: 0.0100
# Epoch 79/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.5408 - eval_accuracy: 0.8434 - val_loss: 6.5961 - val_eval_accuracy: 0.7713 - lr: 0.0100
# Epoch 80/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.3533 - eval_accuracy: 0.7572 - val_loss: 7.1608 - val_eval_accuracy: 0.8449 - lr: 0.0100
# Epoch 81/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.1836 - eval_accuracy: 0.8360 - val_loss: 5.9468 - val_eval_accuracy: 0.7973 - lr: 0.0100
# Epoch 82/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.9720 - eval_accuracy: 0.7821 - val_loss: 6.5532 - val_eval_accuracy: 0.8485 - lr: 0.0100
# Epoch 83/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.2274 - eval_accuracy: 0.8432 - val_loss: 6.3887 - val_eval_accuracy: 0.7791 - lr: 0.0100
# Epoch 84/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.7957 - eval_accuracy: 0.7534 - val_loss: 6.8932 - val_eval_accuracy: 0.8466 - lr: 0.0100
# Epoch 85/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.9962 - eval_accuracy: 0.8443 - val_loss: 6.3155 - val_eval_accuracy: 0.7813 - lr: 0.0100
# Epoch 86/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.0008 - eval_accuracy: 0.7775 - val_loss: 6.6074 - val_eval_accuracy: 0.8485 - lr: 0.0100
# Epoch 87/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.7914 - eval_accuracy: 0.8410 - val_loss: 5.9822 - val_eval_accuracy: 0.7945 - lr: 0.0100
# Epoch 88/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.8221 - eval_accuracy: 0.7714 - val_loss: 6.9760 - val_eval_accuracy: 0.8454 - lr: 0.0100
# Epoch 89/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.3269 - eval_accuracy: 0.8508 - val_loss: 6.0916 - val_eval_accuracy: 0.7896 - lr: 0.0100
# Epoch 90/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.1384 - eval_accuracy: 0.7571 - val_loss: 8.0848 - val_eval_accuracy: 0.8351 - lr: 0.0100
# Epoch 91/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.0729 - eval_accuracy: 0.8365 - val_loss: 6.4349 - val_eval_accuracy: 0.7763 - lr: 0.0100
# Epoch 92/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.4374 - eval_accuracy: 0.7609 - val_loss: 7.8011 - val_eval_accuracy: 0.8373 - lr: 0.0100
# Epoch 93/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.3940 - eval_accuracy: 0.8342 - val_loss: 6.7196 - val_eval_accuracy: 0.7671 - lr: 0.0100
# Epoch 94/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.2660 - eval_accuracy: 0.7798 - val_loss: 6.3447 - val_eval_accuracy: 0.8495 - lr: 0.0100
# Epoch 95/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.2096 - eval_accuracy: 0.8412 - val_loss: 5.9570 - val_eval_accuracy: 0.7940 - lr: 0.0100
# Epoch 96/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.6659 - eval_accuracy: 0.7879 - val_loss: 5.7353 - val_eval_accuracy: 0.8463 - lr: 0.0100
# Epoch 97/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.5180 - eval_accuracy: 0.8412 - val_loss: 6.0733 - val_eval_accuracy: 0.7892 - lr: 0.0100
# Epoch 98/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.2064 - eval_accuracy: 0.7590 - val_loss: 6.8760 - val_eval_accuracy: 0.8463 - lr: 0.0100
# Epoch 99/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.6968 - eval_accuracy: 0.8362 - val_loss: 6.6569 - val_eval_accuracy: 0.7681 - lr: 0.0100
# Epoch 100/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.0484 - eval_accuracy: 0.7499 - val_loss: 8.0459 - val_eval_accuracy: 0.8348 - lr: 0.0100
# Epoch 101/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.4937 - eval_accuracy: 0.8514 - val_loss: 5.5374 - val_eval_accuracy: 0.8185 - lr: 0.0100
# Epoch 102/200
# 3/3 [==============================] - 0s 25ms/step - loss: 6.2533 - eval_accuracy: 0.8108 - val_loss: 6.0161 - val_eval_accuracy: 0.8496 - lr: 0.0100
# Epoch 103/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.3379 - eval_accuracy: 0.8298 - val_loss: 5.4776 - val_eval_accuracy: 0.8209 - lr: 0.0100
# Epoch 104/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.2319 - eval_accuracy: 0.7969 - val_loss: 5.9016 - val_eval_accuracy: 0.8497 - lr: 0.0100
# Epoch 105/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.5591 - eval_accuracy: 0.8345 - val_loss: 6.4887 - val_eval_accuracy: 0.7747 - lr: 0.0100
# Epoch 106/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.8787 - eval_accuracy: 0.7464 - val_loss: 7.9464 - val_eval_accuracy: 0.8359 - lr: 0.0100
# Epoch 107/200
# 3/3 [==============================] - 0s 21ms/step - loss: 7.5652 - eval_accuracy: 0.8373 - val_loss: 6.6481 - val_eval_accuracy: 0.7685 - lr: 0.0100
# Epoch 108/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.4874 - eval_accuracy: 0.7711 - val_loss: 7.7635 - val_eval_accuracy: 0.8387 - lr: 0.0100
# Epoch 109/200
# 3/3 [==============================] - 0s 26ms/step - loss: 7.9841 - eval_accuracy: 0.8293 - val_loss: 6.5499 - val_eval_accuracy: 0.7691 - lr: 0.0100
# Epoch 110/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.1508 - eval_accuracy: 0.7914 - val_loss: 5.6445 - val_eval_accuracy: 0.8465 - lr: 0.0100
# Epoch 111/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.2540 - eval_accuracy: 0.8404 - val_loss: 5.3929 - val_eval_accuracy: 0.8262 - lr: 0.0100
# Epoch 112/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.1388 - eval_accuracy: 0.7998 - val_loss: 5.4739 - val_eval_accuracy: 0.8448 - lr: 0.0100
# Epoch 113/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.0070 - eval_accuracy: 0.8211 - val_loss: 5.3216 - val_eval_accuracy: 0.8365 - lr: 0.0100
# Epoch 114/200
# 3/3 [==============================] - 0s 42ms/step - loss: 5.9832 - eval_accuracy: 0.8364 - val_loss: 5.3370 - val_eval_accuracy: 0.8280 - lr: 0.0100
# Epoch 115/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.9461 - eval_accuracy: 0.8087 - val_loss: 5.2838 - val_eval_accuracy: 0.8352 - lr: 0.0100
# Epoch 116/200
# 3/3 [==============================] - 0s 21ms/step - loss: 6.0296 - eval_accuracy: 0.8014 - val_loss: 6.9412 - val_eval_accuracy: 0.8461 - lr: 0.0100
# Epoch 117/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.2871 - eval_accuracy: 0.8159 - val_loss: 6.7236 - val_eval_accuracy: 0.7617 - lr: 0.0100
# Epoch 118/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.4533 - eval_accuracy: 0.7687 - val_loss: 6.2760 - val_eval_accuracy: 0.8506 - lr: 0.0100
# Epoch 119/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.8511 - eval_accuracy: 0.8472 - val_loss: 6.0781 - val_eval_accuracy: 0.7861 - lr: 0.0100
# Epoch 120/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.9674 - eval_accuracy: 0.7798 - val_loss: 6.8426 - val_eval_accuracy: 0.8467 - lr: 0.0100
# Epoch 121/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.8425 - eval_accuracy: 0.8421 - val_loss: 5.9513 - val_eval_accuracy: 0.7909 - lr: 0.0100
# Epoch 122/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.0097 - eval_accuracy: 0.7673 - val_loss: 6.3313 - val_eval_accuracy: 0.8503 - lr: 0.0100
# Epoch 123/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.9423 - eval_accuracy: 0.8454 - val_loss: 5.9864 - val_eval_accuracy: 0.7894 - lr: 0.0100
# Epoch 124/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.6734 - eval_accuracy: 0.7830 - val_loss: 6.6934 - val_eval_accuracy: 0.8476 - lr: 0.0100
# Epoch 125/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.2415 - eval_accuracy: 0.8453 - val_loss: 6.4757 - val_eval_accuracy: 0.7707 - lr: 0.0100
# Epoch 126/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.1668 - eval_accuracy: 0.7784 - val_loss: 5.9673 - val_eval_accuracy: 0.8515 - lr: 0.0100
# Epoch 127/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.5287 - eval_accuracy: 0.8456 - val_loss: 5.5315 - val_eval_accuracy: 0.8098 - lr: 0.0100
# Epoch 128/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.2958 - eval_accuracy: 0.7987 - val_loss: 5.8855 - val_eval_accuracy: 0.8518 - lr: 0.0100
# Epoch 129/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.2623 - eval_accuracy: 0.8470 - val_loss: 5.5818 - val_eval_accuracy: 0.8067 - lr: 0.0100
# Epoch 130/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.7642 - eval_accuracy: 0.7633 - val_loss: 6.9718 - val_eval_accuracy: 0.8453 - lr: 0.0100
# Epoch 131/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.5242 - eval_accuracy: 0.8317 - val_loss: 7.6170 - val_eval_accuracy: 0.7385 - lr: 0.0100
# Epoch 132/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.1201 - eval_accuracy: 0.7764 - val_loss: 6.6565 - val_eval_accuracy: 0.8489 - lr: 0.0100
# Epoch 133/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.4933 - eval_accuracy: 0.8396 - val_loss: 5.3263 - val_eval_accuracy: 0.8217 - lr: 0.0100
# Epoch 134/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.8877 - eval_accuracy: 0.8258 - val_loss: 5.3359 - val_eval_accuracy: 0.8470 - lr: 0.0100
# Epoch 135/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.9959 - eval_accuracy: 0.8449 - val_loss: 5.4311 - val_eval_accuracy: 0.8137 - lr: 0.0100
# Epoch 136/200
# 3/3 [==============================] - 0s 25ms/step - loss: 6.3339 - eval_accuracy: 0.7803 - val_loss: 6.9297 - val_eval_accuracy: 0.8455 - lr: 0.0100
# Epoch 137/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.5667 - eval_accuracy: 0.8344 - val_loss: 6.0991 - val_eval_accuracy: 0.7821 - lr: 0.0100
# Epoch 138/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.7893 - eval_accuracy: 0.7867 - val_loss: 6.0496 - val_eval_accuracy: 0.8516 - lr: 0.0100
# Epoch 139/200
# 3/3 [==============================] - 0s 26ms/step - loss: 6.5259 - eval_accuracy: 0.8527 - val_loss: 5.6037 - val_eval_accuracy: 0.8035 - lr: 0.0100
# Epoch 140/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.4577 - eval_accuracy: 0.7792 - val_loss: 6.2917 - val_eval_accuracy: 0.8504 - lr: 0.0100
# Epoch 141/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.3462 - eval_accuracy: 0.8347 - val_loss: 6.3173 - val_eval_accuracy: 0.7765 - lr: 0.0100
# Epoch 142/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.7773 - eval_accuracy: 0.7925 - val_loss: 5.3916 - val_eval_accuracy: 0.8492 - lr: 0.0100
# Epoch 143/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.2253 - eval_accuracy: 0.8526 - val_loss: 5.9302 - val_eval_accuracy: 0.7887 - lr: 0.0100
# Epoch 144/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.1092 - eval_accuracy: 0.7671 - val_loss: 7.2225 - val_eval_accuracy: 0.8430 - lr: 0.0100
# Epoch 145/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.0671 - eval_accuracy: 0.8447 - val_loss: 5.8350 - val_eval_accuracy: 0.7932 - lr: 0.0100
# Epoch 146/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.4793 - eval_accuracy: 0.7578 - val_loss: 7.1729 - val_eval_accuracy: 0.8439 - lr: 0.0100
# Epoch 147/200
# 3/3 [==============================] - 0s 25ms/step - loss: 6.7194 - eval_accuracy: 0.8431 - val_loss: 5.2964 - val_eval_accuracy: 0.8199 - lr: 0.0100
# Epoch 148/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.8304 - eval_accuracy: 0.8217 - val_loss: 5.1428 - val_eval_accuracy: 0.8402 - lr: 0.0100
# Epoch 149/200
# 3/3 [==============================] - 0s 25ms/step - loss: 5.7153 - eval_accuracy: 0.8366 - val_loss: 5.0951 - val_eval_accuracy: 0.8371 - lr: 0.0100
# Epoch 150/200
# 3/3 [==============================] - 0s 23ms/step - loss: 5.6720 - eval_accuracy: 0.8197 - val_loss: 5.0780 - val_eval_accuracy: 0.8419 - lr: 0.0100
# Epoch 151/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.6562 - eval_accuracy: 0.8448 - val_loss: 5.1045 - val_eval_accuracy: 0.8304 - lr: 0.0100
# Epoch 152/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.9191 - eval_accuracy: 0.7820 - val_loss: 7.2564 - val_eval_accuracy: 0.8407 - lr: 0.0100
# Epoch 153/200
# 3/3 [==============================] - 0s 24ms/step - loss: 8.1344 - eval_accuracy: 0.8180 - val_loss: 6.3621 - val_eval_accuracy: 0.7697 - lr: 0.0100
# Epoch 154/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.9346 - eval_accuracy: 0.7726 - val_loss: 6.7364 - val_eval_accuracy: 0.8476 - lr: 0.0100
# Epoch 155/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.9272 - eval_accuracy: 0.8432 - val_loss: 6.1113 - val_eval_accuracy: 0.7819 - lr: 0.0100
# Epoch 156/200
# 3/3 [==============================] - 0s 26ms/step - loss: 6.7221 - eval_accuracy: 0.7840 - val_loss: 6.2226 - val_eval_accuracy: 0.8512 - lr: 0.0100
# Epoch 157/200
# 3/3 [==============================] - 0s 42ms/step - loss: 6.2591 - eval_accuracy: 0.8428 - val_loss: 5.7046 - val_eval_accuracy: 0.7989 - lr: 0.0100
# Epoch 158/200
# 3/3 [==============================] - 0s 28ms/step - loss: 6.4837 - eval_accuracy: 0.7843 - val_loss: 6.5221 - val_eval_accuracy: 0.8494 - lr: 0.0100
# Epoch 159/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.1337 - eval_accuracy: 0.8490 - val_loss: 5.5996 - val_eval_accuracy: 0.7999 - lr: 0.0100
# Epoch 160/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.2494 - eval_accuracy: 0.7980 - val_loss: 5.6466 - val_eval_accuracy: 0.8532 - lr: 0.0100
# Epoch 161/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.5840 - eval_accuracy: 0.8455 - val_loss: 5.7169 - val_eval_accuracy: 0.7945 - lr: 0.0100
# Epoch 162/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.9699 - eval_accuracy: 0.7758 - val_loss: 6.4317 - val_eval_accuracy: 0.8503 - lr: 0.0100
# Epoch 163/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.2984 - eval_accuracy: 0.8467 - val_loss: 5.5118 - val_eval_accuracy: 0.8038 - lr: 0.0100
# Epoch 164/200
# 3/3 [==============================] - 0s 25ms/step - loss: 5.8540 - eval_accuracy: 0.8259 - val_loss: 5.0144 - val_eval_accuracy: 0.8414 - lr: 0.0100
# Epoch 165/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.5653 - eval_accuracy: 0.8391 - val_loss: 4.9900 - val_eval_accuracy: 0.8409 - lr: 0.0100
# Epoch 166/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.5341 - eval_accuracy: 0.8278 - val_loss: 5.1318 - val_eval_accuracy: 0.8498 - lr: 0.0100
# Epoch 167/200
# 3/3 [==============================] - 0s 26ms/step - loss: 5.9633 - eval_accuracy: 0.8534 - val_loss: 6.0734 - val_eval_accuracy: 0.7829 - lr: 0.0100
# Epoch 168/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.8199 - eval_accuracy: 0.7406 - val_loss: 8.6046 - val_eval_accuracy: 0.8283 - lr: 0.0100
# Epoch 169/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.0889 - eval_accuracy: 0.8422 - val_loss: 5.2550 - val_eval_accuracy: 0.8162 - lr: 0.0100
# Epoch 170/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.8007 - eval_accuracy: 0.8075 - val_loss: 5.6520 - val_eval_accuracy: 0.8539 - lr: 0.0100
# Epoch 171/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.4196 - eval_accuracy: 0.8585 - val_loss: 5.6748 - val_eval_accuracy: 0.7960 - lr: 0.0100
# Epoch 172/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.2251 - eval_accuracy: 0.7974 - val_loss: 5.4489 - val_eval_accuracy: 0.8535 - lr: 0.0100
# Epoch 173/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.1836 - eval_accuracy: 0.8478 - val_loss: 5.7325 - val_eval_accuracy: 0.7938 - lr: 0.0100
# Epoch 174/200
# 3/3 [==============================] - 0s 23ms/step - loss: 7.1439 - eval_accuracy: 0.7502 - val_loss: 7.7445 - val_eval_accuracy: 0.8375 - lr: 0.0100
# Epoch 175/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.8527 - eval_accuracy: 0.8467 - val_loss: 5.4016 - val_eval_accuracy: 0.8078 - lr: 0.0100
# Epoch 176/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.4610 - eval_accuracy: 0.7805 - val_loss: 6.5990 - val_eval_accuracy: 0.8478 - lr: 0.0100
# Epoch 177/200
# 3/3 [==============================] - 0s 22ms/step - loss: 7.0953 - eval_accuracy: 0.8397 - val_loss: 6.1692 - val_eval_accuracy: 0.7781 - lr: 0.0100
# Epoch 178/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.0725 - eval_accuracy: 0.7714 - val_loss: 5.8704 - val_eval_accuracy: 0.8530 - lr: 0.0100
# Epoch 179/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.1690 - eval_accuracy: 0.8507 - val_loss: 5.1614 - val_eval_accuracy: 0.8205 - lr: 0.0100
# Epoch 180/200
# 3/3 [==============================] - 0s 25ms/step - loss: 6.0010 - eval_accuracy: 0.7851 - val_loss: 7.2230 - val_eval_accuracy: 0.8436 - lr: 0.0100
# Epoch 181/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.5880 - eval_accuracy: 0.8515 - val_loss: 5.3477 - val_eval_accuracy: 0.8100 - lr: 0.0100
# Epoch 182/200
# 3/3 [==============================] - 0s 22ms/step - loss: 5.8486 - eval_accuracy: 0.8169 - val_loss: 5.0621 - val_eval_accuracy: 0.8506 - lr: 0.0100
# Epoch 183/200
# 3/3 [==============================] - 0s 25ms/step - loss: 5.6970 - eval_accuracy: 0.8509 - val_loss: 5.1876 - val_eval_accuracy: 0.8174 - lr: 0.0100
# Epoch 184/200
# 3/3 [==============================] - 0s 23ms/step - loss: 5.8886 - eval_accuracy: 0.7925 - val_loss: 6.1521 - val_eval_accuracy: 0.8519 - lr: 0.0100
# Epoch 185/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.0244 - eval_accuracy: 0.8347 - val_loss: 5.8867 - val_eval_accuracy: 0.7850 - lr: 0.0100
# Epoch 186/200
# 3/3 [==============================] - 0s 26ms/step - loss: 6.3402 - eval_accuracy: 0.8007 - val_loss: 5.5409 - val_eval_accuracy: 0.8539 - lr: 0.0100
# Epoch 187/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.9080 - eval_accuracy: 0.8477 - val_loss: 5.5103 - val_eval_accuracy: 0.8024 - lr: 0.0100
# Epoch 188/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.1761 - eval_accuracy: 0.7887 - val_loss: 5.8195 - val_eval_accuracy: 0.8536 - lr: 0.0100
# Epoch 189/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.5141 - eval_accuracy: 0.8488 - val_loss: 5.8459 - val_eval_accuracy: 0.7900 - lr: 0.0100
# Epoch 190/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.7383 - eval_accuracy: 0.7867 - val_loss: 5.8975 - val_eval_accuracy: 0.8533 - lr: 0.0100
# Epoch 191/200
# 3/3 [==============================] - 0s 22ms/step - loss: 6.3488 - eval_accuracy: 0.8522 - val_loss: 5.8720 - val_eval_accuracy: 0.7900 - lr: 0.0100
# Epoch 192/200
# 3/3 [==============================] - 0s 42ms/step - loss: 6.4538 - eval_accuracy: 0.7988 - val_loss: 5.5744 - val_eval_accuracy: 0.8542 - lr: 0.0100
# Epoch 193/200
# 3/3 [==============================] - 0s 27ms/step - loss: 6.6715 - eval_accuracy: 0.8425 - val_loss: 5.2115 - val_eval_accuracy: 0.8168 - lr: 0.0100
# Epoch 194/200
# 3/3 [==============================] - 0s 24ms/step - loss: 5.6484 - eval_accuracy: 0.8107 - val_loss: 5.2621 - val_eval_accuracy: 0.8539 - lr: 0.0100
# Epoch 195/200
# 3/3 [==============================] - 0s 27ms/step - loss: 6.1679 - eval_accuracy: 0.8507 - val_loss: 5.5173 - val_eval_accuracy: 0.8011 - lr: 0.0100
# Epoch 196/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.2010 - eval_accuracy: 0.7913 - val_loss: 5.9654 - val_eval_accuracy: 0.8529 - lr: 0.0100
# Epoch 197/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.1739 - eval_accuracy: 0.8462 - val_loss: 5.6937 - val_eval_accuracy: 0.7969 - lr: 0.0100
# Epoch 198/200
# 3/3 [==============================] - 0s 23ms/step - loss: 6.8283 - eval_accuracy: 0.7909 - val_loss: 6.0759 - val_eval_accuracy: 0.8523 - lr: 0.0100
# Epoch 199/200
# 3/3 [==============================] - 0s 24ms/step - loss: 6.5319 - eval_accuracy: 0.8478 - val_loss: 6.1464 - val_eval_accuracy: 0.7818 - lr: 0.0100
# Epoch 200/200
# 3/3 [==============================] - 0s 24ms/step - loss: 7.0308 - eval_accuracy: 0.7842 - val_loss: 5.3149 - val_eval_accuracy: 0.8527 - lr: 0.0100

# %%
import matplotlib.pyplot as plt

# 손실 그래프
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 훈련 및 검증 평가 지표 추출
train_accuracy = history.history['eval_accuracy']
val_accuracy = history.history['val_eval_accuracy']

# 평가 지표 그래프 그리기
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 세트 평가
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Loss:", round(loss, 3))
print("Test Accuracy:", round(accuracy, 3))
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: 5.1441 - eval_accuracy: 0.8387
# Test Loss: 5.144
# Test Accuracy: 0.839
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
