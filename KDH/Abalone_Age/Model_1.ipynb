# %%
# 라이브러리 추출
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
# 메서드 정의
def main(URL = 'Dataset\Regression_data.csv'):
    
    # 랜덤 시드 고정
    np.random.seed(42)
    tf.random.set_seed(42)
    
    global df, LEARNING_RATE, EPOCH_COUNT, MB_SIZE, REPORT, TRAIN_RATIO, X, y, X_train, X_test, y_train, y_test, y_pred
    
    df = load_dataset(URL) # 데이터 로드
    Regression_Model() # 회귀 모델

# %%
# 메서드 정의
def load_dataset(URL = 'Dataset\Regression_data.csv'):
    
    # 데이터셋 로드
    df = pd.read_csv(URL)

    # 성별 인코딩
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    df['Sex'] = encoder.fit_transform(df['Sex'])
    
    print(df.head())
    
    return df

# %%
# 사용자 정의 평가 지표 메서드(EvalAccuracy 클래스로 해당 기능을 구현했으며 참고용)
"""
def eval_accuracy(y_true, y_predict):
    
	# 오차율 구하는 과정    
	# np.mean() 메서드의 이유는 미니배치 처리를 고려하여 하나의 지표로 묶어주기 위함 입니다. 
    mdiff = np.mean(np.abs((y_predict - y_true) / y_true))
    # 1 에서 오차율을 빼 정확도를 구합니다. 
    return 1 - mdiff
"""
# Out:
# '\ndef eval_accuracy(y_true, y_predict):\n    \n\t# 오차율 구하는 과정    \n\t# np.mean() 메서드의 이유는 미니배치 처리를 고려하여 하나의 지표로 묶어주기 위함 입니다. \n    mdiff = np.mean(np.abs((y_predict - y_true) / y_true))\n    # 1 에서 오차율을 빼 정확도를 구합니다. \n    return 1 - mdiff\n'

# %%
# 사용자 정의 평가 지표 클래스
class EvalAccuracy(tf.keras.metrics.Metric): # TensorFlow의 Metric 클래스를 상속 받음

    def __init__(self, name="eval_accuracy", **kwargs): # 부모 클래스의 __init__() 메소드를 호출하여 필요한 초기화를 수행
        super(EvalAccuracy, self).__init__(name=name, **kwargs)
        self.correct = self.add_weight(name="ctp", initializer="zeros")
        # add_weight() 메소드를 사용하여 평가 지표를 계산하는데 필요한 변수를 생성(각 배치에서의 평가 결과를 누적하기 위해)
        # add_weight() 는 텐서플로우 Layer 클래스의 메서드(새로운 가중치를 추가하는 기능, 여기서는 평가 지표를 계산하는 데 사용되는 일종의 내부 변수를 의미)
        # 이 구문이 실행되면, EvalAccuracy 인스턴스는 새로운 가중치를 추가하고 그 가중치를 self.correct에 저장한다.
        # 이 self.correct는 update_state() 메서드에서 업데이트되며, '현재까지 처리한 모든 배치에 대한 평가 지표의 평균을 저장'한다.

    def update_state(self, y_true, y_predict, sample_weight=None):
        value = tf.abs((y_predict - y_true) / y_true)
        self.correct.assign(tf.reduce_mean(value)) # 오차율을 계산해서 correct 변수에 누적한 후, assign() 메소드를 사용하여 correct 변수의 값을 업데이트

    def result(self):
        return 1 - self.correct

    def reset_states(self):
        # 에포크마다 평가 지표 초기화
        self.correct.assign(0.)

# %%
def Regression_Model():
    # 학습 모델 구현
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import r2_score
    from sklearn.metrics import mean_squared_error

    # 상수 정의
    LEARNING_RATE = 0.01
    EPOCH_COUNT = 100
    MB_SIZE = 100
    REPORT = 1
    TRAIN_RATIO = 0.8

    # 학습 데이터 분리
    X = df.drop('Rings', axis=1)
    y = df['Rings']
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=TRAIN_RATIO)
    
    # 텐서플로우의 텐서 연산은 계산 효율성 및 GPU사용을 최적화하기 위해 자동 형변환이 발생하지 않는다.
    # 따라서 매개변수를 float타입으로 변경해야 EvalAccuracy 클래스의 update_state 메서드가 작동한다. (사용자 정의 평가 지표)
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')

    # 모델 생성
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)), # (len(X_train.keys()),)로 입력해야 튜플 형태로 입력되어 오류가 발생하지 않음
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=16, activation='relu'),
        tf.keras.layers.Dense(units=1)
    ])


    # 옵티마이저와 손실 함수 설정
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=[EvalAccuracy()])
    
    # 학습 시작
    model.fit(X_train, y_train, epochs=EPOCH_COUNT, batch_size=MB_SIZE, verbose=REPORT)
    
    # 모델 평가
    y_pred = model.predict(X_test)
    
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f'Accuracy: {accuracy}\n MSE: {loss}')

# %%
main()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7
# Epoch 1/100
# 34/34 [==============================] - 1s 2ms/step - loss: 44.1657 - eval_accuracy: 0.7931
# Epoch 2/100
# 34/34 [==============================] - 0s 2ms/step - loss: 8.4862 - eval_accuracy: 0.8120
# Epoch 3/100
# 34/34 [==============================] - 0s 2ms/step - loss: 8.8989 - eval_accuracy: 0.7215
# Epoch 4/100
#  1/34 [..............................] - ETA: 0s - loss: 7.6126 - eval_accuracy: 0.7981
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 34/34 [==============================] - 0s 2ms/step - loss: 7.9800 - eval_accuracy: 0.7290
# Epoch 5/100
# 34/34 [==============================] - 0s 2ms/step - loss: 8.3713 - eval_accuracy: 0.8077
# Epoch 6/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7.5299 - eval_accuracy: 0.8201
# Epoch 7/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7.5096 - eval_accuracy: 0.7527
# Epoch 8/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7.5251 - eval_accuracy: 0.7963
# Epoch 9/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7.7847 - eval_accuracy: 0.8082
# Epoch 10/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7.2687 - eval_accuracy: 0.7844
# Epoch 11/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7.1345 - eval_accuracy: 0.6954
# Epoch 12/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.8183 - eval_accuracy: 0.8278
# Epoch 13/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.9489 - eval_accuracy: 0.8375
# Epoch 14/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.4464 - eval_accuracy: 0.7600
# Epoch 15/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7.1708 - eval_accuracy: 0.7689
# Epoch 16/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.4797 - eval_accuracy: 0.7534
# Epoch 17/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7.1787 - eval_accuracy: 0.8420
# Epoch 18/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.7212 - eval_accuracy: 0.7948
# Epoch 19/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7.0948 - eval_accuracy: 0.7828
# Epoch 20/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.0864 - eval_accuracy: 0.8407
# Epoch 21/100
# 34/34 [==============================] - 0s 3ms/step - loss: 6.3616 - eval_accuracy: 0.8291
# Epoch 22/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.6049 - eval_accuracy: 0.8133
# Epoch 23/100
# 34/34 [==============================] - 0s 3ms/step - loss: 6.2912 - eval_accuracy: 0.8446
# Epoch 24/100
# 34/34 [==============================] - 0s 3ms/step - loss: 6.1673 - eval_accuracy: 0.8905
# Epoch 25/100
# 34/34 [==============================] - 0s 3ms/step - loss: 6.2891 - eval_accuracy: 0.8002
# Epoch 26/100
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8997 - eval_accuracy: 0.7464
# Epoch 27/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.4765 - eval_accuracy: 0.8384
# Epoch 28/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.9323 - eval_accuracy: 0.7871
# Epoch 29/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.9893 - eval_accuracy: 0.8108
# Epoch 30/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.3501 - eval_accuracy: 0.8112
# Epoch 31/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.6336 - eval_accuracy: 0.8375
# Epoch 32/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.7891 - eval_accuracy: 0.8086
# Epoch 33/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.7056 - eval_accuracy: 0.8473
# Epoch 34/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.5557 - eval_accuracy: 0.8120
# Epoch 35/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.0211 - eval_accuracy: 0.8437
# Epoch 36/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.7201 - eval_accuracy: 0.8034
# Epoch 37/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.7329 - eval_accuracy: 0.8088
# Epoch 38/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.4792 - eval_accuracy: 0.8551
# Epoch 39/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.8251 - eval_accuracy: 0.8324
# Epoch 40/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3929 - eval_accuracy: 0.8074
# Epoch 41/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7.0669 - eval_accuracy: 0.8420
# Epoch 42/100
# 34/34 [==============================] - 0s 2ms/step - loss: 6.1684 - eval_accuracy: 0.8605
# Epoch 43/100
# 34/34 [==============================] - 0s 4ms/step - loss: 5.9049 - eval_accuracy: 0.8099
# Epoch 44/100
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8981 - eval_accuracy: 0.8327
# Epoch 45/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.4313 - eval_accuracy: 0.7819
# Epoch 46/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.4028 - eval_accuracy: 0.8731
# Epoch 47/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.2411 - eval_accuracy: 0.8593
# Epoch 48/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.2972 - eval_accuracy: 0.8208
# Epoch 49/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.8252 - eval_accuracy: 0.8709
# Epoch 50/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3365 - eval_accuracy: 0.8837
# Epoch 51/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3375 - eval_accuracy: 0.8020
# Epoch 52/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.1089 - eval_accuracy: 0.8272
# Epoch 53/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9800 - eval_accuracy: 0.8813
# Epoch 54/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.2768 - eval_accuracy: 0.8662
# Epoch 55/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.0961 - eval_accuracy: 0.8191
# Epoch 56/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.0138 - eval_accuracy: 0.8615
# Epoch 57/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7927 - eval_accuracy: 0.8576
# Epoch 58/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.2153 - eval_accuracy: 0.8067
# Epoch 59/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3231 - eval_accuracy: 0.8230
# Epoch 60/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.1913 - eval_accuracy: 0.8255
# Epoch 61/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3890 - eval_accuracy: 0.8536
# Epoch 62/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9420 - eval_accuracy: 0.8320
# Epoch 63/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7471 - eval_accuracy: 0.7968
# Epoch 64/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.3855 - eval_accuracy: 0.8094
# Epoch 65/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7490 - eval_accuracy: 0.8863
# Epoch 66/100
# 34/34 [==============================] - 0s 3ms/step - loss: 4.9946 - eval_accuracy: 0.8556
# Epoch 67/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9715 - eval_accuracy: 0.8498
# Epoch 68/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9542 - eval_accuracy: 0.8561
# Epoch 69/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.0682 - eval_accuracy: 0.8516
# Epoch 70/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6401 - eval_accuracy: 0.8262
# Epoch 71/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9445 - eval_accuracy: 0.8162
# Epoch 72/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.8083 - eval_accuracy: 0.8537
# Epoch 73/100
# 34/34 [==============================] - 0s 3ms/step - loss: 4.6406 - eval_accuracy: 0.8336
# Epoch 74/100
# 34/34 [==============================] - 0s 3ms/step - loss: 5.0037 - eval_accuracy: 0.8402
# Epoch 75/100
# 34/34 [==============================] - 0s 3ms/step - loss: 4.7389 - eval_accuracy: 0.7936
# Epoch 76/100
# 34/34 [==============================] - 0s 3ms/step - loss: 4.8503 - eval_accuracy: 0.8125
# Epoch 77/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6922 - eval_accuracy: 0.8704
# Epoch 78/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9197 - eval_accuracy: 0.8434
# Epoch 79/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9193 - eval_accuracy: 0.8338
# Epoch 80/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7171 - eval_accuracy: 0.8631
# Epoch 81/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9769 - eval_accuracy: 0.7760
# Epoch 82/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.5221 - eval_accuracy: 0.8313
# Epoch 83/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.1520 - eval_accuracy: 0.8205
# Epoch 84/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6390 - eval_accuracy: 0.8889
# Epoch 85/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7128 - eval_accuracy: 0.8370
# Epoch 86/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.8800 - eval_accuracy: 0.8728
# Epoch 87/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.5741 - eval_accuracy: 0.7785
# Epoch 88/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6890 - eval_accuracy: 0.8861
# Epoch 89/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6355 - eval_accuracy: 0.8441
# Epoch 90/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6063 - eval_accuracy: 0.8526
# Epoch 91/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.4722 - eval_accuracy: 0.8831
# Epoch 92/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7618 - eval_accuracy: 0.8312
# Epoch 93/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6133 - eval_accuracy: 0.7536
# Epoch 94/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7493 - eval_accuracy: 0.8748
# Epoch 95/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.7223 - eval_accuracy: 0.8417
# Epoch 96/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.6766 - eval_accuracy: 0.8404
# Epoch 97/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.5949 - eval_accuracy: 0.8544
# Epoch 98/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.9623 - eval_accuracy: 0.8798
# Epoch 99/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.8456 - eval_accuracy: 0.8244
# Epoch 100/100
# 34/34 [==============================] - 0s 2ms/step - loss: 4.8035 - eval_accuracy: 0.7920
# 27/27 [==============================] - 0s 1ms/step
# Accuracy: 0.912091851234436
#  MSE: 5.997882843017578
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
