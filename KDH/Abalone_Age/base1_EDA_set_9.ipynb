# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
def load_dataset(csv_path, TRAIN_RATIO=0.8):
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    # 데이터셋 로드
    df = pd.read_csv(csv_path)
    
    # 성별 원핫 인코딩
    df=pd.get_dummies(df,columns=['Sex'])
    
    # 학습 데이터 분리
    X = df.drop('Rings', axis=1)
    y = df['Rings']
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=TRAIN_RATIO, random_state = 83)
    
    return X_train, X_test, y_train, y_test

csv_path = '../colabo/Data/Regression_data.csv'
X_train, X_test, y_train, y_test = load_dataset(csv_path)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3341, 10) (836, 10) (3341,) (836,)

# %%
# 전복 전체 무게가 살 + 내장 + 껍질보다 적게 나가는 경우는 말이 안됨
body = X_train['Whole weight'] - (X_train['Shucked weight'] + X_train['Viscera weight'] + X_train['Shell weight'])
X_train['body'] = body

index = X_train[X_train['body'] < 0].index

body = X_test['Whole weight'] - (X_test['Shucked weight'] + X_test['Viscera weight'] + X_test['Shell weight'])
X_test['body'] = body

index2 = X_test[X_test['body'] < 0].index

print(index.shape, index2.shape)
# Out:
# (118,) (37,)

# %%
X_train.drop(index, axis=0, inplace=True)
X_test.drop(index2, axis=0, inplace=True)
y_train.drop(index, axis=0, inplace=True)
y_test.drop(index2, axis=0, inplace=True)

# %%
# Lenth가 Diameter보다 크다.
# --> Length는 장축의 길이, Diameter는 단축의 지름으로 판단됨
# 타원(전복 껍데기)의 둘레 및 넓이 구해보기
# Length가 Diameter보다 큰게 딱 1개 있음 --> 그럴 수도 있으니 삭제는 안함
index3 = X_train[X_train['Diameter'] > X_train['Length']].index
index4 = X_test[X_test['Diameter'] > X_test['Length']].index
print(index3.shape, index4.shape)
# Out:
# (1,) (0,)

# %%
import numpy as np

# train 껍질의 넓이 ( a * b * π)
area = 0.5 * X_train['Length'] * 0.5 * X_train['Diameter'] * np.pi
X_train['Area'] = area

# test 껍질의 넓이 
area2 = 0.5 * X_test['Length'] * 0.5 * X_test['Diameter'] * np.pi
X_test['Area'] = area2

# %%
# train 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter = np.pi * np.sqrt(0.5 * ((X_train['Length'] ** 2) + (X_train['Diameter'] ** 2)))
X_train['Perimeter'] = perimeter

# test 껍질의 둘레 (근사) ( 2π*(0.5 * √(a^2 + b^2)))
perimeter2 = np.pi * np.sqrt(0.5 * ((X_test['Length'] ** 2) + (X_test['Diameter'] ** 2)))
X_test['Perimeter'] = perimeter2

X_train.head()
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 461    0.585     0.465   0.170        0.9915          0.3865          0.2240
# 2835   0.570     0.420   0.140        0.8745          0.4160          0.1650
# 1378   0.620     0.500   0.150        1.2930          0.5960          0.3135
# 2569   0.460     0.345   0.115        0.4215          0.1895          0.1020
# 369    0.690     0.560   0.215        1.7190          0.6800          0.2990
#
#       Shell weight  Sex_F  Sex_I  Sex_M    body      Area  Perimeter
# 461          0.265      1      0      0  0.1160  0.213648   1.660072
# 2835         0.250      0      0      1  0.0435  0.188024   1.572837
# 1378         0.354      1      0      0  0.0295  0.243473   1.769361
# 2569         0.111      0      1      0  0.0190  0.124643   1.277329
# 369          0.470      1      0      0  0.2700  0.303478   1.974085

# %%
# 타겟값과 각 변수들 간의 상관관계
co = X_train.corrwith(y_train)

# 상관계수를 내림차순으로 정리
print(co.sort_values(ascending=False))

# 절대값
co_abs = abs(co)
# Out:
# Shell weight      0.619796
# Diameter          0.559512
# Perimeter         0.548978
# Length            0.539317
# Height            0.534439
# body              0.533203
# Area              0.532949
# Whole weight      0.525487
# Viscera weight    0.489945
# Shucked weight    0.403014
# Sex_F             0.242466
# Sex_M             0.178722
# Sex_I            -0.431255
# dtype: float64

# %%
columns = ['Shell weight', 'Diameter', 'Perimeter', 'Length', 'Height', 'body', 'Area', 'Whole weight', 'Sex_F', 'Sex_M', 'Sex_I']
X_train_2 = X_train[columns]
X_test_2 = X_test[columns]
X_train_2.head()
# Out:
#       Shell weight  Diameter  Perimeter  Length  Height    body      Area  \
# 461          0.265     0.465   1.660072   0.585   0.170  0.1160  0.213648
# 2835         0.250     0.420   1.572837   0.570   0.140  0.0435  0.188024
# 1378         0.354     0.500   1.769361   0.620   0.150  0.0295  0.243473
# 2569         0.111     0.345   1.277329   0.460   0.115  0.0190  0.124643
# 369          0.470     0.560   1.974085   0.690   0.215  0.2700  0.303478
#
#       Whole weight  Sex_F  Sex_M  Sex_I
# 461         0.9915      1      0      0
# 2835        0.8745      0      1      0
# 1378        1.2930      1      0      0
# 2569        0.4215      0      0      1
# 369         1.7190      1      0      0

# %%
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 피처 선택
scaling_features = ['Shell weight', 'Diameter', 'Perimeter', 'Length', 'Height', 'body', 'Area', 'Whole weight']  # 원핫인코딩되지 않은 연속형 또는 순서형 변수들

# 스케일링
scaler = MinMaxScaler()
X_train_scaled = X_train_2.copy()  # 원본 데이터 복사
X_test_scaled = X_test_2.copy()    # 원본 데이터 복사
X_train_scaled[scaling_features] = scaler.fit_transform(X_train_2[scaling_features])
X_test_scaled[scaling_features] = scaler.transform(X_test_2[scaling_features])

# %%
"""
from sklearn import metrics
from sklearn import preprocessing

# 피처 스케일링
scaler = preprocessing.MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train_2)
X_test_scaled  = scaler.fit_transform(X_test_2)
"""
# Out:
# '\nfrom sklearn import metrics\nfrom sklearn import preprocessing\n\n# 피처 스케일링\nscaler = preprocessing.MinMaxScaler()\n\nX_train_scaled = scaler.fit_transform(X_train_2)\nX_test_scaled  = scaler.fit_transform(X_test_2)\n'

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

# %%
# 사용자 정의 평가 지표 클래스
import tensorflow as tf

class EvalAccuracy(tf.keras.metrics.Metric): # TensorFlow의 Metric 클래스를 상속 받음

    def __init__(self, name="eval_accuracy", **kwargs): # 부모 클래스의 __init__() 메소드를 호출하여 필요한 초기화를 수행
        super(EvalAccuracy, self).__init__(name=name, **kwargs)
        self.correct = self.add_weight(name="ctp", initializer="zeros")
        # add_weight() 메소드를 사용하여 평가 지표를 계산하는데 필요한 변수를 생성(각 배치에서의 평가 결과를 누적하기 위해)
        # add_weight() 는 텐서플로우 Layer 클래스의 메서드(새로운 가중치를 추가하는 기능, 여기서는 평가 지표를 계산하는 데 사용되는 일종의 내부 변수를 의미)
        # 이 구문이 실행되면, EvalAccuracy 인스턴스는 새로운 가중치를 추가하고 그 가중치를 self.correct에 저장한다.
        # 이 self.correct는 update_state() 메서드에서 업데이트되며, '현재까지 처리한 모든 배치에 대한 평가 지표의 평균을 저장'한다.

    def update_state(self, y_true, y_predict, sample_weight=None):
        value = tf.abs((y_predict - y_true) / y_true)
        self.correct.assign(tf.reduce_mean(value)) # 오차율을 계산해서 correct 변수에 누적한 후, assign() 메소드를 사용하여 correct 변수의 값을 업데이트

    def result(self):
        return 1 - self.correct

    def reset_states(self):
        # 에포크마다 평가 지표 초기화
        self.correct.assign(0.)

# %%
# 베이스모델
import numpy as np

def Base_Model(LEARNING_RATE=0.01):
    
    np.random.seed(42)
    tf.random.set_seed(42)
    
    global X, y, X_train, X_test, y_train, y_test, df
    
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')
    
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=512, activation='relu', input_shape=(len(X_train_2.keys()),)),
        tf.keras.layers.Dense(units=256, activation='relu'),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dense(units=64, activation='relu'),
        tf.keras.layers.Dense(units=1)
    ])
    
    # 옵티마이저와 손실 함수 설정
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=[EvalAccuracy()])
    
    return model

model = Base_Model()
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 512)               6144
#
#  dense_26 (Dense)            (None, 256)               131328
#
#  dense_27 (Dense)            (None, 128)               32896
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  dense_29 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 178,689
# Trainable params: 178,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 자동 중단 설정
es = EarlyStopping(monitor='loss', patience=50, mode='min')
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=40, mode='min')

# %%
# 하이퍼파라미터 세팅
LEARNING_RATE = 0.01
EPOCHS = 200
MB_SIZE = 1000
REPORT = 1
TRAIN_RATIO = 0.8

np.random.seed(42)
tf.random.set_seed(42)
    
history = model.fit(
  X_train_scaled, y_train,
  batch_size=MB_SIZE,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS,
  callbacks=[es, rlrp]
  )
# Out:
# Epoch 1/200
# 1/3 [=========>....................] - ETA: 0s - loss: 4.1360 - eval_accuracy: 0.8609
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 3/3 [==============================] - 0s 83ms/step - loss: 4.4749 - eval_accuracy: 0.8591 - val_loss: 4.5450 - val_eval_accuracy: 0.8367 - lr: 0.0020
# Epoch 2/200
# 3/3 [==============================] - 0s 29ms/step - loss: 4.4247 - eval_accuracy: 0.8518 - val_loss: 4.3761 - val_eval_accuracy: 0.8459 - lr: 0.0020
# Epoch 3/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3781 - eval_accuracy: 0.8480 - val_loss: 4.3533 - val_eval_accuracy: 0.8473 - lr: 0.0020
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 4/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3896 - eval_accuracy: 0.8463 - val_loss: 4.2596 - val_eval_accuracy: 0.8544 - lr: 0.0020
# Epoch 5/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3549 - eval_accuracy: 0.8563 - val_loss: 4.2392 - val_eval_accuracy: 0.8578 - lr: 0.0020
# Epoch 6/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3537 - eval_accuracy: 0.8564 - val_loss: 4.4144 - val_eval_accuracy: 0.8443 - lr: 0.0020
# Epoch 7/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5127 - eval_accuracy: 0.8474 - val_loss: 4.2452 - val_eval_accuracy: 0.8608 - lr: 0.0020
# Epoch 8/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4064 - eval_accuracy: 0.8632 - val_loss: 4.3414 - val_eval_accuracy: 0.8478 - lr: 0.0020
# Epoch 9/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3935 - eval_accuracy: 0.8508 - val_loss: 4.2400 - val_eval_accuracy: 0.8583 - lr: 0.0020
# Epoch 10/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3580 - eval_accuracy: 0.8644 - val_loss: 4.3260 - val_eval_accuracy: 0.8492 - lr: 0.0020
# Epoch 11/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4186 - eval_accuracy: 0.8424 - val_loss: 4.2385 - val_eval_accuracy: 0.8590 - lr: 0.0020
# Epoch 12/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4153 - eval_accuracy: 0.8633 - val_loss: 4.3794 - val_eval_accuracy: 0.8459 - lr: 0.0020
# Epoch 13/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4789 - eval_accuracy: 0.8338 - val_loss: 4.2632 - val_eval_accuracy: 0.8613 - lr: 0.0020
# Epoch 14/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3862 - eval_accuracy: 0.8555 - val_loss: 4.2726 - val_eval_accuracy: 0.8531 - lr: 0.0020
# Epoch 15/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3608 - eval_accuracy: 0.8641 - val_loss: 4.3763 - val_eval_accuracy: 0.8463 - lr: 0.0020
# Epoch 16/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3901 - eval_accuracy: 0.8553 - val_loss: 4.2873 - val_eval_accuracy: 0.8520 - lr: 0.0020
# Epoch 17/200
# 3/3 [==============================] - 0s 46ms/step - loss: 4.3616 - eval_accuracy: 0.8582 - val_loss: 4.3965 - val_eval_accuracy: 0.8449 - lr: 0.0020
# Epoch 18/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.5113 - eval_accuracy: 0.8302 - val_loss: 4.4482 - val_eval_accuracy: 0.8628 - lr: 0.0020
# Epoch 19/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5228 - eval_accuracy: 0.8594 - val_loss: 4.5266 - val_eval_accuracy: 0.8382 - lr: 0.0020
# Epoch 20/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.5020 - eval_accuracy: 0.8447 - val_loss: 4.3029 - val_eval_accuracy: 0.8626 - lr: 0.0020
# Epoch 21/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4030 - eval_accuracy: 0.8583 - val_loss: 4.2830 - val_eval_accuracy: 0.8520 - lr: 0.0020
# Epoch 22/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3927 - eval_accuracy: 0.8435 - val_loss: 4.2807 - val_eval_accuracy: 0.8522 - lr: 0.0020
# Epoch 23/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3544 - eval_accuracy: 0.8476 - val_loss: 4.2489 - val_eval_accuracy: 0.8561 - lr: 0.0020
# Epoch 24/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3467 - eval_accuracy: 0.8575 - val_loss: 4.4292 - val_eval_accuracy: 0.8433 - lr: 0.0020
# Epoch 25/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4958 - eval_accuracy: 0.8439 - val_loss: 4.2767 - val_eval_accuracy: 0.8621 - lr: 0.0020
# Epoch 26/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.5539 - eval_accuracy: 0.8579 - val_loss: 4.4495 - val_eval_accuracy: 0.8418 - lr: 0.0020
# Epoch 27/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4190 - eval_accuracy: 0.8528 - val_loss: 4.2427 - val_eval_accuracy: 0.8580 - lr: 0.0020
# Epoch 28/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3555 - eval_accuracy: 0.8536 - val_loss: 4.2614 - val_eval_accuracy: 0.8540 - lr: 0.0020
# Epoch 29/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3491 - eval_accuracy: 0.8494 - val_loss: 4.2397 - val_eval_accuracy: 0.8583 - lr: 0.0020
# Epoch 30/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3604 - eval_accuracy: 0.8449 - val_loss: 4.2938 - val_eval_accuracy: 0.8623 - lr: 0.0020
# Epoch 31/200
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5116 - eval_accuracy: 0.8687 - val_loss: 4.4658 - val_eval_accuracy: 0.8409 - lr: 0.0020
# Epoch 32/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3963 - eval_accuracy: 0.8492 - val_loss: 4.2359 - val_eval_accuracy: 0.8592 - lr: 0.0020
# Epoch 33/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3586 - eval_accuracy: 0.8521 - val_loss: 4.2791 - val_eval_accuracy: 0.8525 - lr: 0.0020
# Epoch 34/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3491 - eval_accuracy: 0.8499 - val_loss: 4.2416 - val_eval_accuracy: 0.8566 - lr: 0.0020
# Epoch 35/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3553 - eval_accuracy: 0.8578 - val_loss: 4.2846 - val_eval_accuracy: 0.8518 - lr: 0.0020
# Epoch 36/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3631 - eval_accuracy: 0.8547 - val_loss: 4.3158 - val_eval_accuracy: 0.8499 - lr: 0.0020
# Epoch 37/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3596 - eval_accuracy: 0.8579 - val_loss: 4.2414 - val_eval_accuracy: 0.8599 - lr: 0.0020
# Epoch 38/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3671 - eval_accuracy: 0.8544 - val_loss: 4.2582 - val_eval_accuracy: 0.8546 - lr: 0.0020
# Epoch 39/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3482 - eval_accuracy: 0.8621 - val_loss: 4.2928 - val_eval_accuracy: 0.8515 - lr: 0.0020
# Epoch 40/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3479 - eval_accuracy: 0.8589 - val_loss: 4.2877 - val_eval_accuracy: 0.8519 - lr: 0.0020
# Epoch 41/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3933 - eval_accuracy: 0.8413 - val_loss: 4.2610 - val_eval_accuracy: 0.8616 - lr: 0.0020
# Epoch 42/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.4211 - eval_accuracy: 0.8565 - val_loss: 4.2953 - val_eval_accuracy: 0.8514 - lr: 0.0020
# Epoch 43/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3620 - eval_accuracy: 0.8535 - val_loss: 4.4267 - val_eval_accuracy: 0.8436 - lr: 0.0020
# Epoch 44/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.5095 - eval_accuracy: 0.8341 - val_loss: 4.3103 - val_eval_accuracy: 0.8627 - lr: 0.0020
# Epoch 45/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.5503 - eval_accuracy: 0.8698 - val_loss: 4.4397 - val_eval_accuracy: 0.8419 - lr: 0.0020
# Epoch 46/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.4479 - eval_accuracy: 0.8397 - val_loss: 4.3119 - val_eval_accuracy: 0.8629 - lr: 0.0020
# Epoch 47/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4493 - eval_accuracy: 0.8668 - val_loss: 4.2481 - val_eval_accuracy: 0.8550 - lr: 0.0020
# Epoch 48/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3507 - eval_accuracy: 0.8512 - val_loss: 4.2328 - val_eval_accuracy: 0.8584 - lr: 0.0020
# Epoch 49/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3490 - eval_accuracy: 0.8481 - val_loss: 4.2450 - val_eval_accuracy: 0.8567 - lr: 0.0020
# Epoch 50/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3463 - eval_accuracy: 0.8518 - val_loss: 4.2617 - val_eval_accuracy: 0.8615 - lr: 0.0020
# Epoch 51/200
# 3/3 [==============================] - 0s 28ms/step - loss: 4.4014 - eval_accuracy: 0.8655 - val_loss: 4.4668 - val_eval_accuracy: 0.8410 - lr: 0.0020
# Epoch 52/200
# 3/3 [==============================] - 0s 29ms/step - loss: 4.3787 - eval_accuracy: 0.8555 - val_loss: 4.2437 - val_eval_accuracy: 0.8602 - lr: 0.0020
# Epoch 53/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3742 - eval_accuracy: 0.8499 - val_loss: 4.2383 - val_eval_accuracy: 0.8570 - lr: 0.0020
# Epoch 54/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3427 - eval_accuracy: 0.8496 - val_loss: 4.2364 - val_eval_accuracy: 0.8590 - lr: 0.0020
# Epoch 55/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4818 - eval_accuracy: 0.8724 - val_loss: 4.3302 - val_eval_accuracy: 0.8486 - lr: 0.0020
# Epoch 56/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3922 - eval_accuracy: 0.8503 - val_loss: 4.2412 - val_eval_accuracy: 0.8605 - lr: 0.0020
# Epoch 57/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3959 - eval_accuracy: 0.8665 - val_loss: 4.2535 - val_eval_accuracy: 0.8545 - lr: 0.0020
# Epoch 58/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3846 - eval_accuracy: 0.8456 - val_loss: 4.2465 - val_eval_accuracy: 0.8558 - lr: 0.0020
# Epoch 59/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3516 - eval_accuracy: 0.8502 - val_loss: 4.3542 - val_eval_accuracy: 0.8471 - lr: 0.0020
# Epoch 60/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3848 - eval_accuracy: 0.8444 - val_loss: 4.2544 - val_eval_accuracy: 0.8607 - lr: 0.0020
# Epoch 61/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3496 - eval_accuracy: 0.8600 - val_loss: 4.2356 - val_eval_accuracy: 0.8575 - lr: 0.0020
# Epoch 62/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3597 - eval_accuracy: 0.8558 - val_loss: 4.3661 - val_eval_accuracy: 0.8468 - lr: 0.0020
# Epoch 63/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4095 - eval_accuracy: 0.8381 - val_loss: 4.3092 - val_eval_accuracy: 0.8628 - lr: 0.0020
# Epoch 64/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4673 - eval_accuracy: 0.8663 - val_loss: 4.4654 - val_eval_accuracy: 0.8409 - lr: 0.0020
# Epoch 65/200
# 3/3 [==============================] - 0s 29ms/step - loss: 4.4317 - eval_accuracy: 0.8442 - val_loss: 4.2314 - val_eval_accuracy: 0.8580 - lr: 0.0020
# Epoch 66/200
# 3/3 [==============================] - 0s 35ms/step - loss: 4.3770 - eval_accuracy: 0.8627 - val_loss: 4.3655 - val_eval_accuracy: 0.8466 - lr: 0.0020
# Epoch 67/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4334 - eval_accuracy: 0.8439 - val_loss: 4.2366 - val_eval_accuracy: 0.8587 - lr: 0.0020
# Epoch 68/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.4062 - eval_accuracy: 0.8630 - val_loss: 4.5171 - val_eval_accuracy: 0.8388 - lr: 0.0020
# Epoch 69/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.5105 - eval_accuracy: 0.8450 - val_loss: 4.3252 - val_eval_accuracy: 0.8629 - lr: 0.0020
# Epoch 70/200
# 3/3 [==============================] - 0s 30ms/step - loss: 4.5202 - eval_accuracy: 0.8694 - val_loss: 4.4314 - val_eval_accuracy: 0.8428 - lr: 0.0020
# Epoch 71/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.4616 - eval_accuracy: 0.8365 - val_loss: 4.2795 - val_eval_accuracy: 0.8623 - lr: 0.0020
# Epoch 72/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.5502 - eval_accuracy: 0.8669 - val_loss: 4.4089 - val_eval_accuracy: 0.8438 - lr: 0.0020
# Epoch 73/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.4124 - eval_accuracy: 0.8452 - val_loss: 4.2553 - val_eval_accuracy: 0.8614 - lr: 0.0020
# Epoch 74/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3915 - eval_accuracy: 0.8573 - val_loss: 4.2433 - val_eval_accuracy: 0.8558 - lr: 0.0020
# Epoch 75/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3413 - eval_accuracy: 0.8476 - val_loss: 4.2345 - val_eval_accuracy: 0.8580 - lr: 0.0020
# Epoch 76/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3977 - eval_accuracy: 0.8677 - val_loss: 4.2913 - val_eval_accuracy: 0.8512 - lr: 0.0020
# Epoch 77/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3996 - eval_accuracy: 0.8435 - val_loss: 4.2324 - val_eval_accuracy: 0.8599 - lr: 0.0020
# Epoch 78/200
# 3/3 [==============================] - 0s 52ms/step - loss: 4.3878 - eval_accuracy: 0.8554 - val_loss: 4.3342 - val_eval_accuracy: 0.8484 - lr: 0.0020
# Epoch 79/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3423 - eval_accuracy: 0.8598 - val_loss: 4.2538 - val_eval_accuracy: 0.8548 - lr: 0.0020
# Epoch 80/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3380 - eval_accuracy: 0.8515 - val_loss: 4.2435 - val_eval_accuracy: 0.8564 - lr: 0.0020
# Epoch 81/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3510 - eval_accuracy: 0.8432 - val_loss: 4.2838 - val_eval_accuracy: 0.8623 - lr: 0.0020
# Epoch 82/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3943 - eval_accuracy: 0.8650 - val_loss: 4.4302 - val_eval_accuracy: 0.8431 - lr: 0.0020
# Epoch 83/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3947 - eval_accuracy: 0.8471 - val_loss: 4.2336 - val_eval_accuracy: 0.8587 - lr: 0.0020
# Epoch 84/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3339 - eval_accuracy: 0.8477 - val_loss: 4.3180 - val_eval_accuracy: 0.8497 - lr: 0.0020
# Epoch 85/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3536 - eval_accuracy: 0.8510 - val_loss: 4.2399 - val_eval_accuracy: 0.8603 - lr: 0.0020
# Epoch 86/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.4089 - eval_accuracy: 0.8572 - val_loss: 4.2738 - val_eval_accuracy: 0.8526 - lr: 0.0020
# Epoch 87/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3587 - eval_accuracy: 0.8454 - val_loss: 4.2340 - val_eval_accuracy: 0.8602 - lr: 0.0020
# Epoch 88/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3830 - eval_accuracy: 0.8549 - val_loss: 4.2799 - val_eval_accuracy: 0.8522 - lr: 0.0020
# Epoch 89/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3511 - eval_accuracy: 0.8551 - val_loss: 4.2536 - val_eval_accuracy: 0.8616 - lr: 0.0020
# Epoch 90/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3972 - eval_accuracy: 0.8540 - val_loss: 4.2463 - val_eval_accuracy: 0.8603 - lr: 0.0020
# Epoch 91/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3882 - eval_accuracy: 0.8576 - val_loss: 4.2813 - val_eval_accuracy: 0.8522 - lr: 0.0020
# Epoch 92/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3458 - eval_accuracy: 0.8560 - val_loss: 4.2754 - val_eval_accuracy: 0.8623 - lr: 0.0020
# Epoch 93/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3511 - eval_accuracy: 0.8526 - val_loss: 4.4028 - val_eval_accuracy: 0.8446 - lr: 0.0020
# Epoch 94/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3801 - eval_accuracy: 0.8468 - val_loss: 4.2323 - val_eval_accuracy: 0.8593 - lr: 0.0020
# Epoch 95/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3783 - eval_accuracy: 0.8521 - val_loss: 4.2420 - val_eval_accuracy: 0.8557 - lr: 0.0020
# Epoch 96/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3418 - eval_accuracy: 0.8533 - val_loss: 4.3289 - val_eval_accuracy: 0.8485 - lr: 0.0020
# Epoch 97/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3767 - eval_accuracy: 0.8492 - val_loss: 4.2607 - val_eval_accuracy: 0.8538 - lr: 0.0020
# Epoch 98/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3950 - eval_accuracy: 0.8413 - val_loss: 4.2441 - val_eval_accuracy: 0.8611 - lr: 0.0020
# Epoch 99/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.5124 - eval_accuracy: 0.8660 - val_loss: 4.7109 - val_eval_accuracy: 0.8302 - lr: 0.0020
# Epoch 100/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.7332 - eval_accuracy: 0.8350 - val_loss: 4.5107 - val_eval_accuracy: 0.8627 - lr: 0.0020
# Epoch 101/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.6273 - eval_accuracy: 0.8676 - val_loss: 4.2453 - val_eval_accuracy: 0.8544 - lr: 0.0020
# Epoch 102/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3679 - eval_accuracy: 0.8462 - val_loss: 4.3502 - val_eval_accuracy: 0.8628 - lr: 0.0020
# Epoch 103/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3912 - eval_accuracy: 0.8491 - val_loss: 4.2763 - val_eval_accuracy: 0.8522 - lr: 0.0020
# Epoch 104/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3882 - eval_accuracy: 0.8432 - val_loss: 4.2247 - val_eval_accuracy: 0.8596 - lr: 0.0020
# Epoch 105/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3405 - eval_accuracy: 0.8490 - val_loss: 4.3554 - val_eval_accuracy: 0.8473 - lr: 0.0020
# Epoch 106/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.4304 - eval_accuracy: 0.8365 - val_loss: 4.2867 - val_eval_accuracy: 0.8627 - lr: 0.0020
# Epoch 107/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4142 - eval_accuracy: 0.8590 - val_loss: 4.4286 - val_eval_accuracy: 0.8433 - lr: 0.0020
# Epoch 108/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3634 - eval_accuracy: 0.8541 - val_loss: 4.2944 - val_eval_accuracy: 0.8624 - lr: 0.0020
# Epoch 109/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.4717 - eval_accuracy: 0.8554 - val_loss: 4.6037 - val_eval_accuracy: 0.8340 - lr: 0.0020
# Epoch 110/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.5236 - eval_accuracy: 0.8439 - val_loss: 4.2305 - val_eval_accuracy: 0.8569 - lr: 0.0020
# Epoch 111/200
# 3/3 [==============================] - 0s 20ms/step - loss: 4.3417 - eval_accuracy: 0.8562 - val_loss: 4.2255 - val_eval_accuracy: 0.8598 - lr: 0.0020
# Epoch 112/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3416 - eval_accuracy: 0.8441 - val_loss: 4.2395 - val_eval_accuracy: 0.8563 - lr: 0.0020
# Epoch 113/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3665 - eval_accuracy: 0.8443 - val_loss: 4.2377 - val_eval_accuracy: 0.8613 - lr: 0.0020
# Epoch 114/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3875 - eval_accuracy: 0.8578 - val_loss: 4.2490 - val_eval_accuracy: 0.8550 - lr: 0.0020
# Epoch 115/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3372 - eval_accuracy: 0.8556 - val_loss: 4.3515 - val_eval_accuracy: 0.8477 - lr: 0.0020
# Epoch 116/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5121 - eval_accuracy: 0.8327 - val_loss: 4.6336 - val_eval_accuracy: 0.8619 - lr: 0.0020
# Epoch 117/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.8173 - eval_accuracy: 0.8594 - val_loss: 4.4109 - val_eval_accuracy: 0.8434 - lr: 0.0020
# Epoch 118/200
# 3/3 [==============================] - 0s 32ms/step - loss: 4.3669 - eval_accuracy: 0.8523 - val_loss: 4.3146 - val_eval_accuracy: 0.8494 - lr: 0.0020
# Epoch 119/200
# 3/3 [==============================] - 0s 32ms/step - loss: 4.3586 - eval_accuracy: 0.8515 - val_loss: 4.2287 - val_eval_accuracy: 0.8579 - lr: 0.0020
# Epoch 120/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3398 - eval_accuracy: 0.8581 - val_loss: 4.2443 - val_eval_accuracy: 0.8609 - lr: 0.0020
# Epoch 121/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3462 - eval_accuracy: 0.8461 - val_loss: 4.2291 - val_eval_accuracy: 0.8594 - lr: 0.0020
# Epoch 122/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3425 - eval_accuracy: 0.8519 - val_loss: 4.3631 - val_eval_accuracy: 0.8467 - lr: 0.0020
# Epoch 123/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3839 - eval_accuracy: 0.8458 - val_loss: 4.2493 - val_eval_accuracy: 0.8616 - lr: 0.0020
# Epoch 124/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.4001 - eval_accuracy: 0.8621 - val_loss: 4.2663 - val_eval_accuracy: 0.8532 - lr: 0.0020
# Epoch 125/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3303 - eval_accuracy: 0.8554 - val_loss: 4.2554 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 126/200
# 3/3 [==============================] - 0s 41ms/step - loss: 4.3295 - eval_accuracy: 0.8569 - val_loss: 4.2595 - val_eval_accuracy: 0.8539 - lr: 4.0000e-04
# Epoch 127/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3291 - eval_accuracy: 0.8519 - val_loss: 4.2438 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 128/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3281 - eval_accuracy: 0.8634 - val_loss: 4.2517 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 129/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3281 - eval_accuracy: 0.8547 - val_loss: 4.2483 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 130/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3292 - eval_accuracy: 0.8504 - val_loss: 4.2550 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 131/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3303 - eval_accuracy: 0.8484 - val_loss: 4.2637 - val_eval_accuracy: 0.8535 - lr: 4.0000e-04
# Epoch 132/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3302 - eval_accuracy: 0.8596 - val_loss: 4.2405 - val_eval_accuracy: 0.8562 - lr: 4.0000e-04
# Epoch 133/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3308 - eval_accuracy: 0.8521 - val_loss: 4.2425 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 134/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3281 - eval_accuracy: 0.8562 - val_loss: 4.2413 - val_eval_accuracy: 0.8560 - lr: 4.0000e-04
# Epoch 135/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3280 - eval_accuracy: 0.8588 - val_loss: 4.2443 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 136/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3275 - eval_accuracy: 0.8548 - val_loss: 4.2468 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 137/200
# 3/3 [==============================] - 0s 26ms/step - loss: 4.3283 - eval_accuracy: 0.8499 - val_loss: 4.2426 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 138/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3274 - eval_accuracy: 0.8627 - val_loss: 4.2449 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 139/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3266 - eval_accuracy: 0.8566 - val_loss: 4.2432 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 140/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3269 - eval_accuracy: 0.8563 - val_loss: 4.2547 - val_eval_accuracy: 0.8545 - lr: 4.0000e-04
# Epoch 141/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3280 - eval_accuracy: 0.8490 - val_loss: 4.2502 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 142/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3304 - eval_accuracy: 0.8512 - val_loss: 4.2518 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 143/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3270 - eval_accuracy: 0.8646 - val_loss: 4.2525 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 144/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3284 - eval_accuracy: 0.8494 - val_loss: 4.2467 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 145/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3261 - eval_accuracy: 0.8485 - val_loss: 4.2505 - val_eval_accuracy: 0.8549 - lr: 4.0000e-04
# Epoch 146/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3358 - eval_accuracy: 0.8541 - val_loss: 4.2524 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 147/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3263 - eval_accuracy: 0.8520 - val_loss: 4.2462 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 148/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3269 - eval_accuracy: 0.8549 - val_loss: 4.2496 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 149/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3263 - eval_accuracy: 0.8542 - val_loss: 4.2419 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 150/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3263 - eval_accuracy: 0.8505 - val_loss: 4.2474 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 151/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3281 - eval_accuracy: 0.8639 - val_loss: 4.2510 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 152/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3274 - eval_accuracy: 0.8464 - val_loss: 4.2450 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 153/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3261 - eval_accuracy: 0.8578 - val_loss: 4.2434 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 154/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3264 - eval_accuracy: 0.8521 - val_loss: 4.2404 - val_eval_accuracy: 0.8562 - lr: 4.0000e-04
# Epoch 155/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3287 - eval_accuracy: 0.8535 - val_loss: 4.2486 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 156/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3261 - eval_accuracy: 0.8551 - val_loss: 4.2441 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 157/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3273 - eval_accuracy: 0.8601 - val_loss: 4.2588 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 158/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3262 - eval_accuracy: 0.8562 - val_loss: 4.2474 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 159/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3271 - eval_accuracy: 0.8557 - val_loss: 4.2411 - val_eval_accuracy: 0.8561 - lr: 4.0000e-04
# Epoch 160/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3260 - eval_accuracy: 0.8536 - val_loss: 4.2482 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 161/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3261 - eval_accuracy: 0.8543 - val_loss: 4.2436 - val_eval_accuracy: 0.8557 - lr: 4.0000e-04
# Epoch 162/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3310 - eval_accuracy: 0.8592 - val_loss: 4.2558 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 163/200
# 3/3 [==============================] - 0s 43ms/step - loss: 4.3257 - eval_accuracy: 0.8569 - val_loss: 4.2519 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 164/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3365 - eval_accuracy: 0.8601 - val_loss: 4.2586 - val_eval_accuracy: 0.8540 - lr: 4.0000e-04
# Epoch 165/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3277 - eval_accuracy: 0.8563 - val_loss: 4.2474 - val_eval_accuracy: 0.8552 - lr: 4.0000e-04
# Epoch 166/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3271 - eval_accuracy: 0.8585 - val_loss: 4.2530 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 167/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3253 - eval_accuracy: 0.8548 - val_loss: 4.2426 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 168/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3290 - eval_accuracy: 0.8525 - val_loss: 4.2456 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 169/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3259 - eval_accuracy: 0.8522 - val_loss: 4.2491 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 170/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3246 - eval_accuracy: 0.8551 - val_loss: 4.2470 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 171/200
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3270 - eval_accuracy: 0.8623 - val_loss: 4.2363 - val_eval_accuracy: 0.8568 - lr: 4.0000e-04
# Epoch 172/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3291 - eval_accuracy: 0.8565 - val_loss: 4.2544 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 173/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3250 - eval_accuracy: 0.8539 - val_loss: 4.2480 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 174/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3265 - eval_accuracy: 0.8525 - val_loss: 4.2472 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 175/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3277 - eval_accuracy: 0.8601 - val_loss: 4.2531 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 176/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3273 - eval_accuracy: 0.8520 - val_loss: 4.2520 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 177/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3283 - eval_accuracy: 0.8551 - val_loss: 4.2550 - val_eval_accuracy: 0.8544 - lr: 4.0000e-04
# Epoch 178/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3255 - eval_accuracy: 0.8521 - val_loss: 4.2521 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04
# Epoch 179/200
# 3/3 [==============================] - 0s 27ms/step - loss: 4.3252 - eval_accuracy: 0.8470 - val_loss: 4.2397 - val_eval_accuracy: 0.8562 - lr: 4.0000e-04
# Epoch 180/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3270 - eval_accuracy: 0.8483 - val_loss: 4.2380 - val_eval_accuracy: 0.8564 - lr: 4.0000e-04
# Epoch 181/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3251 - eval_accuracy: 0.8600 - val_loss: 4.2483 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 182/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3261 - eval_accuracy: 0.8588 - val_loss: 4.2509 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 183/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3242 - eval_accuracy: 0.8569 - val_loss: 4.2445 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 184/200
# 3/3 [==============================] - 0s 21ms/step - loss: 4.3266 - eval_accuracy: 0.8530 - val_loss: 4.2531 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 185/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3269 - eval_accuracy: 0.8576 - val_loss: 4.2556 - val_eval_accuracy: 0.8543 - lr: 4.0000e-04
# Epoch 186/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3242 - eval_accuracy: 0.8478 - val_loss: 4.2479 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 187/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3247 - eval_accuracy: 0.8526 - val_loss: 4.2430 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 188/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3238 - eval_accuracy: 0.8505 - val_loss: 4.2484 - val_eval_accuracy: 0.8551 - lr: 4.0000e-04
# Epoch 189/200
# 3/3 [==============================] - 0s 27ms/step - loss: 4.3252 - eval_accuracy: 0.8536 - val_loss: 4.2422 - val_eval_accuracy: 0.8558 - lr: 4.0000e-04
# Epoch 190/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3237 - eval_accuracy: 0.8577 - val_loss: 4.2507 - val_eval_accuracy: 0.8548 - lr: 4.0000e-04
# Epoch 191/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3244 - eval_accuracy: 0.8567 - val_loss: 4.2439 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 192/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3244 - eval_accuracy: 0.8558 - val_loss: 4.2408 - val_eval_accuracy: 0.8561 - lr: 4.0000e-04
# Epoch 193/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3270 - eval_accuracy: 0.8545 - val_loss: 4.2391 - val_eval_accuracy: 0.8563 - lr: 4.0000e-04
# Epoch 194/200
# 3/3 [==============================] - 0s 23ms/step - loss: 4.3255 - eval_accuracy: 0.8489 - val_loss: 4.2421 - val_eval_accuracy: 0.8559 - lr: 4.0000e-04
# Epoch 195/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3238 - eval_accuracy: 0.8560 - val_loss: 4.2438 - val_eval_accuracy: 0.8556 - lr: 4.0000e-04
# Epoch 196/200
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3236 - eval_accuracy: 0.8563 - val_loss: 4.2470 - val_eval_accuracy: 0.8553 - lr: 4.0000e-04
# Epoch 197/200
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3235 - eval_accuracy: 0.8552 - val_loss: 4.2525 - val_eval_accuracy: 0.8546 - lr: 4.0000e-04
# Epoch 198/200
# 3/3 [==============================] - 0s 27ms/step - loss: 4.3244 - eval_accuracy: 0.8559 - val_loss: 4.2457 - val_eval_accuracy: 0.8554 - lr: 4.0000e-04
# Epoch 199/200
# 3/3 [==============================] - 0s 29ms/step - loss: 4.3294 - eval_accuracy: 0.8595 - val_loss: 4.2492 - val_eval_accuracy: 0.8550 - lr: 4.0000e-04
# Epoch 200/200
# 3/3 [==============================] - 0s 33ms/step - loss: 4.3243 - eval_accuracy: 0.8556 - val_loss: 4.2531 - val_eval_accuracy: 0.8547 - lr: 4.0000e-04

# %%
import matplotlib.pyplot as plt

# 손실 그래프
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 훈련 및 검증 평가 지표 추출
train_accuracy = history.history['eval_accuracy']
val_accuracy = history.history['val_eval_accuracy']

# 평가 지표 그래프 그리기
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 세트 평가
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Loss:", round(loss, 3))
print("Test Accuracy:", round(accuracy, 3))
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: 4.4564 - eval_accuracy: 0.8737
# Test Loss: 4.456
# Test Accuracy: 0.874
# c:\Users\k10dh\anaconda3\envs\TeamProject\lib\site-packages\keras\engine\training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
