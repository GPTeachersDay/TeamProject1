# %% [markdown]
# # EDA : 강철판
#
# ## features
# 1. X_Minimum : X의 최소값
# 2. X_Maximum : X의 최대값
# 3. Y_Minimum : Y의 최소값
# 4. Y_Maximum : Y의 최대값
# 5. Pixels_Areas : 픽셀 영역 (오류가 발생한 강판의 영역을 픽셀로 표시한 크기)
# 6. X_Perimeter : X 주변의 길이 (오류가 발생한 강판의 X 방향 주변 길이)
# 7. Y_Perimeter : Y 주변의 길이 (오류가 발생한 강판의 Y 방향 주변 길이)
# 8. Sum_of_Luminosity : 휘도의 합 (오류가 발생한 강판 영역의 전체 휘도)
# 9. Minimum_of_Luminosity : 최소 휘도 (오류가 발생한 강판 영역의 최소 휘도)
# 10. Maximum_of_Luminosity : 최대 휘도 (오류가 발생한 강판 영역의 최대 휘도)
# 11. Length_of_Conveyer : 컨베이어의 길이
# 12. TypeOfSteel_A300 : A300 형 강판 여부
# 13. TypeOfSteel_A400 : A400 형 강판 여부
# 14. Steel_Plate_Thickness : 강판의 두께
# 15. Edges_Index : 가장자리 지수 (오류가 발생한 강판의 가장자리 형태를 나타내는 지표)
# 16. Empty_Index : 빈 공간 지수 (오류가 발생한 강판의 빈 공간을 나타내는 지표)
# 17. Square_Index : 정사각형 지수 (오류가 발생한 강판의 정사각형 형태를 나타내는 지표)
# 18. Outside_X_Index : 외부 X 지수 (오류가 발생한 강판의 X 방향 외부 형태를 나타내는 지표)
# 19. Edges_X_Index : 가장자리 X 지수 (오류가 발생한 강판의 X 방향 가장자리를 나타내는 지표)
# 20. Edges_Y_Index : 가장자리 Y 지수 (오류가 발생한 강판의 Y 방향 가장자리를 나타내는 지표)
# 21. Outside_Global_Index : 전체 외부 지수 (오류가 발생한 강판의 전체 외부 형태를 나타내는 지표)
# 22. LogOfAreas : 영역의 로그값
# 23. Log_X_Index : X 지수의 로그값
# 24. Log_Y_Index : Y 지수의 로그값
# 25. Orientation_Index : 방향 지수 (오류가 발생한 강판의 방향을 나타내는 지표)
# 26. Luminosity_Index : 휘도 지수 (오류가 발생한 강판의 휘도를 나타내는 지표)
# 27. SigmoidOfAreas : 영역의 시그모이드 함수 값 (이 함수는 보통 0과 1 사이의 결과를 내며, 여기서는 오류 영역의 특성을 나타낼 수 있습니다)
#
#
# ## target
# 1. Pastry : 페이스트리 결함, 이는 강판의 특정 부분이 너무 얇아져 결함이 발생한 경우를 의미할 수 있습니다.
# 2. Z_Scratch : Z 스크래치 결함, 강판에 'Z' 모양의 스크래치가 생긴 경우를 의미합니다.
# 3. K_Scatch : K 스크래치 결함, 강판에 'K' 모양의 스크래치가 생긴 경우를 의미합니다.
# 4. Stains : 얼룩 결함, 강판에 얼룩이나 불순물이 생긴 경우를 의미합니다.
# 5. Dirtiness : 더러움 결함, 강판이 더러워진 경우를 의미합니다.
# 6. Bumps : 돌기 결함, 강판에 돌기나 울퉁불퉁한 부분이 생긴 경우를 의미합니다.
# 7. Other_Faults : 기타 결함, 위의 카테고리에 속하지 않는 기타 다른 종류의 결함을 의미합니다.
#
#
# ## Domain
# 강판 결함 분석은 제조 공정에서 중요한 부분입니다.
# 강판은 건축, 자동차, 선박, 가전제품 등 다양한 산업에서 사용되는 주요 소재이기 때문에, 그 품질은 최종 제품의 품질에 직접적인 영향을 미칩니다.
# 따라서 강판의 결함을 정확하게 감지하고 분류하는 것은 제조 효율성, 안전성, 그리고 경제성을 높이는 데 매우 중요합니다.
#
# 1. 강판의 특성:
# 강판의 결함은 종류와 크기에 따라 다양하게 나타날 수 있습니다.
# 결함의 유형에는 표면상의 불규칙한 부분, 두께의 불규칙, 재질 결함, 구조적 결함 등이 있을 수 있습니다.
#
# 2. 제조 공정:
# 강판 제조 공정에서의 다양한 단계에서 결함이 발생할 수 있습니다.
# 예를 들어, 제련, 주조, 압연, 열처리, 표면 마무리 등의 단계에서 결함이 발생할 수 있으며, 이는 최종 제품의 품질에 영향을 미칩니다.
#
# 3. 감지 기술:
# 강판 결함 감지는 시각 검사, 자동 결함 감지 시스템, 비파괴 검사 등 다양한 방법으로 수행될 수 있습니다.
# 머신 러닝 및 AI는 이러한 결함 감지 작업을 자동화하고 정확성을 높이는 데 도움이 될 수 있습니다.
#
# 4. 분석 및 품질 관리:
# 결함 분석은 결함의 원인을 찾고, 제조 공정을 개선하여 향후 결함을 방지하는 데 사용됩니다.
# 또한, 강판의 품질은 ISO 등의 국제 표준에 따라 평가되고 관리됩니다.
#
#
# ## Workflow
# 1. 기본 통계량 확인
# 2. 결측치 확인
# 3. 상관 분석
# 4. 분포 확인
# 5. 카테고리별 분석
# 6. 피처 중요도 분석
#
#
# ## Reference
# - https://www.kaggle.com/datasets/uciml/faulty-steel-plates
# - https://www.kaggle.com/code/tahazafar/steel-plate-faults-data-analysis/notebook
# - https://mindcompass.github.io/data_analysis/data_analysis(test2_1)/

# %% [markdown]
# ## EDA

# %%
# 필요한 라이브러리 불러오기
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix

from collections import Counter


# 각종 변수 선언
csv_path = '../data/mulit_classification_data.csv'
save_path = '../../../../../Git_Blog/assets/images/aib/GPTeachersDay/'
save_mode = 0

# %%
df = pd.read_csv(csv_path)
df.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %%
temp_df = pd.DataFrame({
    'Pixels_Areas' : df['Pixels_Areas'],
    'Area' : (df['X_Maximum'] - df['X_Minimum']) * (df['Y_Maximum'] - df['Y_Minimum'])
})
temp_df
# Out:
#       Pixels_Areas  Area
# 0              267   352
# 1              108   174
# 2               71   108
# 3              176   315
# 4             2409  4369
# ...            ...   ...
# 1936           273   448
# 1937           287   527
# 1938           292   435
# 1939           419  1023
# 1940           103   320
#
# [1941 rows x 2 columns]

# %% [markdown]
# ### Data Structure
# - 데이터 구조
#   - 데이터 개수 : 1,941
#   - 특성 개수 : 26
#   - 타겟 : 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults'
# - 결측 없음
# - 중복값 없음

# %%
print(f'✅ 중복값 개수 : {df.duplicated().sum()}')
df.info()
# Out:
# ✅ 중복값 개수 : 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941 entries, 0 to 1940
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Minimum              1941 non-null   int64
#  1   X_Maximum              1941 non-null   int64
#  2   Y_Minimum              1941 non-null   int64
#  3   Y_Maximum              1941 non-null   int64
#  4   Pixels_Areas           1941 non-null   int64
#  5   X_Perimeter            1941 non-null   int64
#  6   Y_Perimeter            1941 non-null   int64
#  7   Sum_of_Luminosity      1941 non-null   int64
#  8   Minimum_of_Luminosity  1941 non-null   int64
#  9   Maximum_of_Luminosity  1941 non-null   int64
#  10  Length_of_Conveyer     1941 non-null   int64
#  11  TypeOfSteel_A300       1941 non-null   int64
#  12  TypeOfSteel_A400       1941 non-null   int64
#  13  Steel_Plate_Thickness  1941 non-null   int64
# ...

# %%
df.describe(include="all")
# Out:
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1941.000000  1941.000000  1.941000e+03  1.941000e+03    1941.000000
# mean    571.136012   617.964451  1.650685e+06  1.650739e+06    1893.878413
# std     520.690671   497.627410  1.774578e+06  1.774590e+06    5168.459560
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      51.000000   192.000000  4.712530e+05  4.712810e+05      84.000000
# 50%     435.000000   467.000000  1.204128e+06  1.204136e+06     174.000000
# 75%    1053.000000  1072.000000  2.183073e+06  2.183084e+06     822.000000
# max    1705.000000  1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000   1941.000000       1.941000e+03            1941.000000
# mean     111.855229     82.965997       2.063121e+05              84.548686
# ...

# %% [markdown]
# ### Target
# - 타겟변수 : 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults'
# - 'Other Faults', 'Bumps', 'K_Scatch'가 대부분을 비율을 차지하고 있습니다.

# %%
y_list = list(df.iloc[:,-7:].columns)
df["Type"] = df.loc[:,y_list][y_list].idxmax(axis=1)
df = df.drop(columns=y_list)
df["Type"].value_counts()
# Out:
# Other_Faults    673
# Bumps           402
# K_Scatch        391
# Z_Scratch       190
# Pastry          158
# Stains           72
# Dirtiness        55
# Name: Type, dtype: int64

# %%
df['Type'].value_counts().index
# Out:
# Index(['Other_Faults', 'Bumps', 'K_Scatch', 'Z_Scratch', 'Pastry', 'Stains',
#        'Dirtiness'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, 2, figsize=(14,5))

text_dic = dict(rotation=-15, size=11, color="black")
ax[0].pie(x=df['Type'].value_counts().values,
    labels=df['Type'].value_counts().index,
    radius=1,
    autopct=lambda pct : f'{pct:.2f}%' if pct>5 else '',
    textprops=text_dic,
    pctdistance=0.7,
    startangle=90,
    colors = sns.color_palette('Set3'),
    wedgeprops={'width':0.5, 'edgecolor':'w', 'linewidth':2},
    counterclock=False)

sns.countplot(data=df, x='Type'
              , palette = sns.color_palette('Set3')
              , order=df['Type'].value_counts().index
              , ax=ax[1])

if save_mode:
    fig.savefig(save_path + 'steel_targets.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ### Features
# - `Y_Minimum`과 `Y_Maximum`에서 이상치로 의심되는 케이스가 보입니다.
# - 값차이가 커서 적절한 스케일링이 필요합니다.

# %%
df.iloc[:,:-1].describe()
# Out:
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1941.000000  1941.000000  1.941000e+03  1.941000e+03    1941.000000
# mean    571.136012   617.964451  1.650685e+06  1.650739e+06    1893.878413
# std     520.690671   497.627410  1.774578e+06  1.774590e+06    5168.459560
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      51.000000   192.000000  4.712530e+05  4.712810e+05      84.000000
# 50%     435.000000   467.000000  1.204128e+06  1.204136e+06     174.000000
# 75%    1053.000000  1072.000000  2.183073e+06  2.183084e+06     822.000000
# max    1705.000000  1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000   1941.000000       1.941000e+03            1941.000000
# mean     111.855229     82.965997       2.063121e+05              84.548686
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.boxplot(df.iloc[:,:-1])
ax.xaxis.set_major_locator(mticker.FixedLocator(ax.get_xticks()))
ax.set_xticklabels(list(df.iloc[:,:-1].columns), rotation=80)
if save_mode:
    fig.savefig(save_path + 'steel_boxplot.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ### Correlation
# <p>• 일부 특성 사이에 강한 상관관계가 있어 다중공선성의 문제를 해결해야 합니다.</p>

# %%
corr = df.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize=(24, 20))
sns.heatmap(corr,
            cmap="RdYlBu_r",
            annot=True,
            annot_kws = {'size':12},
            mask=mask,
            fmt='.2f',
            linewidths=.5,
            cbar_kws={"shrink": .5})

plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_heatmap1.png', dpi=80, bbox_inches='tight')
# Out:
# C:\Users\leeyeonjun85\AppData\Local\Temp\ipykernel_71392\1159359484.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# C:\Users\leeyeonjun85\AppData\Local\Temp\ipykernel_71392\1159359484.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
df.columns
# Out:
# Index(['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
#        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'Type'],
#       dtype='object')

# %%
# 상관계수 0.95 이상 컬럼 제거
multicollinearity_list = ['X_Minimum', 'Y_Minimum', 'Pixels_Areas', 'TypeOfSteel_A300']
corr = df.drop(columns=multicollinearity_list).corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize=(24, 20))
sns.heatmap(corr,
            cmap="RdYlBu_r",
            annot=True,
            annot_kws = {'size':12},
            mask=mask,
            fmt='.2f',
            linewidths=.5,
            cbar_kws={"shrink": .5})

plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_heatmap2.png', dpi=80, bbox_inches='tight')
# Out:
# C:\Users\leeyeonjun85\AppData\Local\Temp\ipykernel_71392\1390443681.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.drop(columns=multicollinearity_list).corr()
# C:\Users\leeyeonjun85\AppData\Local\Temp\ipykernel_71392\1390443681.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %% [markdown]
# ## Export Report

# %%
# from ydata_profiling import ProfileReport
# df_report = ProfileReport(df, title='Steel Profile Report')
# df_report.to_file('eda_steel.html')

# %% [markdown]
# ## Predict Model

# %%
def load_dataset(csv_path, TRAIN_RATIO=0.8):
    
    # 데이터셋 로드
    df = pd.read_csv(csv_path)
    
    # 타겟 변수 생성
    y_list = list(df.iloc[:,-7:].columns)
    df["Type"] = df.loc[:,y_list][y_list].idxmax(axis=1)
    df = df.drop(columns=y_list)
    df["Type"].value_counts()
    
    # 학습 데이터 분리
    X_df = df.drop('Type', axis=1)
    y_df = df['Type']
    X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, train_size=TRAIN_RATIO, random_state = 83)
    
    # 표준화
    scaler=StandardScaler() 
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    X_train = pd.DataFrame(X_train, columns=X_df.columns)
    X_test = pd.DataFrame(X_test, columns=X_df.columns)

    return df, X_df, y_df, X_train, X_test, y_train, y_test

# 데이터 불러오기
df, X_df, y_df, X_train, X_test, y_train, y_test = load_dataset(csv_path)

# 타겟 라벨인코딩
encoder = LabelEncoder()
y_train, y_test = encoder.fit_transform(y_train), encoder.fit_transform(y_test)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

def get_metrics(model, X, y):
    y_pred=model.predict(X)
    
    Precision    = metrics.precision_score (y, y_pred, average="weighted")
    Recall       = metrics.recall_score    (y, y_pred, average="weighted")
    Accuracy     = metrics.accuracy_score  (y, y_pred)
    F1           = metrics.f1_score        (y, y_pred, average="weighted")
    
    print(f'Precision Score  : {Precision}')
    print(f'Recall Score     : {Recall}')
    print(f'Accuracy Score   : {Accuracy}')
    print(f'F1 Score         : {F1}')
    return Precision, Recall, Accuracy, F1
# Out:
# (1552, 27) (389, 27) (1552,) (389,)

# %%
# 라벨인코딩된 타겟 범주 복구하기
print(encoder.classes_)
encoder.inverse_transform(y_train)
# Out:
# ['Bumps' 'Dirtiness' 'K_Scatch' 'Other_Faults' 'Pastry' 'Stains'
#  'Z_Scratch']
# array(['Other_Faults', 'K_Scatch', 'Bumps', ..., 'Bumps', 'Other_Faults',
#        'Pastry'], dtype=object)

# %%
X_train.iloc[:,:-1].describe().loc[['mean','min','max']].style.set_precision(2)
# Out:
# C:\Users\leeyeonjun85\AppData\Local\Temp\ipykernel_71392\593051333.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   X_train.iloc[:,:-1].describe().loc[['mean','min','max']].style.set_precision(2)
# <style type="text/css">
# </style>
# <table id="T_4c934">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c934_level0_col0" class="col_heading level0 col0" >X_Minimum</th>
#       <th id="T_4c934_level0_col1" class="col_heading level0 col1" >X_Maximum</th>
#       <th id="T_4c934_level0_col2" class="col_heading level0 col2" >Y_Minimum</th>
#       <th id="T_4c934_level0_col3" class="col_heading level0 col3" >Y_Maximum</th>
#       <th id="T_4c934_level0_col4" class="col_heading level0 col4" >Pixels_Areas</th>
#       <th id="T_4c934_level0_col5" class="col_heading level0 col5" >X_Perimeter</th>
#       <th id="T_4c934_level0_col6" class="col_heading level0 col6" >Y_Perimeter</th>
# ...

# %% [markdown]
# ### Base Model
# - 최빈값 기준모델 사용

# %%
# Base Model : 최빈값
y_max = Counter(y_train).most_common(1)[0][0]
y_pred = np.array([y_max] * len(y_test))

print(f'Base Model Precision    : {metrics.precision_score (y_test, y_pred, average="weighted"):.3f}')
print(f'Base Model Recall       : {metrics.recall_score    (y_test, y_pred, average="weighted"):.3f}')
print(f'Base Model Accuracy     : {metrics.accuracy_score  (y_test, y_pred):.3f}')
print(f'Base Model F1           : {metrics.f1_score        (y_test, y_pred, average="weighted"):.3f}')
# Out:
# Base Model Precision    : 0.133
# Base Model Recall       : 0.365
# Base Model Accuracy     : 0.365
# Base Model F1           : 0.195
# c:\Users\leeyeonjun85\.conda\envs\p310_1\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Logistic Regression Model

# %%
model_lg_all=LogisticRegression(random_state=83)
model_lg_all.fit(X_train, y_train)

lg_precision_train, lg_recall_train, lg_accuracy_train, lg_f1_train = get_metrics(model_lg_all, X_train, y_train)
print('='*100)
lg_precision_test, lg_recall_test, lg_accuracy_test, lg_f1_test = get_metrics(model_lg_all, X_test, y_test)
# Out:
# Precision Score  : 0.7312053079421882
# Recall Score     : 0.7319587628865979
# Accuracy Score   : 0.7319587628865979
# F1 Score         : 0.7300944405385978
# ...
# Precision Score  : 0.7396843860646829
# Recall Score     : 0.7352185089974294
# Accuracy Score   : 0.7352185089974294
# F1 Score         : 0.7362794259199159
# c:\Users\leeyeonjun85\.conda\envs\p310_1\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
c_mat = confusion_matrix(y_test, model_lg_all.predict(X_test))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(14,13))
fig.suptitle('Confusion Matrix', fontsize = 28, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,
            cbar_kws = {'shrink': .5},
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_lg_cm.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ### Random Forest Classifier Model

# %%
model_rf_all = RandomForestClassifier(random_state=83)
model_rf_all.fit(X_train, y_train)

rf_precision_train, rf_recall_train, rf_accuracy_train, rf_f1_train = get_metrics(model_rf_all, X_train, y_train)
print('='*100)
rf_precision_test, rf_recall_test, rf_accuracy_test, rf_f1_test = get_metrics(model_rf_all, X_test, y_test)
# Out:
# Precision Score  : 1.0
# Recall Score     : 1.0
# Accuracy Score   : 1.0
# F1 Score         : 1.0
# ...
# Precision Score  : 0.7975582630613092
# Recall Score     : 0.7866323907455013
# Accuracy Score   : 0.7866323907455013
# F1 Score         : 0.789146418592701

# %%
c_mat = confusion_matrix(y_test, model_rf_all.predict(X_test))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(14,13))
fig.suptitle('Confusion Matrix', fontsize = 28, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,
            cbar_kws = {'shrink': .5},
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_rf_cm.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ### Gradient Boosting Classifier Model

# %%
model_gb_all = GradientBoostingClassifier(random_state=83)
model_gb_all.fit(X_train, y_train)

gb_precision_train, gb_recall_train, gb_accuracy_train, gb_f1_train = get_metrics(model_gb_all, X_train, y_train)
print('='*100)
gb_precision_test, gb_recall_test, gb_accuracy_test, gb_f1_test = get_metrics(model_gb_all, X_test, y_test)
# Out:
# Precision Score  : 0.9748512901371206
# Recall Score     : 0.9748711340206185
# Accuracy Score   : 0.9748711340206185
# F1 Score         : 0.9748604098017101
# ...
# Precision Score  : 0.783480406772955
# Recall Score     : 0.7737789203084833
# Accuracy Score   : 0.7737789203084833
# F1 Score         : 0.7766428674317828

# %%
c_mat = confusion_matrix(y_test, model_gb_all.predict(X_test))

# 히트맵을 그린다
fig, ax = plt.subplots(figsize=(14,13))
fig.suptitle('Confusion Matrix', fontsize = 28, fontweight = 'bold', y = 0.93)
sns.heatmap(c_mat, 
            cmap = sns.color_palette('Blues'), 
            annot = True,
            annot_kws = {'fontweight':'bold','size':14},
            fmt=',.0f',
            linewidths = 2,
            cbar_kws = {'shrink': .5},
           )

ax.xaxis.set_ticklabels(encoder.classes_); ax.yaxis.set_ticklabels(encoder.classes_)
plt.xlabel('Predicte - Y', fontsize = 14)
plt.ylabel('True - Y', fontsize = 14)
plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_gb_cm.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ### ML Model Compare
#
# <p>• 머신러닝 모델들의 Accuracy평가지표는 레거시모델의 Accuracy보다 높습니다.</p>

# %%
# Metrics to DataFrame
metrics_df = pd.DataFrame({
    'Train Precision' : [lg_precision_train, rf_precision_train, gb_precision_train],
    'Test Precision'  : [lg_precision_test, rf_precision_test, gb_precision_test],
    'Train Recall' : [lg_recall_train, rf_recall_train, gb_recall_train],
    'Test Recall'  : [lg_recall_test, rf_recall_test, gb_recall_test],
    'Train Accuracy' : [lg_accuracy_train, rf_accuracy_train, gb_accuracy_train],
    'Test Accuracy'  : [lg_accuracy_test, rf_accuracy_test, gb_accuracy_test],
    'Train F1' : [lg_f1_train, rf_f1_train, gb_f1_train],
    'Test F1'  : [lg_f1_test, rf_f1_test, gb_f1_test],
})

# 그래프 그리기
fig = plt.figure(figsize=(20, 4))
fig.suptitle('ML Model Compare', fontsize = 24, fontweight = 'bold', y = 1)

x_label = ['Linear Regression', 'Random Forest', 'Gradient Boosting']

ax = plt.subplot(1, 4, 1)
plt.title('Precision Score', fontsize = 16, y = 1)
plt.bar(x_label, metrics_df['Test Precision'], color=sns.color_palette('Set3'))
plt.plot(metrics_df['Train Precision'], marker='o', label='Train Data')
# plt.axhline(y=0.926, color='r', linewidth=2, label='Legacy Model')
ax.xaxis.set_major_locator(mticker.FixedLocator(ax.get_xticks()))
ax.set_xticklabels(x_label, rotation=20, fontsize=12)

ax = plt.subplot(1, 4, 2)
plt.title('Recall Score', fontsize = 16, y = 1)
plt.bar(x_label, metrics_df['Test Recall'], color=sns.color_palette('Set3'))
plt.plot(metrics_df['Train Recall'], marker='o', label='Train Data')
# plt.axhline(y=0.789, color='r', linewidth=2, label='Legacy Model')
ax.xaxis.set_major_locator(mticker.FixedLocator(ax.get_xticks()))
ax.set_xticklabels(x_label, rotation=20, fontsize=12)

ax = plt.subplot(1, 4, 3)
plt.title('Accuracy Score', fontsize = 16, y = 1)
plt.bar(x_label, metrics_df['Test Accuracy'], color=sns.color_palette('Set3'), label='Test Data')
plt.plot(metrics_df['Train Accuracy'], marker='o', label='Train Data')
plt.axhline(y=0.412, color='r', linewidth=2, label='Legacy Model')
ax.xaxis.set_major_locator(mticker.FixedLocator(ax.get_xticks()))
ax.set_xticklabels(x_label, rotation=20, fontsize=12)
plt.legend(fontsize=12, loc=(-1.1, 0.2))

ax = plt.subplot(1, 4, 4)
plt.title('F1 Score', fontsize = 16, y = 1)
plt.bar(x_label, metrics_df['Test F1'], color=sns.color_palette('Set3'))
plt.plot(metrics_df['Train F1'], marker='o', label='Train Data')
# plt.axhline(y=0.852, color='r', linewidth=2, label='Legacy Model')
ax.xaxis.set_major_locator(mticker.FixedLocator(ax.get_xticks()))
ax.set_xticklabels(x_label, rotation=20, fontsize=12)


plt.subplots_adjust(right=0.85, left=0.15, top=0.85, bottom=0.15, wspace=0.3, hspace=0.2)
plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_ml_models.png', dpi=80, bbox_inches='tight')

# %% [markdown]
# ## Feature Importance
#
# ### RF Top6
# Length_of_Conveyer, Pixels_Areas, LogOfAreas, Outside_X_Index, Steel_Plate_Thickness, Sum_of_Luminosity
#
# ### GB Top6
# Log_X_Index, Steel_Plate_Thickness, Length_of_Conveyer, Outside_X_Index, Orientation_Index, TypeOfSteel_A400
#
# ### 공통 top6
# Length_of_Conveyer, Outside_X_Index, Steel_Plate_Thickness

# %%
# Mean Decrease Impurity
MDI_rf = pd.DataFrame({ 'feature':X_test.columns, 'MDI':model_rf_all.feature_importances_}).sort_values(by='MDI', ascending=True)
print(MDI_rf.sort_values(by='MDI', ascending=False))

# Graph
fig = plt.figure(figsize=(10, 6))
plt.title('Mean Decrease Impurity : Random Forest', fontsize=16)
plt.barh(MDI_rf.feature, MDI_rf.MDI, color=sns.color_palette('Set3'))
plt.axvline(MDI_rf.MDI.mean(), color="red", label="Mean")
plt.legend(fontsize=10, loc=(0.7, 0.1))

plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_mdi_rf.png', dpi=80, bbox_inches='tight')
# Out:
#                   feature       MDI
# 10     Length_of_Conveyer  0.063488
# 4            Pixels_Areas  0.062418
# 21             LogOfAreas  0.061183
# 17        Outside_X_Index  0.054972
# 13  Steel_Plate_Thickness  0.053246
# 7       Sum_of_Luminosity  0.050045
# 22            Log_X_Index  0.046905
# 1               X_Maximum  0.042895
# 0               X_Minimum  0.042077
# 8   Minimum_of_Luminosity  0.041148
# 24      Orientation_Index  0.039621
# 2               Y_Minimum  0.036906
# 16           Square_Index  0.034381
# 3               Y_Maximum  0.034299
# 25       Luminosity_Index  0.033143
# 14            Edges_Index  0.031548
# 15            Empty_Index  0.031309
# 5             X_Perimeter  0.031091
# 9   Maximum_of_Luminosity  0.031079
# 18          Edges_X_Index  0.029984
# 19          Edges_Y_Index  0.026946
# 26         SigmoidOfAreas  0.025722
# 6             Y_Perimeter  0.025403
# 23            Log_Y_Index  0.023362
# 11       TypeOfSteel_A300  0.022667
# ...

# %%
# Mean Decrease Impurity
MDI_gb = pd.DataFrame({ 'feature':X_test.columns, 'MDI':model_gb_all.feature_importances_}).sort_values(by='MDI', ascending=True)
print(MDI_gb.sort_values(by='MDI', ascending=False))

# Graph
fig = plt.figure(figsize=(10, 6))
plt.title('Mean Decrease Impurity : Gradient Boosting', fontsize=16)
plt.barh(MDI_gb.feature, MDI_gb.MDI, color=sns.color_palette('Set3'))
plt.axvline(MDI_gb.MDI.mean(), color="red", label="Mean")
plt.legend(fontsize=10, loc=(0.7, 0.1))

plt.show()

if save_mode:
    fig.savefig(save_path + 'steel_mdi_gb.png', dpi=80, bbox_inches='tight')
# Out:
#                   feature       MDI
# 22            Log_X_Index  0.131902
# 13  Steel_Plate_Thickness  0.104832
# 10     Length_of_Conveyer  0.103990
# 17        Outside_X_Index  0.082412
# 24      Orientation_Index  0.050174
# 12       TypeOfSteel_A400  0.050107
# 0               X_Minimum  0.047113
# 4            Pixels_Areas  0.044119
# 11       TypeOfSteel_A300  0.040007
# 16           Square_Index  0.035434
# 8   Minimum_of_Luminosity  0.034684
# 2               Y_Minimum  0.030468
# 14            Edges_Index  0.026301
# 19          Edges_Y_Index  0.025520
# 15            Empty_Index  0.024639
# 21             LogOfAreas  0.023780
# 1               X_Maximum  0.023063
# 3               Y_Maximum  0.022495
# 25       Luminosity_Index  0.022145
# 7       Sum_of_Luminosity  0.014003
# 9   Maximum_of_Luminosity  0.013821
# 6             Y_Perimeter  0.013532
# 18          Edges_X_Index  0.012631
# 23            Log_Y_Index  0.007989
# 26         SigmoidOfAreas  0.006993
# ...

# %% [markdown]
# ### 다중공선성 의심 특성 제거

# %%
multicollinearity_list = ['X_Minimum', 'Y_Minimum', 'Pixels_Areas', 'TypeOfSteel_A300']

X_train_cr = X_train.drop(columns=multicollinearity_list)
X_test_cr = X_test.drop(columns=multicollinearity_list)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, )
# Out:
# (1552, 27) (389, 27) (1552,) (389,)

# %%
model_lg_cr=LogisticRegression(random_state=83)
model_lg_cr.fit(X_train_cr, y_train)

lg_precision_train_cr, lg_recall_train_cr, lg_accuracy_train_cr, lg_f1_train_cr = get_metrics(model_lg_cr, X_train_cr, y_train)
print('='*100)
lg_precision_test_cr, lg_recall_test_cr, lg_accuracy_test_cr, lg_f1_test_cr = get_metrics(model_lg_cr, X_test_cr, y_test)
# Out:
# Precision Score  : 0.7316214625483914
# Recall Score     : 0.7326030927835051
# Accuracy Score   : 0.7326030927835051
# F1 Score         : 0.7308328244389304
# ...
# Precision Score  : 0.7432774598688832
# Recall Score     : 0.7377892030848329
# Accuracy Score   : 0.7377892030848329
# F1 Score         : 0.7391554815799818
# c:\Users\leeyeonjun85\.conda\envs\p310_1\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model_rf_cr = RandomForestClassifier(random_state=83, max_depth=8)
model_rf_cr.fit(X_train, y_train)

rf_precision_train_cr, rf_recall_train_cr, rf_accuracy_train_cr, rf_f1_train_cr = get_metrics(model_rf_cr, X_train, y_train)
print('='*100)
rf_precision_test_cr, rf_recall_test_cr, rf_accuracy_test_cr, rf_f1_test_cr = get_metrics(model_rf_cr, X_test, y_test)
# Out:
# Precision Score  : 0.8790620832249999
# Recall Score     : 0.8704896907216495
# Accuracy Score   : 0.8704896907216495
# F1 Score         : 0.8708805013772631
# ...
# Precision Score  : 0.7672785467638953
# Recall Score     : 0.7532133676092545
# Accuracy Score   : 0.7532133676092545
# F1 Score         : 0.7545105783010666

# %%
model_gb_cr = GradientBoostingClassifier(random_state=83, max_depth=3)
model_gb_cr.fit(X_train, y_train)

gb_precision_train_cr, gb_recall_train_cr, gb_accuracy_train_cr, gb_f1_train_cr = get_metrics(model_gb_cr, X_train, y_train)
print('='*100)
gb_precision_test_cr, gb_recall_test_cr, gb_accuracy_test_cr, gb_f1_test_cr = get_metrics(model_gb_cr, X_test, y_test)
# Out:
# Precision Score  : 0.9748512901371206
# Recall Score     : 0.9748711340206185
# Accuracy Score   : 0.9748711340206185
# F1 Score         : 0.9748604098017101
# ...
# Precision Score  : 0.783480406772955
# Recall Score     : 0.7737789203084833
# Accuracy Score   : 0.7737789203084833
# F1 Score         : 0.7766428674317828

# %%
metrics_df = pd.DataFrame({
    'score_name' : [
                    'Precision', 'Precision', 
                    'Precision', 'Precision', 
                    'Precision', 'Precision', 
                    'Recall', 'Recall', 
                    'Recall', 'Recall', 
                    'Recall', 'Recall', 
                    'Accuracy', 'Accuracy', 
                    'Accuracy', 'Accuracy', 
                    'Accuracy', 'Accuracy', 
                    'F1', 'F1', 
                    'F1', 'F1', 
                    'F1', 'F1', 
                    ],
    'model_name' : [
                    'Logistic Regression', 'Logistic Regression', 
                    'Random Forest', 'Random Forest', 
                    'Gradient Boosting', 'Gradient Boosting', 
                    'Logistic Regression', 'Logistic Regression', 
                    'Random Forest', 'Random Forest', 
                    'Gradient Boosting', 'Gradient Boosting', 
                    'Logistic Regression', 'Logistic Regression', 
                    'Random Forest', 'Random Forest', 
                    'Gradient Boosting', 'Gradient Boosting', 
                    'Logistic Regression', 'Logistic Regression', 
                    'Random Forest', 'Random Forest', 
                    'Gradient Boosting', 'Gradient Boosting', 
                    ],
    'data_name' : [
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    'Train', 'Test', 
                    ],
    'Whole Features' : [
                    lg_precision_train, lg_precision_test,
                    rf_precision_train, rf_precision_test,
                    gb_precision_train, gb_precision_test,
                    lg_recall_train, lg_recall_test,
                    rf_recall_train, rf_recall_test,
                    gb_recall_train, gb_recall_test,
                    lg_accuracy_train, lg_accuracy_test,
                    rf_accuracy_train, rf_accuracy_test,
                    gb_accuracy_train, gb_accuracy_test,
                    lg_f1_train, lg_f1_test,
                    rf_f1_train, rf_f1_test,
                    gb_f1_train, gb_f1_test,
                        ],
    'Except Correlation' : [
                    lg_precision_train_cr, lg_precision_test_cr,
                    rf_precision_train_cr, rf_precision_test_cr,
                    gb_precision_train_cr, gb_precision_test_cr,
                    lg_recall_train_cr, lg_recall_test_cr,
                    rf_recall_train_cr, rf_recall_test_cr,
                    gb_recall_train_cr, gb_recall_test_cr,
                    lg_accuracy_train_cr, lg_accuracy_test_cr,
                    rf_accuracy_train_cr, rf_accuracy_test_cr,
                    gb_accuracy_train_cr, gb_accuracy_test_cr,
                    lg_f1_train_cr, lg_f1_test_cr,
                    rf_f1_train_cr, rf_f1_test_cr,
                    gb_f1_train_cr, gb_f1_test_cr,
                                ],
})
metrics_df = metrics_df.set_index(['score_name','model_name','data_name'])

if save_mode:
    metrics_df.style.background_gradient(axis=1).to_excel(save_path + 'steel_compare.xlsx')

metrics_df.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_03f65_row0_col0, #T_03f65_row1_col0, #T_03f65_row2_col1, #T_03f65_row3_col1, #T_03f65_row4_col0, #T_03f65_row4_col1, #T_03f65_row5_col0, #T_03f65_row5_col1, #T_03f65_row6_col0, #T_03f65_row7_col0, #T_03f65_row8_col1, #T_03f65_row9_col1, #T_03f65_row10_col0, #T_03f65_row10_col1, #T_03f65_row11_col0, #T_03f65_row11_col1, #T_03f65_row12_col0, #T_03f65_row13_col0, #T_03f65_row14_col1, #T_03f65_row15_col1, #T_03f65_row16_col0, #T_03f65_row16_col1, #T_03f65_row17_col0, #T_03f65_row17_col1, #T_03f65_row18_col0, #T_03f65_row19_col0, #T_03f65_row20_col1, #T_03f65_row21_col1, #T_03f65_row22_col0, #T_03f65_row22_col1, #T_03f65_row23_col0, #T_03f65_row23_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# ...
