# %%
# import os
# print(f"✅ 현재 위치 : {os.getcwd()}")

# 클래스 코드 수정시 캐시된 파이선파일 재설정
import model1
import imp
imp.reload(model1)

# 클래스 불러오기
import model1
from model1 import *

# 모델 인스턴스 생성
ref_model = Model_1()

# 데이터 불러오기
csv_path='../../Data/Regression_data.csv'
df, X, y, X_train, X_test, y_train, y_test = ref_model.load_data(csv_path)

# 모델 빌드
model = ref_model.get_model(len(X_train.columns))

# 저장된 가중치 불러와서 테스트데이터 평가
model.load_weights('model1.h5')
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss : {loss:.3f}\nAccuracy  : {accuracy:.3f}')

import json
with open('model1.json') as json_file:
    json_file = json.loads(json_file.read())
model1_hist = pd.DataFrame(json_file)
model1_hist
# Out:
# 26/26 [==============================] - 1s 14ms/step - loss: 5.3474 - accuracy: 0.9035
# Test Loss : 5.347
# Accuracy  : 0.904
#            loss  accuracy    val_loss  val_accuracy            lr
# 0    111.622696 -0.005186  110.771545      0.000827  1.000000e-03
# 1    110.471153  0.001704  110.526772      0.001805  9.999975e-04
# 2    109.750801 -0.000235  110.335564      0.002405  9.999902e-04
# 3    108.501114  0.000158  110.240364      0.002533  9.999779e-04
# 4    107.790031 -0.001891  110.174461      0.002463  9.999606e-04
# ..          ...       ...         ...           ...           ...
# 995    7.199337  0.811652    5.385863      0.853010  6.170000e-08
# 996    7.417943  0.803587    5.385948      0.853024  3.950000e-08
# 997    7.605025  0.787362    5.384201      0.853029  2.220000e-08
# 998    7.572842  0.792730    5.385278      0.853029  9.900000e-09
# 999    7.236722  0.793238    5.385430      0.853022  2.500000e-09
#
# [1000 rows x 5 columns]
