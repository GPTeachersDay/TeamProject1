# %%
# import os
# print(f"✅ 현재 위치 : {os.getcwd()}")

# 클래스 코드 수정시 캐시된 파이선파일 재설정
import model1
import imp
imp.reload(model1)

# 클래스 불러오기
import model1
from model1 import *

# 모델 인스턴스 생성
ref_model = Model_1()

# 데이터 불러오기
csv_path='../../Data/Regression_data.csv'
df, X, y, X_train, X_test, y_train, y_test = ref_model.load_data(csv_path)

# 모델 빌드
model = ref_model.get_model(len(X_train.columns), node_n=12, dout=0.1)

# 저장된 가중치 불러와서 테스트데이터 평가
model.load_weights('model1.h5')
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss : {loss:.3f}\nAccuracy  : {accuracy:.3f}')

import json
with open('model1.json') as json_file:
    json_file = json.loads(json_file.read())
model1_hist = pd.DataFrame(json_file)
model1_hist
# Out:
# 27/27 [==============================] - 1s 9ms/step - loss: 5.3877 - accuracy: 0.9174
# Test Loss : 5.388
# Accuracy  : 0.917
#            loss  accuracy    val_loss  val_accuracy            lr
# 0    115.152763 -0.022830  110.657150     -0.007578  1.000000e-03
# 1    114.421059 -0.021702  110.377846     -0.006207  9.999975e-04
# 2    113.298431 -0.018546  110.122093     -0.004940  9.999902e-04
# 3    112.600449 -0.020522  109.900200     -0.003867  9.999779e-04
# 4    111.492256 -0.016751  109.712326     -0.002999  9.999606e-04
# ..          ...       ...         ...           ...           ...
# 995    8.952813  0.780854    5.838498      0.829763  6.170000e-08
# 996    9.353971  0.774432    5.837861      0.829828  3.950000e-08
# 997    8.717520  0.780295    5.837824      0.829816  2.220000e-08
# 998    9.044662  0.778915    5.838986      0.829806  9.900000e-09
# 999    8.704660  0.780729    5.838577      0.829860  2.500000e-09
#
# [1000 rows x 5 columns]
