# %% [markdown]
# # 데이터 로드

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f25386d3-7c21-4769-803c-e7fd3f633a16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f25386d3-7c21-4769-803c-e7fd3f633a16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 
df = pd.read_csv('Regression_data.csv')
df=pd.get_dummies(df,columns=['Sex'])
df
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
# ...

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# Sex_F           0.309666  0.318626  0.298421      0.299741        0.263991
# Sex_I          -0.551465 -0.564315 -0.518552     -0.557592       -0.521842
# Sex_M           0.236543  0.240376  0.215459      0.252038        0.251793
#
# ...

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings        Sex_F        Sex_I  \
# count     4177.000000   4177.000000  4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684     0.312904     0.321283
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
def load_dataset(csv_path, TRAIN_RATIO=0.8):
    
    # 데이터셋 로드
    df = pd.read_csv(csv_path)
    
    # 성별 원핫 인코딩
    df=pd.get_dummies(df,columns=['Sex'])
    
    # 학습 데이터 분리
    X = df.drop('Rings', axis=1)
    y = df['Rings']
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=TRAIN_RATIO, random_state = 83)
    y_train = y_train.astype('float32')
    y_test = y_test.astype('float32')
    return X_train, X_test, y_train, y_test

csv_path = 'Regression_data.csv'
X_train, X_test, y_train, y_test = load_dataset(csv_path)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3341, 10) (836, 10) (3341,) (836,)

# %%
# 사용자 정의 평가 지표 클래스
import tensorflow as tf
class EvalAccuracy(tf.keras.metrics.Metric): # TensorFlow의 Metric 클래스를 상속 받음

    def __init__(self, name="eval_accuracy", **kwargs): # 부모 클래스의 __init__() 메소드를 호출하여 필요한 초기화를 수행
        super(EvalAccuracy, self).__init__(name=name, **kwargs)
        self.correct = self.add_weight(name="ctp", initializer="zeros")
        # add_weight() 메소드를 사용하여 평가 지표를 계산하는데 필요한 변수를 생성(각 배치에서의 평가 결과를 누적하기 위해)
        # add_weight() 는 텐서플로우 Layer 클래스의 메서드(새로운 가중치를 추가하는 기능, 여기서는 평가 지표를 계산하는 데 사용되는 일종의 내부 변수를 의미)
        # 이 구문이 실행되면, EvalAccuracy 인스턴스는 새로운 가중치를 추가하고 그 가중치를 self.correct에 저장한다.
        # 이 self.correct는 update_state() 메서드에서 업데이트되며, '현재까지 처리한 모든 배치에 대한 평가 지표의 평균을 저장'한다.

    def update_state(self, y_true, y_predict, sample_weight=None):
        value = tf.abs((y_predict - y_true) / y_true)
        self.correct.assign(tf.reduce_mean(value)) # 오차율을 계산해서 correct 변수에 누적한 후, assign() 메소드를 사용하여 correct 변수의 값을 업데이트

    def result(self):
        return 1 - self.correct

    def reset_states(self):
        # 에포크마다 평가 지표 초기화
        self.correct.assign(0.)

# %%
import tensorflow as tf
# 베이스모델
def Base_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=128, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=64, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model

model = Base_Model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# ...
# Total params: 9,729
# Trainable params: 9,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 6

history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/6
# 84/84 [==============================] - 1s 5ms/step - loss: 11.3089 - eval_accuracy: 0.7834 - val_loss: 6.3962 - val_eval_accuracy: 0.7844
# Epoch 2/6
#  1/84 [..............................] - ETA: 0s - loss: 4.8121 - eval_accuracy: 0.8249
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 8.0257 - eval_accuracy: 0.7568 - val_loss: 8.3732 - val_eval_accuracy: 0.8222
# Epoch 3/6
# 84/84 [==============================] - 0s 3ms/step - loss: 7.9043 - eval_accuracy: 0.7992 - val_loss: 6.0511 - val_eval_accuracy: 0.8388
# Epoch 4/6
# 84/84 [==============================] - 0s 2ms/step - loss: 7.0330 - eval_accuracy: 0.7655 - val_loss: 7.5909 - val_eval_accuracy: 0.8264
# ...

# %%
# 베이스모델 활성함수 바꿔보기 sigmoid
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=128, activation='sigmoid', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=64, activation='sigmoid'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model

model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/6
# 84/84 [==============================] - 1s 4ms/step - loss: 12.2599 - eval_accuracy: 0.6776 - val_loss: 9.6764 - val_eval_accuracy: 0.8011
# Epoch 2/6
# 34/84 [===========>..................] - ETA: 0s - loss: 10.4366 - eval_accuracy: 0.7572
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 10.3114 - eval_accuracy: 0.7572 - val_loss: 9.2359 - val_eval_accuracy: 0.8036
# Epoch 3/6
# 84/84 [==============================] - 0s 3ms/step - loss: 9.8014 - eval_accuracy: 0.7295 - val_loss: 9.4021 - val_eval_accuracy: 0.7631
# Epoch 4/6
# 84/84 [==============================] - 0s 2ms/step - loss: 9.0928 - eval_accuracy: 0.6894 - val_loss: 7.8172 - val_eval_accuracy: 0.8068
# ...

# %%
# 베이스모델 활성함수 바꿔보기 softmax
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=128, activation='softmax', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=64, activation='softmax'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model

model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/6
# 65/84 [======================>.......] - ETA: 0s - loss: 45.8206 - eval_accuracy: 0.7257
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 1s 9ms/step - loss: 39.1187 - eval_accuracy: 0.7854 - val_loss: 13.1421 - val_eval_accuracy: 0.7664
# Epoch 2/6
# 84/84 [==============================] - 0s 3ms/step - loss: 11.5867 - eval_accuracy: 0.8011 - val_loss: 10.1230 - val_eval_accuracy: 0.7984
# Epoch 3/6
# 84/84 [==============================] - 0s 3ms/step - loss: 10.7506 - eval_accuracy: 0.8092 - val_loss: 9.9827 - val_eval_accuracy: 0.7975
# Epoch 4/6
# ...

# %% [markdown]
# 단순하게 활성함수만 바꿔봤을때는 relu가 가장 좋은것으로 판명

# %% [markdown]
# 옵티마이저 참고
#
# https://velog.io/@chang0517/Optimizer-%EC%A2%85%EB%A5%98-%EB%B0%8F-%EC%A0%95%EB%A6%AC
# https://keras.io/ko/optimizers/#adamax

# %%
# 베이스모델 optimizers Adam, units 2배
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=128, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model

model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/6
# 84/84 [==============================] - 1s 4ms/step - loss: 11.2275 - eval_accuracy: 0.8210 - val_loss: 6.7082 - val_eval_accuracy: 0.7717
# Epoch 2/6
# 25/84 [=======>......................] - ETA: 0s - loss: 6.7589 - eval_accuracy: 0.8337
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 6.3147 - eval_accuracy: 0.8722 - val_loss: 4.9837 - val_eval_accuracy: 0.8321
# Epoch 3/6
# 84/84 [==============================] - 0s 3ms/step - loss: 5.6562 - eval_accuracy: 0.8188 - val_loss: 4.7909 - val_eval_accuracy: 0.8435
# Epoch 4/6
# 84/84 [==============================] - 0s 3ms/step - loss: 5.5160 - eval_accuracy: 0.8482 - val_loss: 5.5703 - val_eval_accuracy: 0.8315
# ...

# %%
# 옵티마이저 ADAM으로 해봄
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=128, activation='relu'),
            tf.keras.layers.Dense(units=64, activation='relu'),
            tf.keras.layers.Dense(units=32, activation='relu'),
            tf.keras.layers.Dense(units=16, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model
EPOCHS = 100
model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 2s 3ms/step - loss: 14.2020 - eval_accuracy: 0.7692 - val_loss: 5.9771 - val_eval_accuracy: 0.8083
# Epoch 2/100
# 30/84 [=========>....................] - ETA: 0s - loss: 6.7398 - eval_accuracy: 0.8177
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 2ms/step - loss: 6.4498 - eval_accuracy: 0.7459 - val_loss: 4.8636 - val_eval_accuracy: 0.8385
# Epoch 3/100
# 84/84 [==============================] - 0s 2ms/step - loss: 5.6883 - eval_accuracy: 0.7946 - val_loss: 5.7668 - val_eval_accuracy: 0.8288
# Epoch 4/100
# ...

# %%
# 층을 더 늘리고 경사하강법
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=128, activation='relu'),
            tf.keras.layers.Dense(units=64, activation='relu'),
            tf.keras.layers.Dense(units=32, activation='relu'),
            tf.keras.layers.Dense(units=16, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model
EPOCHS = 100
model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 4ms/step - loss: 18.7729 - eval_accuracy: 0.6874 - val_loss: 15.3048 - val_eval_accuracy: 0.7312
# Epoch 2/100
# 29/84 [=========>....................] - ETA: 0s - loss: 7.3794 - eval_accuracy: 0.8372
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 8.1243 - eval_accuracy: 0.7641 - val_loss: 6.2310 - val_eval_accuracy: 0.7985
# Epoch 3/100
# 84/84 [==============================] - 0s 3ms/step - loss: 7.1863 - eval_accuracy: 0.8378 - val_loss: 7.8739 - val_eval_accuracy: 0.7344
# Epoch 4/100
# ...

# %%
# adadelta
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=128, activation='relu'),
            tf.keras.layers.Dense(units=64, activation='relu'),
            tf.keras.layers.Dense(units=32, activation='relu'),
            tf.keras.layers.Dense(units=16, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.Adadelta(learning_rate=LEARNING_RATE) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model
EPOCHS = 100
model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 4s 12ms/step - loss: 104.7509 - eval_accuracy: 0.0368 - val_loss: 101.5852 - val_eval_accuracy: 0.0422
# Epoch 2/100
#  1/84 [..............................] - ETA: 0s - loss: 139.0552 - eval_accuracy: 0.0413
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 88.5583 - eval_accuracy: 0.3473 - val_loss: 52.4294 - val_eval_accuracy: 0.3487
# Epoch 3/100
# 84/84 [==============================] - 0s 3ms/step - loss: 15.0718 - eval_accuracy: 0.7709 - val_loss: 8.1158 - val_eval_accuracy: 0.7863
# Epoch 4/100
# ...

# %%
def Test_Model(LEARNING_RATE=0.01):
    import tensorflow as tf
    model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=256, activation='relu', input_shape=(len(X_train.keys()),)),
            tf.keras.layers.Dense(units=128, activation='relu'),
            tf.keras.layers.Dense(units=64, activation='relu'),
            tf.keras.layers.Dense(units=32, activation='relu'),
            tf.keras.layers.Dense(units=16, activation='relu'),
            tf.keras.layers.Dense(units=1)
        ])
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=LEARNING_RATE, rho = 0.9) # SGD : 경사하강법을 기본적으로 사용하는 옵티마이저
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[EvalAccuracy()]) # metrics=[eval_accuracy(y_pred, y_test)] 직접 작성한 eval_accuracy를 평가지표로 사용할 수 있음
    return model
EPOCHS = 100
model = Test_Model()
history = model.fit(
  X_train, y_train,
  validation_split = 0.2,
  verbose=1,
  epochs=EPOCHS)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 5ms/step - loss: 25.4733 - eval_accuracy: 0.5707 - val_loss: 43.8970 - val_eval_accuracy: 0.4067
# Epoch 2/100
#  1/84 [..............................] - ETA: 0s - loss: 50.7320 - eval_accuracy: 0.4079
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py:2448: UserWarning: Metric EvalAccuracy implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 84/84 [==============================] - 0s 3ms/step - loss: 12.8527 - eval_accuracy: 0.8217 - val_loss: 9.3353 - val_eval_accuracy: 0.7142
# Epoch 3/100
# 84/84 [==============================] - 0s 3ms/step - loss: 10.5342 - eval_accuracy: 0.8526 - val_loss: 5.6840 - val_eval_accuracy: 0.8131
# Epoch 4/100
# ...
